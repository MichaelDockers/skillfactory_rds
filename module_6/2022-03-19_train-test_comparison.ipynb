# %% [markdown]
# # Combining two datasets and making it similar
#
# Don't use this one, [here](2022-04-02_train-test_comparison.ipynb) it more actual version.

# %% [markdown]
# ## imports

# %%
from datetime import datetime
import re
import json

import pandas as pd
import numpy as np

from lib.data_viz_functions import *

# %%
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 100)

# %% [markdown]
# ## reading data from disk

# %%
train_jane = pd.read_pickle("data/train_df_full_part1.pkl.zip", compression="zip")
train_baseline = pd.read_pickle(
    "data/all_auto_ru_09_09_2020.pkl.zip", compression="zip"
)
test = pd.read_pickle("data/test.pkl.zip", compression="zip")

train_jane.shape, train_baseline.shape, test.shape
# Out:
# ((130201, 36), (89378, 26), (34686, 32))

# %% [markdown]
# ## preprocessing functions and vocs

# %%
colors_dict = {
    "040001": "чёрный",
    "EE1D19": "красный",
    "0000CC": "синий",
    "CACECB": "серый",
    "007F00": "зелёный",
    "FAFBFB": "белый",
    "97948F": "серый",
    "22A0F8": "синий",
    "660099": "фиолетовый",
    "200204": "коричневый",
    "C49648": "коричневый",
    "DEA522": "золотистый",
    "4A2197": "фиолетовый",
    "FFD600": "жёлтый",
    "FF8649": "оранжевый",
    "FFC0CB": "розовый",
}

vendor_voc_additional = {
    "CADILLAC": "AMERICAN",
    "CHERY": "CHINESE",
    "CHEVROLET": "AMERICAN",
    "CHRYSLER": "AMERICAN",
    "CITROEN": "EUROPEAN",
    "DAEWOO": "KOREAN",
    "DODGE": "AMERICAN",
    "FORD": "AMERICAN",
    "GEELY": "CHINEESE",
    "HYUNDAI": "KOREAN",
    "JAGUAR": "EUROPEAN",
    "JEEP": "AMERICAN",
    "KIA": "KOREAN",
    "MAZDA": "JAPANESE",
    "MINI": "EUROPEAN",
    "OPEL": "EUROPEAN",
    "PEUGEOT": "EUROPEAN",
    "PORSCHE": "EUROPEAN",
    "RENAULT": "EUROPEAN",
    "SUBARU": "JAPANESE",
    "SUZUKI": "JAPANESE",
    "GREAT_WALL": "CHINESE",
    "LAND_ROVER": "EUROPEAN",
    "SSANG_YONG": "KOREAN",
}

# %%
def parse_ownership_duration(train_str: str) -> float:

    """
    Returns ownership duration in days
    """

    baseline_str = "{'year': 2020, 'month': 9}"

    if not isinstance(train_str, str):
        return np.nan
    elif "year" in str(train_str):
        baseline_dict = json.loads(baseline_str.replace("'", '"'))
        train_dict = json.loads(train_str.replace("'", '"'))

        baseline_date = datetime.strptime(
            f"{baseline_dict['year']}-{baseline_dict['month']}-1", "%Y-%m-%d"
        )
        train_date = datetime.strptime(
            f"{train_dict['year']}-{train_dict['month']}-1", "%Y-%m-%d"
        )
        return (baseline_date - train_date).days
    elif " и " in str(train_str):
        return (
            int(train_str.split(" ")[0]) * 365
            + int(train_str.split(" и ")[1].split(" ")[0]) * 30
        )
    else:
        return int(train_str.split(" ")[0]) * 365


def get_number_of_owners_from_owners(in_str):
    if not isinstance(in_str, str):
        return None
    else:
        result = in_str.replace("\xa0", "")
        return int(re.sub("\D", "", result))
    # return string (to cat)


def get_engine_value(in_str):
    parsed_str = re.findall("(\d+.\d+)", in_str)
    if len(parsed_str):
        return float(parsed_str[0])
    else:
        return None


def get_volume_from_vehicleConfiguration(in_str: str) -> str:
    if not pd.isna(in_str):
        engine_volume = re.findall("[\d]*[.][\d]+", in_str)
        if len(engine_volume) >= 1:
            return engine_volume[0]
        else:
            return np.nan
    else:
        return np.nan

# %% [markdown]
# ## quick view

# %%
describe_nums(train_jane.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T
row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.5%, transparent 0.5%);
# }
# #T_076bb_row3_col3, #T_076bb_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_076bb_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.4%, transparent 0.4%);
# }
# #T_076bb_row5_col0, #T_076bb_row6_col0, #T_076bb_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# #T_076bb_row7_col3, #T_076bb_row8_col0, #T_076bb_row8_col3, #T_076bb_row9_col0, #T_076bb_row9_col3 {
#   width: 10em;
# }
# #T_076bb_row7_col4, #T_076bb_row7_col7, #T_076bb_row8_col4, #T_076bb_row8_col7, #T_076bb_row9_col4, #T_076bb_row9_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_076bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_076bb_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_076bb_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_076bb_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_076bb_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_076bb_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_076bb_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_076bb_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_076bb_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_076bb_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_076bb_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_076bb_level0_row0" class="row_heading level0 row0" >mileage</th>
#       <td id="T_076bb_row0_col0" class="data row0 col0" >17403</td>
#       <td id="T_076bb_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_076bb_row0_col2" class="data row0 col2" >89378.000000</td>
#       <td id="T_076bb_row0_col3" class="data row0 col3" >134828.811497</td>
#       <td id="T_076bb_row0_col4" class="data row0 col4" >102979.784485</td>
#       <td id="T_076bb_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_076bb_row0_col6" class="data row0 col6" >56042.500000</td>
#       <td id="T_076bb_row0_col7" class="data row0 col7" >130000.000000</td>
#       <td id="T_076bb_row0_col8" class="data row0 col8" >194939.750000</td>
#       <td id="T_076bb_row0_col9" class="data row0 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_076bb_level0_row1" class="row_heading level0 row1" >price</th>
#       <td id="T_076bb_row1_col0" class="data row1 col0" >8168</td>
#       <td id="T_076bb_row1_col1" class="data row1 col1" >410</td>
#       <td id="T_076bb_row1_col2" class="data row1 col2" >88968.000000</td>
#       <td id="T_076bb_row1_col3" class="data row1 col3" >1294586.356330</td>
#       <td id="T_076bb_row1_col4" class="data row1 col4" >1950410.471999</td>
#       <td id="T_076bb_row1_col5" class="data row1 col5" >16000.000000</td>
#       <td id="T_076bb_row1_col6" class="data row1 col6" >350000.000000</td>
#       <td id="T_076bb_row1_col7" class="data row1 col7" >650000.000000</td>
#       <td id="T_076bb_row1_col8" class="data row1 col8" >1480000.000000</td>
#       <td id="T_076bb_row1_col9" class="data row1 col9" >99000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_076bb_level0_row2" class="row_heading level0 row2" >enginePower</th>
#       <td id="T_076bb_row2_col0" class="data row2 col0" >396</td>
#       <td id="T_076bb_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_076bb_row2_col2" class="data row2 col2" >89377.000000</td>
#       <td id="T_076bb_row2_col3" class="data row2 col3" >171.231637</td>
#       <td id="T_076bb_row2_col4" class="data row2 col4" >83.527540</td>
#       <td id="T_076bb_row2_col5" class="data row2 col5" >11.000000</td>
#       <td id="T_076bb_row2_col6" class="data row2 col6" >115.000000</td>
#       <td id="T_076bb_row2_col7" class="data row2 col7" >150.000000</td>
#       <td id="T_076bb_row2_col8" class="data row2 col8" >199.000000</td>
#       <td id="T_076bb_row2_col9" class="data row2 col9" >800.000000</td>
#     </tr>
#     <tr>
#       <th id="T_076bb_level0_row3" class="row_heading level0 row3" >productionDate</th>
#       <td id="T_076bb_row3_col0" class="data row3 col0" >80</td>
#       <td id="T_076bb_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_076bb_row3_col2" class="data row3 col2" >89378.000000</td>
#       <td id="T_076bb_row3_col3" class="data row3 col3" >2010.832531</td>
#       <td id="T_076bb_row3_col4" class="data row3 col4" >7.024776</td>
#       <td id="T_076bb_row3_col5" class="data row3 col5" >1904.000000</td>
#       <td id="T_076bb_row3_col6" class="data row3 col6" >2007.000000</td>
#       <td id="T_076bb_row3_col7" class="data row3 col7" >2011.000000</td>
#       <td id="T_076bb_row3_col8" class="data row3 col8" >2016.000000</td>
#       <td id="T_076bb_row3_col9" class="data row3 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_076bb_level0_row4" class="row_heading level0 row4" >modelDate</th>
#       <td id="T_076bb_row4_col0" class="data row4 col0" >78</td>
#       <td id="T_076bb_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_076bb_row4_col2" class="data row4 col2" >89377.000000</td>
#       <td id="T_076bb_row4_col3" class="data row4 col3" >2008.543294</td>
#       <td id="T_076bb_row4_col4" class="data row4 col4" >7.415436</td>
#       <td id="T_076bb_row4_col5" class="data row4 col5" >1904.000000</td>
#       <td id="T_076bb_row4_col6" class="data row4 col6" >2005.000000</td>
#       <td id="T_076bb_row4_col7" class="data row4 col7" >2009.000000</td>
#       <td id="T_076bb_row4_col8" class="data row4 col8" >2014.000000</td>
#       <td id="T_076bb_row4_col9" class="data row4 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_076bb_level0_row5" class="row_heading level0 row5" >numberOfDoors</th>
#       <td id="T_076bb_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_076bb_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_076bb_row5_col2" class="data row5 col2" >89377.000000</td>
#       <td id="T_076bb_row5_col3" class="data row5 col3" >4.510467</td>
#       <td id="T_076bb_row5_col4" class="data row5 col4" >0.653203</td>
#       <td id="T_076bb_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_076bb_row5_col6" class="data row5 col6" >4.000000</td>
#       <td id="T_076bb_row5_col7" class="data row5 col7" >5.000000</td>
#       <td id="T_076bb_row5_col8" class="data row5 col8" >5.000000</td>
#       <td id="T_076bb_row5_col9" class="data row5 col9" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_076bb_level0_row6" class="

# %%
describe_nums(test.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_d29a8_row0_col0, #T_d29a8_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_d29a8_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_d29a8_row0_col4, #T_d29a8_row2_col4 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_d29a8_row0_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_d29a8_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.5%, transparent 68.5%);
# }
# #T_d29a8_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d29a8_row1_col7 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_d29a8_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 32.5%, transparent 32.5%);
# }
# #T_d29a8_row2_col3, #T_d29a8_row3_col3, #T_d29a8_row4_col3, #T_d29a8_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_d29a8_row2_col7, #T_d29a8_row3_col7, #T_d29a8_row4_col7, #T_d29a8_row5_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_d29a8_row3_col0, #T_d29a8_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.2%, transparent 0.2%);
# }
# #T_d29a8_row3_col4, #T_d29a8_row4_col4, #T_d29a8_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_d29a8_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_d29a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d29a8_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_d29a8_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_d29a8_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_d29a8_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_d29a8_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_d29a8_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_d29a8_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_d29a8_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_d29a8_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_d29a8_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d29a8_level0_row0" class="row_heading level0 row0" >parsing_unixtime</th>
#       <td id="T_d29a8_row0_col0" class="data row0 col0" >34686</td>
#       <td id="T_d29a8_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_d29a8_row0_col2" class="data row0 col2" >34686.000000</td>
#       <td id="T_d29a8_row0_col3" class="data row0 col3" >1603286733.619356</td>
#       <td id="T_d29a8_row0_col4" class="data row0 col4" >149307.058483</td>
#       <td id="T_d29a8_row0_col5" class="data row0 col5" >1603107306.000000</td>
#       <td id="T_d29a8_row0_col6" class="data row0 col6" >1603221157.750000</td>
#       <td id="T_d29a8_row0_col7" class="data row0 col7" >1603254133.000000</td>
#       <td id="T_d29a8_row0_col8" class="data row0 col8" >1603290080.250000</td>
#       <td id="T_d29a8_row0_col9" class="data row0 col9" >1603710264.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d29a8_level0_row1" class="row_heading level0 row1" >sell_id</th>
#       <td id="T_d29a8_row1_col0" class="data row1 col0" >34686</td>
#       <td id="T_d29a8_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_d29a8_row1_col2" class="data row1 col2" >34686.000000</td>
#       <td id="T_d29a8_row1_col3" class="data row1 col3" >1098300150.880644</td>
#       <td id="T_d29a8_row1_col4" class="data row1 col4" >19112247.594511</td>
#       <td id="T_d29a8_row1_col5" class="data row1 col5" >2665.000000</td>
#       <td id="T_d29a8_row1_col6" class="data row1 col6" >1099048798.000000</td>
#       <td id="T_d29a8_row1_col7" class="data row1 col7" >1100910913.000000</td>
#       <td id="T_d29a8_row1_col8" class="data row1 col8" >1101245023.750000</td>
#       <td id="T_d29a8_row1_col9" class="data row1 col9" >1101374610.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d29a8_level0_row2" class="row_heading level0 row2" >mileage</th>
#       <td id="T_d29a8_row2_col0" class="data row2 col0" >11268</td>
#       <td id="T_d29a8_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_d29a8_row2_col2" class="data row2 col2" >34686.000000</td>
#       <td id="T_d29a8_row2_col3" class="data row2 col3" >162009.767889</td>
#       <td id="T_d29a8_row2_col4" class="data row2 col4" >100676.559489</td>
#       <td id="T_d29a8_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_d29a8_row2_col6" class="data row2 col6" >91153.500000</td>
#       <td id="T_d29a8_row2_col7" class="data row2 col7" >149779.500000</td>
#       <td id="T_d29a8_row2_col8" class="data row2 col8" >215000.000000</td>
#       <td id="T_d29a8_row2_col9" class="data row2 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d29a8_level0_row3" class="row_heading level0 row3" >productionDate</th>
#       <td id="T_d29a8_row3_col0" class="data row3 col0" >69</td>
#       <td id="T_d29a8_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_d29a8_row3_col2" class="data row3 col2" >34686.000000</td>
#       <td id="T_d29a8_row3_col3" class="data row3 col3" >2009.264602</td>
#       <td id="T_d29a8_row3_col4" class="data row3 col4" >7.047661</td>
#       <td id="T_d29a8_row3_col5" class="data row3 col5" >1904.000000</td>
#       <td id="T_d29a8_row3_col6" class="data row3 col6" >2006.000000</td>
#       <td id="T_d29a8_row3_col7" class="data row3 col7" >2011.000000</td>
#       <td id="T_d29a8_row3_col8" class="data row3 col8" >2014.000000</td>
#       <td id="T_d29a8_row3_col9" class="data row3 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d29a8_level0_row4" class="row_heading level0 row4" >modelDate</th>
#       <td id="T_d29a8_row4_col0" class="data row4 col0" >66</td>
#       <td id="T_d29a8_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_d29a8_row4_col2" class="data row4 col2" >34686.000000</td>
#       <td id="T_d29a8_row4_col3" class="data row4 col3" >2007.074728</td>
#       <td id="T_d29a8_row4_col4" class="data row4 col4" >7.415894</td>
#       <td id="T_d29a8_row4_col5" class="data row4 col5" >1904.000000</td>
#       <td id="T_d29a8_row4_col6" class="data row4 col6" >2004.000000</td>
#       <td id="T_d29a8_row4_col7" class="data row4 col7" >2008.000000</td>
#       <td id="T_d29a8_row4_col8" class="data row4 col8" >2012.000000</td>
#       <td id="T_d29a8_row4_col9" class="data row4 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d29a8_level0_row5" class="row_heading level0 row5" >numberOfDoors</th>
#       <td id="T_d29a8_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_d29a8_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_d29a8_row5_col2" class="data row5 col2" >34686.000000</td>
#       <td id="T_d29a8_row5_col3" class="data row5 col3" >4.450816</td>
#       <td id="T_d29a8_row5_col4" class="data row5 col4" >0.703040</td>
#       <td id="T_d29a8_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_d29a8_row5_col6" class="data row5 col6" >4.000000</td>
#       <td id="T_d29a8_row5_col7" class="data row5 col7" >5.000000</td>
#       <td id="T_d29a8_row5_col8" class="data row5 col8" >5.000000</td>
#       <td id="T_d29a8_row5_col9" class="data row5 col9" >5.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
train_jane.select_dtypes("object").shape, train_baseline.select_dtypes(
    "object"
).shape, test.select_dtypes("object").shape
# Out:
# ((130201, 26), (89378, 16), (34686, 26))

# %%
train_jane.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                        count unique  \
# super_gen             130135  43825
# image                 130065  42933
# car_url               129969  40721
# description           129988  35274
# equipment_dict        129969  31190
# complectation_dict    105267   2348
# name                  130153   2283
# region                103034   1335
# date_added            103034    939
# vehicleConfiguration  129987    564
# model_name            103034    514
# enginePower           129988    307
# Владение               14286    261
# engineDisplacement    129988     52
# bodyType              129986     21
# color                 129988     16
# brand                 129988     12
# fuelType              129986      5
# vehicleTransmission   129986      4
# Владельцы             103034      3
# Привод                103032      3
# ПТС                   103034      2
# Руль                  103033      2
# priceCurrency         130153      2
# Состояние             103032      1
# Таможня               103030      1
#
#                                                                     top  \
# super_gen             {'sale-data-attributes': {'asciiCat': 'cars', ...
# image                 https://avatars.mds.yandex.net/get-autoru-vos/...
# car_url               https://auto.ru/cars/new/group/toyota/rav_4/21...
# description           Официальный дилер Mercedes Benz ООО РОЛЬФ фили...
# equipment_dict                                                       {}
# complectation_dict    ['cruise-control', 'multi-wheel', 'airbag-pass...
# name                                      Nissan X-Trail III Рестайлинг
# region                                                         в Москве
# date_added                                                  25 сентября
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 3.0
# model_name                                                       Tiguan
# enginePower                                                     249 N12
# Владение                                              3 года и 2 месяца
# engineDisplacement                                              2.0 LTR
# bodyType                                              внедорожник 5 дв.
# color                                                            чёрный
# brand                                                            TOYOTA
# fuelType                                                         бензин
# vehicleTransmission                                      автоматическая
# Владельцы                                                    1 владелец
# Привод                                                           полный
# ПТС                                                            Оригинал
# Руль                                                              Левый
# priceCurrency                                                       RUB
# Состояние                                            Не требует ремонта
# Таможня                                                      Растаможен
#
#                         freq
# super_gen                235
# image                    241
# car_url                  428
# description             3230
# equipment_dict          8214
# complectation_dict      1979
# name                    4013
# region                 39180
# date_added             44873
# vehicleConfiguration   10895
# model_name              4592
# enginePower            14262
# Владение                 646
# engineDisplacement     36933
# bodyType               75068
# color                  42216
# brand                  20117
# fuelType              100407
# vehicleTransmission    73836
# Владельцы              40576
# Привод                 58563
# ПТС                    92587
# Руль                   99356
# priceCurrency         129969
# Состояние             103032
# Таможня               103030

# %%
train_baseline.select_dtypes("object").describe().T.sort_values(
    "unique", ascending=False
)
# Out:
#                       count unique  \
# description           86124  77568
# start_date            89378  75680
# Комплектация          89378   5839
# name                  89377   4484
# vehicleConfiguration  89377   1860
# model                 89378   1086
# engineDisplacement    89377    534
# Владение              29201    290
# bodyType              89377    168
# brand                 89378     36
# color                 89378     16
# fuelType              89378      6
# vehicleTransmission   89377      4
# Привод                89377      3
# Руль                  89378      2
# ПТС                   89017      2
#
#                                                                     top   freq
# description           РОЛЬФ Северо-Запад - это первый мегамолл автом...    246
# start_date                                         2020-09-01T10:01:11Z     93
# Комплектация                                                {'id': '0'}  59130
# name                                                  2.0 AT (150 л.с.)   1610
# vehicleConfiguration                               SEDAN MECHANICAL 1.6   4166
# model                                                             FOCUS   2467
# engineDisplacement                                                  1.6  17032
# Владение                                    {'year': 2018, 'month': 10}    497
# bodyType                                              Внедорожник 5 дв.  31885
# brand                                                          MERCEDES   8012
# color                                                            040001  25212
# fuelType                                                         бензин  75053
# vehicleTransmission                                           AUTOMATIC  49218
# Привод                                                         передний  47315
# Руль                                                               LEFT  87589
# ПТС                                                            ORIGINAL  78597

# %%
train_jane["enginePower"] = train_jane["enginePower"].replace("undefined N12", None)
train_jane["enginePower"] = (
    train_jane[~pd.isna(train_jane["enginePower"])]["enginePower"]
    .str.split()
    .str.get(0)
    .astype("int")
)

# %%
test["enginePower"] = test["enginePower"].replace("undefined N12", None)
test["enginePower"] = (
    test[~pd.isna(test["enginePower"])]["enginePower"]
    .str.split()
    .str.get(0)
    .astype("int")
)

# %%
train_jane["engineDisplacement"] = train_jane["engineDisplacement"].replace(
    " LTR", None
)
train_jane["engineDisplacement"] = (
    train_jane[~pd.isna(train_jane["engineDisplacement"])]["engineDisplacement"]
    .str.split()
    .str.get(0)
    .astype("float")
)

# %%
train_baseline['name'] = train_baseline['name'].astype('str')
mask = train_baseline['name'].str.lower().str.contains('electro')
train_baseline.loc[mask, 'name'] = 'Electro'

# %%
train_baseline['engineDisplacement'] = train_baseline['name'].apply(get_volume_from_vehicleConfiguration).astype('float64')

# %%
train_baseline['engineDisplacement'].unique()
# Out:
# array([2.8, 1.8, 2.3, 2. , 2.6, 2.2, 2.5, 1.9, 2.1, 2.4, 1.6, 1.3, 3.3,
#        1.4, 1.2, 3.2, 1.5, 3.1, 3. , 2.7, 4.2, 4. , 3.9, 6.3, 6. , 3.7,
#        4.1, nan, 3.6, 5.9, 5.2, 2.9, 5. , 1.7, 4.4, 3.4, 3.5, 4.8, 5.4,
#        6.6, 0.7, 4.9, 4.6, 6.2, 4.5, 6.4, 8.2, 5.3, 5.7, 7. , 1.1, 0.8,
#        4.3, 8.1, 6.7, 3.8, 1. , 7.5, 7.4, 6.5, 6.1, 6.8, 4.7, 8.4, 5.8,
#        7.3, 5.6, 5.5])

# %%
test["engineDisplacement"] = test["engineDisplacement"].replace(
    " LTR", None
)
test["engineDisplacement"] = (
    test[~pd.isna(test["engineDisplacement"])]["engineDisplacement"]
    .str.split()
    .str.get(0)
    .astype("float")
)

# %%
train_jane.engineDisplacement.head()
# Out:
# 0    1.8
# 1    1.6
# 2    1.6
# 3    1.4
# 4    1.4
# Name: engineDisplacement, dtype: float64

# %%
train_jane["used"] = train_jane["car_url"].str.contains("used")

# %%
train_jane[train_jane["used"] == False].dropna(thresh=24).shape
# Out:
# (0, 37)

# %%
test.iloc[34682]
# Out:
# bodyType                                                            седан
# brand                                                                 BMW
# car_url                 https://auto.ru/cars/used/sale/bmw/5er/1101369...
# color                                                              чёрный
# complectation_dict                                                    NaN
# description                                Продаётся отличный автомобиль.
# engineDisplacement                                                    2.0
# enginePower                                                           190
# equipment_dict                                                        NaN
# fuelType                                                           дизель
# image                   https://autoru.naydex.net/nwI1K7152/b604fdsYg7...
# mileage                                                             98000
# modelDate                                                            2016
# model_info              {"code":"5ER","name":"5 серии","ru_name":"5 се...
# model_name                                                            5ER
# name                                   520d xDrive 2.0d AT (190 л.с.) 4WD
# numberOfDoors                                                           4
# parsing_unixtime                                               1603707651
# priceCurrency                                                         RUB
# productionDate                                                       2018
# sell_id                                                        1101369581
# super_gen               {"id":"20856402","name":"520","nameplate":"520...
# vehicleConfiguration                                  SEDAN AUTOMATIC 2.0
# vehicleTransmission                                        автоматическая
# vendor                                                           EUROPEAN
# Владельцы                                                      1 владелец
# Владение                                                              NaN
# ПТС                                                              Оригинал
# Привод                                                             полный
# Руль                                                                Левый
# Состояние                                              Не требует ремонта
# Таможня                                                        Растаможен
# Name: 34682, dtype: object

# %%
train_jane["car_url"].str.contains("used").value_counts()
# Out:
# True     103034
# False     26935
# Name: car_url, dtype: int64

# %%
test.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                       count unique  \
# car_url               34686  34686
# image                 34686  34557
# description           34686  31732
# equipment_dict        24690  23705
# super_gen             34686   5890
# name                  34686   2780
# complectation_dict     6418   2364
# model_info            34686    954
# vehicleConfiguration  34686    634
# model_name            34686    544
# Владение              11995    275
# bodyType              34686     24
# color                 34686     16
# brand                 34686     12
# fuelType              34686      5
# vehicleTransmission   34686      4
# Владельцы             34686      3
# Привод                34686      3
# vendor                34686      2
# ПТС                   34685      2
# Руль                  34686      2
# Состояние             34686      1
# priceCurrency         34686      1
# Таможня               34686      1
#
#                                                                     top   freq
# car_url               https://auto.ru/cars/used/sale/skoda/octavia/1...      1
# image                 https://avatars.mds.yandex.net/get-verba/21620...     13
# description           Выгода до 82 000 руб. при обмене на Ваш автомо...    264
# equipment_dict                                         {"leather":true}    108
# super_gen             {"id":"6214876","displacement":1598,"engine_ty...    193
# name                                                  1.6 AT (110 л.с.)    631
# complectation_dict    {"id":"4562904","name":"Elegance","available_o...     51
# model_info            {"code":"OCTAVIA","name":"Octavia","ru_name":"...   1404
# vehicleConfiguration                      ALLROAD_5_DOORS AUTOMATIC 3.0   2389
# model_name                                                      OCTAVIA   1418
# Владение                                             1 год и 10 месяцев    209
# bodyType                                                          седан  13147
# color                                                            чёрный  11010
# brand                                                               BMW   4473
# fuelType                                                         бензин  28601
# vehicleTransmission                                      автоматическая  19596
# Владельцы                                                   3 или более  15957
# Привод                                                         передний  15565
# vendor                                                         EUROPEAN  20682
# ПТС                                                            Оригинал  30098
# Руль                                                              Левый  33287
# Состояние                                            Не требует ремонта  34686
# priceCurrency                                                       RUB  34686
# Таможня                                                      Растаможен  34686

# %%
test["fuelType"].value_counts()
# Out:
# бензин     28601
# дизель      5800
# гибрид       223
# электро       55
# газ            7
# Name: fuelType, dtype: int64

# %%
test.groupby("car_url")["image"].count().sort_values(ascending=False).head(10)
# Out:
# car_url
# https://auto.ru/cars/used/sale/audi/100/1016944865-8eb8f/            1
# https://auto.ru/cars/used/sale/skoda/octavia/1100434568-e9537421/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100515744-d97a41fa/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100514944-54916e94/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100513036-35594e9f/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100495414-bb724b6c/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100492150-5ae5281f/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100491772-7f29f9e8/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100487934-c961ee31/    1
# https://auto.ru/cars/used/sale/skoda/octavia/1100486714-6ff064ce/    1
# Name: image, dtype: int64

# %%
test.iloc[2]["model_info"]
# Out:
# '{"code":"SUPERB","name":"Superb","ru_name":"Суперб","morphology":{},"nameplate":{"code":"","name":"","semantic_url":""}}'

# %%
test[test["vehicleConfiguration"] == "ALLROAD_5_DOORS AUTOMATIC 2.0"].sample(
    5, random_state=42
)
# Out:
#                 bodyType       brand  \
# 23340  внедорожник 5 дв.  VOLKSWAGEN
# 5517   внедорожник 5 дв.       HONDA
# 10155  внедорожник 5 дв.         BMW
# 6177   внедорожник 5 дв.       HONDA
# 4276   внедорожник 5 дв.        AUDI
#
#                                                  car_url        color  \
# 23340  https://auto.ru/cars/used/sale/volkswagen/tigu...  серебристый
# 5517   https://auto.ru/cars/used/sale/honda/cr_v/1101...        белый
# 10155  https://auto.ru/cars/used/sale/bmw/x3/10960043...      красный
# 6177   https://auto.ru/cars/used/sale/honda/cr_v/1100...      красный
# 4276   https://auto.ru/cars/used/sale/audi/q5/1101303...        белый
#
#                                       complectation_dict  \
# 23340                                                NaN
# 5517                                                 NaN
# 10155  {"id":"2424078","name":"xDrive20","available_o...
# 6177                                                 NaN
# 4276                                                 NaN
#
#                                              description  engineDisplacement  \
# 23340  Единственный владелец\nАвтомобиль с полным НДС...                 2.0
# 5517   ✔У НАС КРЕДИТ ДАДУТ ВСЕМ!\n●ПРОСТО ОСТАВЬТЕ ЗА...                 2.0
# 10155  Продаю  автомобиль  БМВ-Х 3,2009 года выпуска,...                 2.0
# 6177   Авто в отличном состоянии для своих лет, ходов...                 2.0
# 4276   Состояние нового автомобиля. Нет крашенных эле...                 2.0
#
#        enginePower                                     equipment_dict  \
# 23340          140  {"cruise-control":true,"asr":true,"airbag-driv...
# 5517           128  {"engine-proof":true,"asr":true,"adaptive-ligh...
# 10155          177  {"engine-proof":true,"esp":true,"airbag-driver...
# 6177           128                                                NaN
# 4276           180  {"alloy-wheel-disks":true,"ptf":true,"aux":tru...
#
#       fuelType                                              image  mileage  \
# 23340   дизель  https://autoru.naydex.net/o9DBXQ270/5ac010hAY0...    70366
# 5517    бензин  https://autoru.naydex.net/mcQh17801/f1b5751dCi...   156000
# 10155   дизель  https://autoru.naydex.net/lICN99c69/9bc7d3Rr7k...   158313
# 6177    бензин  https://avatars.mds.yandex.net/get-autoru-vos/...   319000
# 4276    бензин  https://avatars.mds.yandex.net/get-autoru-vos/...    31420
#
#        modelDate                                         model_info  \
# 23340       2011  {"code":"TIGUAN","name":"Tiguan","ru_name":"Ти...
# 5517        1995  {"code":"CR_V","name":"CR-V","ru_name":"CR-V",...
# 10155       2006  {"code":"X3","name":"X3","ru_name":"Х3","morph...
# 6177        1995  {"code":"CR_V","name":"CR-V","ru_name":"CR-V",...
# 4276        2012  {"code":"Q5","name":"Q5","ru_name":"Ку5","morp...
#
#       model_name                        name  numberOfDoors  parsing_unixtime  \
# 23340     TIGUAN      2.0d AT (140 л.с.) 4WD              5        1603213368
# 5517        CR_V       2.0 AT (128 л.с.) 4WD              5        1603254705
# 10155         X3  20d 2.0d AT (177 л.с.) 4WD              5        1603117968
# 6177        CR_V       2.0 AT (128 л.с.) 4WD              5        1603257132
# 4276          Q5       2.0 AT (180 л.с.) 4WD              5        1603129045
#
#       priceCurrency  productionDate     sell_id  \
# 23340           RUB            2015  1101291589
# 5517            RUB            1998  1101117481
# 10155           RUB            2009  1096004334
# 6177            RUB            1998  1100628270
# 4276            RUB            2016  1101303784
#
#                                                super_gen  \
# 23340  {"id":"7344497","displacement":1968,"engine_ty...
# 5517   {"id":"20501678","displacement":1973,"engine_t...
# 10155  {"id":"4917631","name":"20d","nameplate":"20d"...
# 6177   {"id":"20501678","displacement":1973,"engine_t...
# 4276   {"id":"20773921","displacement":1984,"engine_t...
#
#                 vehicleConfiguration vehicleTransmission    vendor  \
# 23340  ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 5517   ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  JAPANESE
# 10155  ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
# 6177   ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  JAPANESE
# 4276   ALLROAD_5_DOORS AUTOMATIC 2.0      автоматическая  EUROPEAN
#
#          Владельцы            Владение       ПТС  Привод   Руль  \
# 23340   1 владелец                 NaN  Оригинал  полный  Левый
# 5517   3 или более                 NaN  Оригинал  полный  Левый
# 10155  3 или более  3 года и 5 месяцев  Оригинал  полный  Левый
# 6177   3 или более                 NaN  Оригинал  полный  Левый
# 4276   2 владельца            2 месяца  Оригинал  полный  Левый
#
#                 Состояние     Таможня
# 23340  Не требует ремонта  Растаможен
# 5517   Не требует ремонта  Растаможен
# 10155  Не требует ремонта  Растаможен
# 6177   Не требует ремонта  Растаможен
# 4276   Не требует ремонта  Растаможен

# %%
test["Владельцы"] = test["Владельцы"].apply(get_number_of_owners_from_owners)
train_jane["Владельцы"] = train_jane["Владельцы"].apply(get_number_of_owners_from_owners)

# %%
print(
    "unique object cols in train (Jane's version):",
    set(train_jane.select_dtypes("object").columns.tolist())
    - set(test.select_dtypes("object").columns.tolist()),
    "\nunique object cols in test:",
    set(test.select_dtypes("object").columns.tolist())
    - set(train_jane.select_dtypes("object").columns.tolist()),
)
# Out:
# unique object cols in train (Jane's version): {'region', 'used', 'date_added'}
# unique object cols in test: {'vendor', 'model_info'}

# %% [markdown]
# ## making train and test similar

# %%
train_jane["model_name"] = train_jane.model_name.apply(lambda x: x.lower() if not pd.isna(x) else x)
test["model_name"] = test.model_name.apply(lambda x: x.lower() if not pd.isna(x) else x)

# %%
vendor_voc = (
    test[["brand", "vendor"]].drop_duplicates().set_index("brand").to_dict()["vendor"]
) | vendor_voc_additional
vendor_voc
# Out:
# {'SKODA': 'EUROPEAN',
#  'AUDI': 'EUROPEAN',
#  'HONDA': 'JAPANESE',
#  'VOLVO': 'EUROPEAN',
#  'BMW': 'EUROPEAN',
#  'NISSAN': 'JAPANESE',
#  'INFINITI': 'JAPANESE',
#  'MERCEDES': 'EUROPEAN',
#  'TOYOTA': 'JAPANESE',
#  'LEXUS': 'JAPANESE',
#  'VOLKSWAGEN': 'EUROPEAN',
#  'MITSUBISHI': 'JAPANESE',
#  'CADILLAC': 'AMERICAN',
#  'CHERY': 'CHINESE',
#  'CHEVROLET': 'AMERICAN',
#  'CHRYSLER': 'AMERICAN',
#  'CITROEN': 'EUROPEAN',
#  'DAEWOO': 'KOREAN',
#  'DODGE': 'AMERICAN',
#  'FORD': 'AMERICAN',
#  'GEELY': 'CHINEESE',
#  'HYUNDAI': 'KOREAN',
#  'JAGUAR': 'EUROPEAN',
#  'JEEP': 'AMERICAN',
#  'KIA': 'KOREAN',
#  'MAZDA': 'JAPANESE',
#  'MINI': 'EUROPEAN',
#  'OPEL': 'EUROPEAN',
#  'PEUGEOT': 'EUROPEAN',
#  'PORSCHE': 'EUROPEAN',
#  'RENAULT': 'EUROPEAN',
#  'SUBARU': 'JAPANESE',
#  'SUZUKI': 'JAPANESE',
#  'GREAT_WALL': 'CHINESE',
#  'LAND_ROVER': 'EUROPEAN',
#  'SSANG_YONG': 'KOREAN'}

# %%
train_jane["vendor"] = train_jane["brand"].map(vendor_voc)
train_baseline["vendor"] = train_baseline["brand"].map(vendor_voc)
train_jane.vendor.unique().tolist(), train_baseline.vendor.unique().tolist()
# Out:
# (['EUROPEAN', nan, 'JAPANESE'],
#  ['EUROPEAN', 'AMERICAN', 'CHINESE', 'KOREAN', 'CHINEESE', 'JAPANESE'])

# %%
test.vendor.value_counts(dropna=False)
# Out:
# EUROPEAN    20682
# JAPANESE    14004
# Name: vendor, dtype: int64

# %%
train_jane.vendor.value_counts(dropna=False)
# Out:
# EUROPEAN    72959
# JAPANESE    57029
# NaN           213
# Name: vendor, dtype: int64

# %%
train_baseline.vendor.value_counts(dropna=False)
# Out:
# EUROPEAN    43082
# JAPANESE    21917
# KOREAN      13122
# AMERICAN     9976
# CHINESE       986
# CHINEESE      295
# Name: vendor, dtype: int64

# %%
train_baseline.loc[train_baseline.vendor.isna()]["brand"].unique()
# Out:
# array([], dtype=object)

# %%
train_jane.dropna(subset=["vendor"], axis="rows", inplace=True)

# %%
print(
    len(train_jane.loc[train_jane.vendor.isna()]["model_name"].unique().tolist()),
    "na of",
    len(train_jane.model_name.unique().tolist()),
)
# Out:
# 0 na of 514

# %%
train_jane.loc[train_jane.vendor.isna()].shape
# Out:
# (0, 37)

# %%
train_jane.priceCurrency.unique()
# Out:
# array(['RUB', 'RUR'], dtype=object)

# %%
train_baseline.columns.sort_values().tolist()
# Out:
# ['bodyType',
#  'brand',
#  'color',
#  'description',
#  'engineDisplacement',
#  'enginePower',
#  'fuelType',
#  'hidden',
#  'mileage',
#  'model',
#  'modelDate',
#  'name',
#  'numberOfDoors',
#  'price',
#  'productionDate',
#  'start_date',
#  'vehicleConfiguration',
#  'vehicleTransmission',
#  'vendor',
#  'Владельцы',
#  'Владение',
#  'Комплектация',
#  'ПТС',
#  'Привод',
#  'Руль',
#  'Состояние',
#  'Таможня']

# %% [markdown]
# ## deleting cols which can't be used
#
# at least for now - to re-review later

# %%
del test["car_url"]
del test["complectation_dict"]
del test["equipment_dict"]
del test["image"]
del test["model_info"]
del test["name"]
del test["parsing_unixtime"]
del test["priceCurrency"]
del test["sell_id"]
del test["vehicleConfiguration"]
del test["Состояние"]
del test["Таможня"]
del test["super_gen"]
del test["model_name"]
del train_baseline["hidden"]
del train_baseline["name"]
del train_baseline["start_date"]
del train_baseline["vehicleConfiguration"]
del train_baseline["Комплектация"]
del train_baseline["Состояние"]
del train_baseline["Таможня"]
del train_baseline["model"]
del train_jane["car_url"]
del train_jane["complectation_dict"]
del train_jane["date_added"]
del train_jane["equipment_dict"]
del train_jane["image"]
del train_jane["model_info"]
del train_jane["name"]
del train_jane["parsing_unixtime"]
del train_jane["priceCurrency"]
del train_jane["region"]
del train_jane["sell_id"]
del train_jane["vehicleConfiguration"]
del train_jane["views"]
del train_jane["Состояние"]
del train_jane["Таможня"]
del train_jane["super_gen"]
del train_jane["used"]
del train_jane["model_name"]

# %% [markdown]
# ## view again

# %%
describe_nums(train_jane.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_8db2d_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_8db2d_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.2%, transparent 4.2%);
# }
# #T_8db2d_row0_col4 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_8db2d_row0_col7 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_8db2d_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 53.4%, transparent 53.4%);
# }
# #T_8db2d_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_8db2d_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_8db2d_row1_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_8db2d_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 2.0%, transparent 2.0%);
# }
# #T_8db2d_row2_col3, #T_8db2d_row4_col3, #T_8db2d_row6_col3, #T_8db2d_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_8db2d_row2_col4, #T_8db2d_row3_col4, #T_8db2d_row4_col4, #T_8db2d_row5_col4, #T_8db2d_row6_col4, #T_8db2d_row7_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_8db2d_row2_col7, #T_8db2d_row3_col7, #T_8db2d_row4_col7, #T_8db2d_row5_col7, #T_8db2d_row6_col7, #T_8db2d_row7_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_8db2d_row3_col0, #T_8db2d_row4_col0, #T_8db2d_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.3%, transparent 0.3%);
# }
# #T_8db2d_row3_col3, #T_8db2d_row5_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.1%, transparent 0.1%);
# }
# #T_8db2d_row6_col0, #T_8db2d_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_8db2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8db2d_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_8db2d_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_8db2d_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_8db2d_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_8db2d_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_8db2d_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_8db2d_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_8db2d_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_8db2d_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_8db2d_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8db2d_level0_row0" class="row_heading level0 row0" >mileage</th>
#       <td id="T_8db2d_row0_col0" class="data row0 col0" >15181</td>
#       <td id="T_8db2d_row0_col1" class="data row0 col1" >26954</td>
#       <td id="T_8db2d_row0_col2" class="data row0 col2" >103034.000000</td>
#       <td id="T_8db2d_row0_col3" class="data row0 col3" >116610.915407</td>
#       <td id="T_8db2d_row0_col4" class="data row0 col4" >85154.492046</td>
#       <td id="T_8db2d_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_8db2d_row0_col6" class="data row0 col6" >51000.000000</td>
#       <td id="T_8db2d_row0_col7" class="data row0 col7" >100000.000000</td>
#       <td id="T_8db2d_row0_col8" class="data row0 col8" >161000.000000</td>
#       <td id="T_8db2d_row0_col9" class="data row0 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8db2d_level0_row1" class="row_heading level0 row1" >price</th>
#       <td id="T_8db2d_row1_col0" class="data row1 col0" >8105</td>
#       <td id="T_8db2d_row1_col1" class="data row1 col1" >20223</td>
#       <td id="T_8db2d_row1_col2" class="data row1 col2" >109765.000000</td>
#       <td id="T_8db2d_row1_col3" class="data row1 col3" >2801223.260639</td>
#       <td id="T_8db2d_row1_col4" class="data row1 col4" >2689068.150068</td>
#       <td id="T_8db2d_row1_col5" class="data row1 col5" >23000.000000</td>
#       <td id="T_8db2d_row1_col6" class="data row1 col6" >1000000.000000</td>
#       <td id="T_8db2d_row1_col7" class="data row1 col7" >2045000.000000</td>
#       <td id="T_8db2d_row1_col8" class="data row1 col8" >3649000.000000</td>
#       <td id="T_8db2d_row1_col9" class="data row1 col9" >39990000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8db2d_level0_row2" class="row_heading level0 row2" >enginePower</th>
#       <td id="T_8db2d_row2_col0" class="data row2 col0" >306</td>
#       <td id="T_8db2d_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_8db2d_row2_col2" class="data row2 col2" >129986.000000</td>
#       <td id="T_8db2d_row2_col3" class="data row2 col3" >205.952133</td>
#       <td id="T_8db2d_row2_col4" class="data row2 col4" >97.503652</td>
#       <td id="T_8db2d_row2_col5" class="data row2 col5" >41.000000</td>
#       <td id="T_8db2d_row2_col6" class="data row2 col6" >146.000000</td>
#       <td id="T_8db2d_row2_col7" class="data row2 col7" >180.000000</td>
#       <td id="T_8db2d_row2_col8" class="data row2 col8" >249.000000</td>
#       <td id="T_8db2d_row2_col9" class="data row2 col9" >646.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8db2d_level0_row3" class="row_heading level0 row3" >modelDate</th>
#       <td id="T_8db2d_row3_col0" class="data row3 col0" >53</td>
#       <td id="T_8db2d_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_8db2d_row3_col2" class="data row3 col2" >129986.000000</td>
#       <td id="T_8db2d_row3_col3" class="data row3 col3" >2012.934578</td>
#       <td id="T_8db2d_row3_col4" class="data row3 col4" >6.017749</td>
#       <td id="T_8db2d_row3_col5" class="data row3 col5" >1938.000000</td>
#       <td id="T_8db2d_row3_col6" class="data row3 col6" >2010.000000</td>
#       <td id="T_8db2d_row3_col7" class="data row3 col7" >2014.000000</td>
#       <td id="T_8db2d_row3_col8" class="data row3 col8" >2017.000000</td>
#       <td id="T_8db2d_row3_col9" class="data row3 col9" >2021.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8db2d_level0_row4" class="row_heading level0 row4" >engineDisplacement</th>
#       <td id="T_8db2d_row4_col0" class="data row4 col0" >51</td>
#       <td id="T_8db2d_row4_col1" class="data row4 col1" >416</td>
#       <td id="T_8db2d_row4_col2" class="data row4 col2" >129572.000000</td>
#       <td id="T_8db2d_row4_col3" class="data row4 col3" >2.437865</td>
#       <td id="T_8db2d_row4_col4" class="data row4 col4" >0.933884</td>
#       <td id="T_8db2d_row4_col5" class="data row4 col5" >0.700000</td>
#       <td id="T_8db2d_row4_col6" class="data row4 col6" >2.000000</td>
#       <td id="T_8db2d_row4_col7" class="data row4 col7" >2.000000</td>
#       <td id="T_8db2d_row4_col8" class="data row4 col8" >3.000000</td>
#       <td id="T_8db2d_row4_col9" class="data row4 col9" >6.600000</td>
#     </tr>
#     <tr>
#       <th id="T_8db2d_level0_row5" class="row_heading level0 row5" >productionDate</th>
#       <td id="T_8db2d_row5_col0" class="data row5 col0" >50</td>
#       <td id="T_8db2d_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_8db2d_row5_col2" class="data row5 col2" >129988.000000</td>
#       <td id="T_8db2d_row5_col3" class="data row5 col3" >2015.083854</td>
#       <td id="T_8db2d_row5_col4" class="data row5 col4" >5.929774</td>
#       <td id="T_8db2d_row5_col5" class="data row5 col5" >1952.000000</td>
#       <td id="T_8db2d_row5_col6" class="data row5 col6" >2012.000000</td>
#       <td id="T_8db2d_row5_col7" class="data row5 col7" >2016.000000</td>
#       <td id="T_8db2d_row5_col8" class="data row5 col8" >2020.000000</td>
#       <td id="T_8db2d_row5_col9" class="data row5 col9" >2021.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8db2d_level0_row6" class="row_heading level0 row6" >numberOfDoors</th>
#       <td id="T_8db2d_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_8db2d_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_8db2d_row6_col2" class="data row6 col2" >129987.000000</td>
#       <td id="T_8db2d_row6_col3" class="data row6

# %%
describe_nums(train_baseline.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_318df_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_318df_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.4%, transparent 10.4%);
# }
# #T_318df_row0_col4 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_318df_row0_col7 {
#   background-color: #414487;
#   color: #f1f1f1;
# }
# #T_318df_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 46.9%, transparent 46.9%);
# }
# #T_318df_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_318df_row1_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_318df_row1_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_318df_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 2.3%, transparent 2.3%);
# }
# #T_318df_row2_col3, #T_318df_row5_col3, #T_318df_row6_col3, #T_318df_row7_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_318df_row2_col4, #T_318df_row3_col4, #T_318df_row4_col4, #T_318df_row5_col4, #T_318df_row6_col4, #T_318df_row7_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_318df_row2_col7, #T_318df_row3_col7, #T_318df_row4_col7, #T_318df_row5_col7, #T_318df_row6_col7, #T_318df_row7_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_318df_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.5%, transparent 0.5%);
# }
# #T_318df_row3_col3, #T_318df_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_318df_row4_col0, #T_318df_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.4%, transparent 0.4%);
# }
# #T_318df_row6_col0, #T_318df_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_318df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_318df_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_318df_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_318df_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_318df_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_318df_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_318df_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_318df_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_318df_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_318df_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_318df_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_318df_level0_row0" class="row_heading level0 row0" >mileage</th>
#       <td id="T_318df_row0_col0" class="data row0 col0" >17403</td>
#       <td id="T_318df_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_318df_row0_col2" class="data row0 col2" >89378.000000</td>
#       <td id="T_318df_row0_col3" class="data row0 col3" >134828.811497</td>
#       <td id="T_318df_row0_col4" class="data row0 col4" >102979.784485</td>
#       <td id="T_318df_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_318df_row0_col6" class="data row0 col6" >56042.500000</td>
#       <td id="T_318df_row0_col7" class="data row0 col7" >130000.000000</td>
#       <td id="T_318df_row0_col8" class="data row0 col8" >194939.750000</td>
#       <td id="T_318df_row0_col9" class="data row0 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_318df_level0_row1" class="row_heading level0 row1" >price</th>
#       <td id="T_318df_row1_col0" class="data row1 col0" >8168</td>
#       <td id="T_318df_row1_col1" class="data row1 col1" >410</td>
#       <td id="T_318df_row1_col2" class="data row1 col2" >88968.000000</td>
#       <td id="T_318df_row1_col3" class="data row1 col3" >1294586.356330</td>
#       <td id="T_318df_row1_col4" class="data row1 col4" >1950410.471999</td>
#       <td id="T_318df_row1_col5" class="data row1 col5" >16000.000000</td>
#       <td id="T_318df_row1_col6" class="data row1 col6" >350000.000000</td>
#       <td id="T_318df_row1_col7" class="data row1 col7" >650000.000000</td>
#       <td id="T_318df_row1_col8" class="data row1 col8" >1480000.000000</td>
#       <td id="T_318df_row1_col9" class="data row1 col9" >99000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_318df_level0_row2" class="row_heading level0 row2" >enginePower</th>
#       <td id="T_318df_row2_col0" class="data row2 col0" >396</td>
#       <td id="T_318df_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_318df_row2_col2" class="data row2 col2" >89377.000000</td>
#       <td id="T_318df_row2_col3" class="data row2 col3" >171.231637</td>
#       <td id="T_318df_row2_col4" class="data row2 col4" >83.527540</td>
#       <td id="T_318df_row2_col5" class="data row2 col5" >11.000000</td>
#       <td id="T_318df_row2_col6" class="data row2 col6" >115.000000</td>
#       <td id="T_318df_row2_col7" class="data row2 col7" >150.000000</td>
#       <td id="T_318df_row2_col8" class="data row2 col8" >199.000000</td>
#       <td id="T_318df_row2_col9" class="data row2 col9" >800.000000</td>
#     </tr>
#     <tr>
#       <th id="T_318df_level0_row3" class="row_heading level0 row3" >productionDate</th>
#       <td id="T_318df_row3_col0" class="data row3 col0" >80</td>
#       <td id="T_318df_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_318df_row3_col2" class="data row3 col2" >89378.000000</td>
#       <td id="T_318df_row3_col3" class="data row3 col3" >2010.832531</td>
#       <td id="T_318df_row3_col4" class="data row3 col4" >7.024776</td>
#       <td id="T_318df_row3_col5" class="data row3 col5" >1904.000000</td>
#       <td id="T_318df_row3_col6" class="data row3 col6" >2007.000000</td>
#       <td id="T_318df_row3_col7" class="data row3 col7" >2011.000000</td>
#       <td id="T_318df_row3_col8" class="data row3 col8" >2016.000000</td>
#       <td id="T_318df_row3_col9" class="data row3 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_318df_level0_row4" class="row_heading level0 row4" >modelDate</th>
#       <td id="T_318df_row4_col0" class="data row4 col0" >78</td>
#       <td id="T_318df_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_318df_row4_col2" class="data row4 col2" >89377.000000</td>
#       <td id="T_318df_row4_col3" class="data row4 col3" >2008.543294</td>
#       <td id="T_318df_row4_col4" class="data row4 col4" >7.415436</td>
#       <td id="T_318df_row4_col5" class="data row4 col5" >1904.000000</td>
#       <td id="T_318df_row4_col6" class="data row4 col6" >2005.000000</td>
#       <td id="T_318df_row4_col7" class="data row4 col7" >2009.000000</td>
#       <td id="T_318df_row4_col8" class="data row4 col8" >2014.000000</td>
#       <td id="T_318df_row4_col9" class="data row4 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_318df_level0_row5" class="row_heading level0 row5" >engineDisplacement</th>
#       <td id="T_318df_row5_col0" class="data row5 col0" >67</td>
#       <td id="T_318df_row5_col1" class="data row5 col1" >112</td>
#       <td id="T_318df_row5_col2" class="data row5 col2" >89266.000000</td>
#       <td id="T_318df_row5_col3" class="data row5 col3" >2.206392</td>
#       <td id="T_318df_row5_col4" class="data row5 col4" >0.879322</td>
#       <td id="T_318df_row5_col5" class="data row5 col5" >0.700000</td>
#       <td id="T_318df_row5_col6" class="data row5 col6" >1.600000</td>
#       <td id="T_318df_row5_col7" class="data row5 col7" >2.000000</td>
#       <td id="T_318df_row5_col8" class="data row5 col8" >2.500000</td>
#       <td id="T_318df_row5_col9" class="data row5 col9" >8.400000</td>
#     </tr>
#     <tr>
#       <th id="T_318df_level0_row6" class="row_heading level0 row6" >numberOfDoors</th>
#       <td id="T_318df_row6_col0" class="data row6 col0" >5</td>
#       <td id="T_318df_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_318df_row6_col2" class="data ro

# %%
describe_nums(test.select_dtypes(exclude="object"))
# Out:
# <style type="text/css">
# #T_abab3_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 100.0%, transparent 100.0%);
# }
# #T_abab3_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_abab3_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_abab3_row0_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_abab3_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 2.8%, transparent 2.8%);
# }
# #T_abab3_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.1%, transparent 0.1%);
# }
# #T_abab3_row1_col4, #T_abab3_row2_col4, #T_abab3_row3_col4, #T_abab3_row4_col4, #T_abab3_row5_col4, #T_abab3_row6_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_abab3_row1_col7, #T_abab3_row4_col7, #T_abab3_row5_col7, #T_abab3_row6_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_abab3_row2_col0, #T_abab3_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.6%, transparent 0.6%);
# }
# #T_abab3_row2_col3, #T_abab3_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.2%, transparent 1.2%);
# }
# #T_abab3_row2_col7, #T_abab3_row3_col7 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_abab3_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.5%, transparent 0.5%);
# }
# #T_abab3_row4_col3, #T_abab3_row5_col3, #T_abab3_row6_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, transparent 0.0%);
# }
# #T_abab3_row5_col0, #T_abab3_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightblue 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_abab3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abab3_level0_col0" class="col_heading level0 col0" >unique</th>
#       <th id="T_abab3_level0_col1" class="col_heading level0 col1" >n/a count</th>
#       <th id="T_abab3_level0_col2" class="col_heading level0 col2" >count</th>
#       <th id="T_abab3_level0_col3" class="col_heading level0 col3" >mean</th>
#       <th id="T_abab3_level0_col4" class="col_heading level0 col4" >std</th>
#       <th id="T_abab3_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_abab3_level0_col6" class="col_heading level0 col6" >25%</th>
#       <th id="T_abab3_level0_col7" class="col_heading level0 col7" >50%</th>
#       <th id="T_abab3_level0_col8" class="col_heading level0 col8" >75%</th>
#       <th id="T_abab3_level0_col9" class="col_heading level0 col9" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abab3_level0_row0" class="row_heading level0 row0" >mileage</th>
#       <td id="T_abab3_row0_col0" class="data row0 col0" >11268</td>
#       <td id="T_abab3_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_abab3_row0_col2" class="data row0 col2" >34686.000000</td>
#       <td id="T_abab3_row0_col3" class="data row0 col3" >162009.767889</td>
#       <td id="T_abab3_row0_col4" class="data row0 col4" >100676.559489</td>
#       <td id="T_abab3_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_abab3_row0_col6" class="data row0 col6" >91153.500000</td>
#       <td id="T_abab3_row0_col7" class="data row0 col7" >149779.500000</td>
#       <td id="T_abab3_row0_col8" class="data row0 col8" >215000.000000</td>
#       <td id="T_abab3_row0_col9" class="data row0 col9" >1000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_abab3_level0_row1" class="row_heading level0 row1" >enginePower</th>
#       <td id="T_abab3_row1_col0" class="data row1 col0" >315</td>
#       <td id="T_abab3_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_abab3_row1_col2" class="data row1 col2" >34686.000000</td>
#       <td id="T_abab3_row1_col3" class="data row1 col3" >188.194142</td>
#       <td id="T_abab3_row1_col4" class="data row1 col4" >89.087035</td>
#       <td id="T_abab3_row1_col5" class="data row1 col5" >30.000000</td>
#       <td id="T_abab3_row1_col6" class="data row1 col6" >125.000000</td>
#       <td id="T_abab3_row1_col7" class="data row1 col7" >169.000000</td>
#       <td id="T_abab3_row1_col8" class="data row1 col8" >233.000000</td>
#       <td id="T_abab3_row1_col9" class="data row1 col9" >639.000000</td>
#     </tr>
#     <tr>
#       <th id="T_abab3_level0_row2" class="row_heading level0 row2" >productionDate</th>
#       <td id="T_abab3_row2_col0" class="data row2 col0" >69</td>
#       <td id="T_abab3_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_abab3_row2_col2" class="data row2 col2" >34686.000000</td>
#       <td id="T_abab3_row2_col3" class="data row2 col3" >2009.264602</td>
#       <td id="T_abab3_row2_col4" class="data row2 col4" >7.047661</td>
#       <td id="T_abab3_row2_col5" class="data row2 col5" >1904.000000</td>
#       <td id="T_abab3_row2_col6" class="data row2 col6" >2006.000000</td>
#       <td id="T_abab3_row2_col7" class="data row2 col7" >2011.000000</td>
#       <td id="T_abab3_row2_col8" class="data row2 col8" >2014.000000</td>
#       <td id="T_abab3_row2_col9" class="data row2 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_abab3_level0_row3" class="row_heading level0 row3" >modelDate</th>
#       <td id="T_abab3_row3_col0" class="data row3 col0" >66</td>
#       <td id="T_abab3_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_abab3_row3_col2" class="data row3 col2" >34686.000000</td>
#       <td id="T_abab3_row3_col3" class="data row3 col3" >2007.074728</td>
#       <td id="T_abab3_row3_col4" class="data row3 col4" >7.415894</td>
#       <td id="T_abab3_row3_col5" class="data row3 col5" >1904.000000</td>
#       <td id="T_abab3_row3_col6" class="data row3 col6" >2004.000000</td>
#       <td id="T_abab3_row3_col7" class="data row3 col7" >2008.000000</td>
#       <td id="T_abab3_row3_col8" class="data row3 col8" >2012.000000</td>
#       <td id="T_abab3_row3_col9" class="data row3 col9" >2020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_abab3_level0_row4" class="row_heading level0 row4" >engineDisplacement</th>
#       <td id="T_abab3_row4_col0" class="data row4 col0" >54</td>
#       <td id="T_abab3_row4_col1" class="data row4 col1" >55</td>
#       <td id="T_abab3_row4_col2" class="data row4 col2" >34631.000000</td>
#       <td id="T_abab3_row4_col3" class="data row4 col3" >2.406070</td>
#       <td id="T_abab3_row4_col4" class="data row4 col4" >0.960483</td>
#       <td id="T_abab3_row4_col5" class="data row4 col5" >0.700000</td>
#       <td id="T_abab3_row4_col6" class="data row4 col6" >1.800000</td>
#       <td id="T_abab3_row4_col7" class="data row4 col7" >2.000000</td>
#       <td id="T_abab3_row4_col8" class="data row4 col8" >3.000000</td>
#       <td id="T_abab3_row4_col9" class="data row4 col9" >6.600000</td>
#     </tr>
#     <tr>
#       <th id="T_abab3_level0_row5" class="row_heading level0 row5" >numberOfDoors</th>
#       <td id="T_abab3_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_abab3_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_abab3_row5_col2" class="data row5 col2" >34686.000000</td>
#       <td id="T_abab3_row5_col3" class="data row5 col3" >4.450816</td>
#       <td id="T_abab3_row5_col4" class="data row5 col4" >0.703040</td>
#       <td id="T_abab3_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_abab3_row5_col6" class="data row5 col6" >4.000000</td>
#       <td id="T_abab3_row5_col7" class="data row5 col7" >5.000000</td>
#       <td id="T_abab3_row5_col8" class="data row5 col8" >5.000000</td>
#       <td id="T_abab3_row5_col9" class="data row5 col9" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_abab3_level0_row6" class="row_heading level0 row6" >Владельцы</th>
#       <td id="T_abab3_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_abab3_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_abab3_row6_col2" class="data row6 col2" >34686.000000</td>
#       <td id="T_abab3_row6_col3" class="data row6 col3" >2.187338</td>
#       <td id="T_abab3_row6_col4" class="data row6 col4" >0.835266</td>
#       <td id="T_abab3_row6_col5" class="data row6 col5" >1.000000</td>
#       <td id="T_abab3_ro

# %%
train_jane.select_dtypes("object").shape, train_baseline.select_dtypes(
    "object"
).shape, test.select_dtypes("object").shape
# Out:
# ((129988, 11), (89378, 11), (34686, 11))

# %%
train_jane.select_dtypes("object").describe().T.sort_values("unique", ascending=False)
# Out:
#                       count unique  \
# description          129988  35274
# Владение              14286    261
# bodyType             129986     21
# color                129988     16
# brand                129988     12
# fuelType             129986      5
# vehicleTransmission  129986      4
# Привод               103032      3
# vendor               129988      2
# ПТС                  103034      2
# Руль                 103033      2
#
#                                                                    top    freq
# description          Официальный дилер Mercedes Benz ООО РОЛЬФ фили...    3230
# Владение                                             3 года и 2 месяца     646
# bodyType                                             внедорожник 5 дв.   75068
# color                                                           чёрный   42216
# brand                                                           TOYOTA   20117
# fuelType                                                        бензин  100407
# vehicleTransmission                                     автоматическая   73836
# Привод                                                          полный   58563
# vendor                                                        EUROPEAN   72959
# ПТС                                                           Оригинал   92587
# Руль                                                             Левый   99356

# %%
train_baseline.select_dtypes("object").describe().T.sort_values(
    "unique", ascending=False
)
# Out:
#                      count unique  \
# description          86124  77568
# Владение             29201    290
# bodyType             89377    168
# brand                89378     36
# color                89378     16
# fuelType             89378      6
# vendor               89378      6
# vehicleTransmission  89377      4
# Привод               89377      3
# Руль                 89378      2
# ПТС                  89017      2
#
#                                                                    top   freq
# description          РОЛЬФ Северо-Запад - это первый мегамолл автом...    246
# Владение                                   {'year': 2018, 'month': 10}    497
# bodyType                                             Внедорожник 5 дв.  31885
# brand                                                         MERCEDES   8012
# color                                                           040001  25212
# fuelType                                                        бензин  75053
# vendor                                                        EUROPEAN  43082
# vehicleTransmission                                          AUTOMATIC  49218
# Привод                                                        передний  47315
# Руль                                                              LEFT  87589
# ПТС                                                           ORIGINAL  78597

# %%
test.select_dtypes("object").describe().T.sort_values("unique", ascending=False)[
    "top"
].head(1).tolist()
# Out:
# ['Выгода до 82 000 руб. при обмене на Ваш автомобиль! \nВыгода при покупке в кредит до 100 000 руб.! \nРОЛЬФ ЯСЕНЕВО с пробегом. \n-Мы принимаем любые легковые и коммерческие автомобили независимо от марки, года выпуска, пробега и состояния автомобиля. \n-В наличии более 500 проверенных и готовых к продаже автомобилей. \n-Более 400 комплектов шин, дисков, колес в сборе. \n-Все автомобили проходят комплексную проверку - техническую, криминалистическую, проверку истории кузовных ремонтов сертифицированными специалистами. \n-Мы предоставляем гарантию юридической чистоты в соответствии с законодательством РФ. \n-Мы работаем каждый день с 9:00 до 22:00 (без выходных). \nУслуги: \n• Срочный выкуп Вашего автомобиля \n• Выкуп кредитных а/м \n• Trade-in - обмен Вашего автомобиля на новый или с пробегом (возможна доплата с любой стороны) \n• Выездная оценка Вашего а/м \n• Комиссионная продажа (на Ваших условиях) \n• Аукцион \n• Кредитование \n• Страхование КАСКО, ОСАГО \n• Дополнительное оборудование \n• Запасные части \n• Сервисное обслуживание \n• Б/У шины и диски']

# %%
test.sample(3).T
# Out:
#                                                                  4240   \
# bodyType                                                         седан
# brand                                                             AUDI
# color                                                            синий
# description          Автомобиль в хорошем техническом и внешнем сос...
# engineDisplacement                                                 2.0
# enginePower                                                        130
# fuelType                                                        бензин
# mileage                                                         360000
# modelDate                                                         2000
# numberOfDoors                                                        4
# productionDate                                                    2001
# vehicleTransmission                                           вариатор
# vendor                                                        EUROPEAN
# Владельцы                                                            3
# Владение                                              5 лет и 4 месяца
# ПТС                                                           Дубликат
# Привод                                                        передний
# Руль                                                             Левый
#
#                                                                  2391   \
# bodyType                                             внедорожник 5 дв.
# brand                                                             AUDI
# color                                                           чёрный
# description          Комфорт: 6. Безопасность: 7. Салон: 5. Обзор: ...
# engineDisplacement                                                 3.0
# enginePower                                                        245
# fuelType                                                        дизель
# mileage                                                         101837
# modelDate                                                         2009
# numberOfDoors                                                        5
# productionDate                                                    2015
# vehicleTransmission                                     автоматическая
# vendor                                                        EUROPEAN
# Владельцы                                                            2
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                          полный
# Руль                                                             Левый
#
#                                                                  12071
# bodyType                                             внедорожник 5 дв.
# brand                                                           NISSAN
# color                                                          красный
# description          Куплен у официального дилера. Сервисная книжка...
# engineDisplacement                                                 3.5
# enginePower                                                        249
# fuelType                                                        бензин
# mileage                                                         165000
# modelDate                                                         2010
# numberOfDoors                                                        5
# productionDate                                                    2011
# vehicleTransmission                                           вариатор
# vendor                                                        JAPANESE
# Владельцы                                                            2
# Владение                                            3 года и 7 месяцев
# ПТС                                                           Оригинал
# Привод                                                          полный
# Руль                                                             Левый

# %%
train_jane.loc[train_jane.price.isna()].shape[0], train_jane.price.shape[
    0
], train_jane.loc[train_jane.price.isna()].shape[0] / train_jane.price.shape[0]
# Out:
# (20223, 129988, 0.15557589931378282)

# %% [markdown]
# ## conclusion - to do about variables
#
# $y = price$ - dropna, multiply for date course based coefficient for each dataset, take a log
#
# - [ ] **description** - to tokenize - to read more about tokenize
# - [ ] **engineDisplacement** - convert to float
# - [ ] **enginePower** - convert to integer
# - [ ] **Владельцы** - convert to integer
# - [ ] **Владение** - calculate number of day
# - [ ] **used** - is it possible to create this from urls or something for other datasets?
# - [ ] **super_gen** - do we have something to extract? We have no such col in baseline
# - [ ] **bodyType**, **color**, **brand**, **fuelType**, **vehicleTransmission**, **Привод**, **ПТС**, **Руль** - _temporary keep as is_
#
# more
#
# - [ ] mileage rename
# - [ ] compare with existing features
# - [ ] compare 4 dicts (equepment, complactation) train - test
# Numerics - fill na, log if tailed, standartize
# https://www.kaggle.com/datasets/gmbitz/all-auto-ru-09-09-2020

# %% [markdown]
# ## more to do
#
# check NA <= 5 () (new column)
# make new or used column
# electric - drop
#
# make t-sne plot new-used - is it differ?

# %% [markdown]
# ## checking datasets similarity

# %%
train_jane.shape, train_baseline.shape, test.shape
# Out:
# ((129988, 19), (89378, 19), (34686, 18))

# %%
train_jane[train_jane.columns.sort_values().tolist()].sample(3, random_state=42).T
# Out:
#                                                                 81629   \
# bodyType                                                    компактвэн
# brand                                                           TOYOTA
# color                                                            серый
# description           Надежный и проверенный автомобиль с пробегом ...
# engineDisplacement                                                 1.8
# enginePower                                                      147.0
# fuelType                                                        бензин
# mileage                                                       160861.0
# modelDate                                                       2009.0
# numberOfDoors                                                      5.0
# price                                                         649000.0
# productionDate                                                  2009.0
# vehicleTransmission                                           вариатор
# vendor                                                        JAPANESE
# Владельцы                                                          1.0
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                        передний
# Руль                                                             Левый
#
#                                                                 45094   \
# bodyType                                                 хэтчбек 5 дв.
# brand                                                           NISSAN
# color                                                          красный
# description          Только один день автомобили с пробегом с выгод...
# engineDisplacement                                                 1.6
# enginePower                                                      110.0
# fuelType                                                        бензин
# mileage                                                       107539.0
# modelDate                                                       2010.0
# numberOfDoors                                                      5.0
# price                                                         629815.0
# productionDate                                                  2011.0
# vehicleTransmission                                     автоматическая
# vendor                                                        JAPANESE
# Владельцы                                                          2.0
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                        передний
# Руль                                                             Левый
#
#                                                                 117876
# bodyType                                             внедорожник 5 дв.
# brand                                                       VOLKSWAGEN
# color                                                            белый
# description          Автомобиль с пробегом от официального дилера V...
# engineDisplacement                                                 2.0
# enginePower                                                      150.0
# fuelType                                                        дизель
# mileage                                                        31922.0
# modelDate                                                       2016.0
# numberOfDoors                                                      5.0
# price                                                        2298000.0
# productionDate                                                  2018.0
# vehicleTransmission                                   роботизированная
# vendor                                                        EUROPEAN
# Владельцы                                                          1.0
# Владение                                             3 года и 2 месяца
# ПТС                                                           Оригинал
# Привод                                                          полный
# Руль                                                             Левый

# %%
# train_baseline.rename(columns={"model": "model_name"}, inplace=True)
train_baseline[train_baseline.columns.sort_values().tolist()].sample(
    3, random_state=42
).T
# Out:
#                                                                  54772  \
# bodyType                                                    Компактвэн
# brand                                                             OPEL
# color                                                           040001
# description          Продам авто в хорошем состоянии без проблем вс...
# engineDisplacement                                                 1.8
# enginePower                                                      140.0
# fuelType                                                        бензин
# mileage                                                         177000
# modelDate                                                       2005.0
# numberOfDoors                                                      5.0
# price                                                         360000.0
# productionDate                                                    2008
# vehicleTransmission                                              ROBOT
# vendor                                                        EUROPEAN
# Владельцы                                                          2.0
# Владение                                    {'year': 2017, 'month': 6}
# ПТС                                                           ORIGINAL
# Привод                                                        передний
# Руль                                                              LEFT
#
#                                                                  73499  \
# bodyType                                                         Седан
# brand                                                       VOLKSWAGEN
# color                                                           FFD600
# description          Штрафы оплаченны !! На днях снимут с машины, н...
# engineDisplacement                                                 1.6
# enginePower                                                       90.0
# fuelType                                                        бензин
# mileage                                                         380000
# modelDate                                                       2014.0
# numberOfDoors                                                      4.0
# price                                                         340000.0
# productionDate                                                    2016
# vehicleTransmission                                         MECHANICAL
# vendor                                                        EUROPEAN
# Владельцы                                                          1.0
# Владение                                                           NaN
# ПТС                                                           ORIGINAL
# Привод                                                        передний
# Руль                                                              LEFT
#
#                                                                  74260
# bodyType                                                       Лифтбек
# brand                                                       VOLKSWAGEN
# color                                                           FAFBFB
# description          Фольксваген Центр Подольск готов сделать вам п...
# engineDisplacement                                                 1.6
# enginePower                                                       90.0
# fuelType                                                        бензин
# mileage                                                              0
# modelDate                                                       2020.0
# numberOfDoors                                                      5.0
# price                                                         821900.0
# productionDate                                                    2020
# vehicleTransmission                                         MECHANICAL
# vendor                                                        EUROPEAN
# Владельцы                                                          NaN
# Владение                                                           NaN
# ПТС                                                           ORIGINAL
# Привод                                                        передний
# Руль                                                              LEFT

# %%
test[test.columns.sort_values().tolist()].sample(3, random_state=42).T
# Out:
#                                                                  19026  \
# bodyType                                             внедорожник 5 дв.
# brand                                                           TOYOTA
# color                                                           чёрный
# description          ЛОТ: 01215604\nФаворит Хофф\n\nВы можете получ...
# engineDisplacement                                                 2.0
# enginePower                                                        150
# fuelType                                                        бензин
# mileage                                                         121490
# modelDate                                                         2000
# numberOfDoors                                                        5
# productionDate                                                    2001
# vehicleTransmission                                     автоматическая
# vendor                                                        JAPANESE
# Владельцы                                                            3
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                          полный
# Руль                                                             Левый
#
#                                                                  3337   \
# bodyType                                                         седан
# brand                                                             AUDI
# color                                                            синий
# description          Авто в идеальном состоянии проблем нет смотрит...
# engineDisplacement                                                 1.8
# enginePower                                                        125
# fuelType                                                        бензин
# mileage                                                         240000
# modelDate                                                         1994
# numberOfDoors                                                        4
# productionDate                                                    1997
# vehicleTransmission                                       механическая
# vendor                                                        EUROPEAN
# Владельцы                                                            2
# Владение                                             1 год и 5 месяцев
# ПТС                                                           Оригинал
# Привод                                                        передний
# Руль                                                             Левый
#
#                                                                  11807
# bodyType                                             внедорожник 5 дв.
# brand                                                           NISSAN
# color                                                            белый
# description          Комфорт: 6. Безопасность: 4. Обзор: 2. Салон: 2.
# engineDisplacement                                                 2.0
# enginePower                                                        141
# fuelType                                                        бензин
# mileage                                                         104842
# modelDate                                                         2010
# numberOfDoors                                                        5
# productionDate                                                    2014
# vehicleTransmission                                           вариатор
# vendor                                                        JAPANESE
# Владельцы                                                            2
# Владение                                                           NaN
# ПТС                                                           Оригинал
# Привод                                                          полный
# Руль                                                             Левый

# %% [markdown]
# ## comments on further train_baseline processing
#
# - [ ] bodyType - no doors specified
# - [ ] color - hexified
# - [ ] model_name - more standartified
# - [ ] productionDate - different dtype
# - [x] Владение - to convert to number of days
# - [ ] vehicleTransmission - to standartize naming
# - [ ] ПТС - to standartize naming
# - [ ] Руль - to standartize naming

# %% [markdown]
# ## merging train datasets

# %%
train_jane['sample'] = 1
train_baseline['sample'] = 2
train = pd.concat([train_jane, train_baseline])
train["modelDate"] = train["modelDate"].astype("float32")
train["numberOfDoors"] = train["numberOfDoors"].astype("float32")
train["productionDate"] = train["productionDate"].astype("float32")
train["Владельцы"] = train["Владельцы"].astype("float32")

# %%
train["Владение"] = train["Владение"].apply(parse_ownership_duration)
test["Владение"] = test["Владение"].apply(parse_ownership_duration)

# %%
train["Владение"].value_counts().head(5)
# Out:
# 1155.0    646
# 2555.0    634
# 730.0     623
# 3650.0    603
# 365.0     525
# Name: Владение, dtype: int64

# %% [markdown]
# ## ------------------------

# %%
train.drop_duplicates(inplace=True)
train.dropna(subset=['price'], inplace = True)

# %% [markdown]
# ### processing body type

# %%
train['bodyType'] = train['bodyType'].str.replace('-', ' ')
train['bodyType'] = train['bodyType'].str.lower()

# %%
test['bodyType'] = test['bodyType'].str.replace('-', ' ')
test['bodyType'] = test['bodyType'].apply(lambda x: x.split()[0] if not pd.isna(x) else x)

# %%
train['bodyType'] = train['bodyType'].apply(lambda x: x.split()[0] if not pd.isna(x) else x)
train.bodyType.value_counts()
# Out:
# внедорожник    48273
# седан          40795
# хэтчбек        12625
# лифтбек         6089
# универсал       4502
# минивэн         2990
# компактвэн      2554
# купе            2103
# пикап            803
# кабриолет        242
# родстер          194
# фургон           175
# микровэн          54
# тарга              9
# лимузин            7
# фастбек            3
# Name: bodyType, dtype: int64

# %% [markdown]
# ### processing vehicleTransmission column to standart naming

# %%
transmission_dict = {
    'роботизированная': 'ROBOT',
    'автоматическая': 'AUTOMATIC',
    'механическая': 'MECHANICAL',
    'вариатор': 'VARIATOR'
}

# %%
test['vehicleTransmission'] = test['vehicleTransmission'].replace(transmission_dict)
train['vehicleTransmission'] = train['vehicleTransmission'].replace(transmission_dict)

# %%
train['vehicleTransmission'].value_counts(dropna=False)
# Out:
# AUTOMATIC     67906
# MECHANICAL    30233
# ROBOT         11910
# VARIATOR      11369
# NaN               2
# Name: vehicleTransmission, dtype: int64

# %%
test['vehicleTransmission'].value_counts(dropna=False)
# Out:
# AUTOMATIC     19596
# MECHANICAL     7209
# VARIATOR       3999
# ROBOT          3882
# Name: vehicleTransmission, dtype: int64

# %% [markdown]
# #### BodyType column #1 - a lot of cats

# %%
# train['bodyType'] = train['bodyType'].apply(get_bodytype)

# %% [markdown]
# #### BodyType column #2 - only main types - few cats

# %%
train['bodyType'] = train['bodyType'].apply(lambda x: x.split()[0] if not pd.isna(x) else x)

# %% [markdown]
# #### Model Name standardization

# %%
train["color"].replace(colors_dict, inplace=True)

# %%
train.color.unique()
# Out:
# array(['белый', 'синий', 'серый', 'чёрный', 'бежевый', 'серебристый',
#        'красный', 'коричневый', 'оранжевый', 'пурпурный', 'жёлтый',
#        'зелёный', 'голубой', 'фиолетовый', 'золотистый', 'розовый'],
#       dtype=object)

# %% [markdown]
# ### Description section

# %% [markdown]
# #### Lowering all text

# %%
train['description'] = train['description'].str.lower()

# %% [markdown]
# #### Cleaning from all except letters and digits

# %%
r = re.compile('[\W_]+')
train['description'].apply(lambda x: r.sub(' ', x) if not pd.isna(x) else x)
# Out:
# 0        автомобиль приобретался у официального дилера ...
# 1        группа компаний элан моторс официальный дилер ...
# 2        специальные предложения на автомобили в наличи...
# 3         купим ваш автомобиль дорого гарантированная с...
# 4        лот 01267595 скидка на автомобиль при покупке ...
#                                ...
# 89373    светит крутит работает всё без торга в москву ...
# 89374    автомобиль на ходу каждый день в движении с мо...
# 89375    автомобиль куплен в декабре 2015 г новым всё ч...
# 89376    продаю семейного любимца большой вместительный...
# 89377    авто в отличном состоянии всё работает большой...
# Name: description, Length: 121420, dtype: object

# %% [markdown]
# ## ПТС и Руль

# %%
train["ПТС"].replace({"ORIGINAL":"Оригинал", "DUPLICATE":"Дубликат"}, inplace=True)

# %%
train["Руль"].replace({"LEFT":"Левый", "RIGHT":"Правый"}, inplace=True)

# %% [markdown]
# ## writing to files

# %%
train.to_pickle("data/2022-03-30_train_preprocessed.pkl.zip", compression="zip")
test.to_pickle("data/2022-03-30_test_preprocessed.pkl.zip", compression="zip")

# %%
for c in train.columns:
    print(c, train[c].unique())
# Out:
# bodyType ['лифтбек' 'внедорожник' 'компактвэн' 'хэтчбек' 'универсал' 'седан' 'купе'
#  'кабриолет' 'родстер' 'минивэн' 'микровэн' 'пикап' nan 'фургон' 'лимузин'
#  'тарга' 'фастбек']
# brand ['SKODA' 'AUDI' 'HONDA' 'VOLVO' 'BMW' 'NISSAN' 'INFINITI' 'MERCEDES'
#  'TOYOTA' 'LEXUS' 'VOLKSWAGEN' 'MITSUBISHI' 'CADILLAC' 'CHERY' 'CHEVROLET'
#  'CHRYSLER' 'CITROEN' 'DAEWOO' 'DODGE' 'FORD' 'GEELY' 'HYUNDAI' 'JAGUAR'
#  'JEEP' 'KIA' 'MAZDA' 'MINI' 'OPEL' 'PEUGEOT' 'PORSCHE' 'RENAULT' 'SUBARU'
#  'SUZUKI' 'GREAT_WALL' 'LAND_ROVER' 'SSANG_YONG']
# color ['белый' 'синий' 'серый' 'чёрный' 'бежевый' 'серебристый' 'красный'
#  'коричневый' 'оранжевый' 'пурпурный' 'жёлтый' 'зелёный' 'голубой'
#  'фиолетовый' 'золотистый' 'розовый']
# description ['автомобиль приобретался у официального дилера оригинальный птс дополнительные опции обогрев всех сидений биксеноновая головная оптика датчики дождя и света двухзонный климат контроль круиз контроль передние и задние датчики парковки дополнительное оборудование сигнализация с автозапуском 007944 кредит от 8 первоначальный взнос от 0 более 20 банков партнеров ваш автомобиль может быть первоначальным взносом оформление за 30 минут по двум документам без справок и поручителей без скрытых платежей и комиссий возможна дистанционная подача заявки на кредит iobgogf 45095 '
#  'группа компаний элан моторс официальный дилер представляет на автомобильном рынке санкт петербурга и северо западного федерального округа бренды chery haval lifan zotye dfm jac motors уаз кредит 7 9 годовых ниже потребительского кредита на данный автомобиль действует скидка при покупке в кредит в нашем автоцентре вы можете воспользоваться одной из нескольких выгодных программ автокредитования от банков партнеров кредит предоставляется банком партнером взнос от 0 сроком до 7 лет валюта кредита рубли сумма кредита до 3 х млн руб документы необходимые для рассмотрения паспорт и водительское удостоверение или любой другой документ при обмене вашего автомобиля по программе trade in в нашем автоцентре предоставляется дополнительная скидка уникальная расширенная гарантия до 2 лет на двигатель и кпп более подробную информацию вы можете получить в отделе продаж или по телефону ждём вас по адресу г санкт петербург выборгское ш 27'
