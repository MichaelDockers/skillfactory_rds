# %% [markdown]
# ## imports

# %%
from warnings import filterwarnings

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler, LabelEncoder
from pycaret.regression import *

sns.set()
filterwarnings("ignore")

# %% [markdown]
# ## pre-saved data loading

# %%
train_raw = pd.read_parquet("https://github.com/XelorR/sf_project_6/raw/master/data/2022-04-08_train_pre-model.parquet")
test_raw = pd.read_parquet("https://github.com/XelorR/sf_project_6/raw/master/data/2022-04-08_test_pre-model.parquet")

train_raw.shape, test_raw.shape
# Out:
# ((115367, 30), (34686, 28))

# %% [markdown]
# ## pre-preprocessing

# %%
train_raw["train/test"] = "train"
test_raw["train/test"] = "test"

data = train_raw.append(test_raw)
data["ptc"].fillna("Оригинал", inplace=True)
data[data.select_dtypes("object").columns.tolist()] = data[data.select_dtypes("object").columns.tolist()].astype(str)

train = data.loc[data["train/test"] == "train"].drop(columns=["sample", "description", "train/test"])
test = data.loc[data["train/test"] == "test"].drop(columns=["sample", "description", "train/test", "price"])

# %% [markdown]
# ## preprocessing

# %%
s = setup(
    data = train,
    target="price",
    date_features=["parsed_date"],
    high_cardinality_features = ["model_name"], 
    normalize=True,
    transformation=True,
    remove_outliers = True,
    handle_unknown_categorical = True,
    remove_multicollinearity = True,
    # preprocess = False,
    # categorical_imputation = "mode",
    # imputation_type="iterative",
    # numeric_iterative_imputer = "catboost",
    # categorical_iterative_imputer = "catboost",
    # feature_selection=True,
    # feature_selection_threshold = 0.5,
    combine_rare_levels = True,
)
# Out:
# <style type="text/css">
# #T_f0c02_row7_col1, #T_f0c02_row27_col1, #T_f0c02_row29_col1, #T_f0c02_row35_col1, #T_f0c02_row38_col1, #T_f0c02_row40_col1, #T_f0c02_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f0c02_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0c02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f0c02_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f0c02_row0_col1" class="data row0 col1" >3213</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f0c02_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f0c02_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f0c02_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_f0c02_row2_col1" class="data row2 col1" >(115367, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f0c02_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_f0c02_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f0c02_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_f0c02_row4_col1" class="data row4 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f0c02_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_f0c02_row5_col1" class="data row5 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f0c02_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_f0c02_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f0c02_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_f0c02_row7_col1" class="data row7 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f0c02_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_f0c02_row8_col1" class="data row8 col1" >frequency</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f0c02_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_f0c02_row9_col1" class="data row9 col1" >(76718, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f0c02_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_f0c02_row10_col1" class="data row10 col1" >(34611, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f0c02_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_f0c02_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f0c02_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_f0c02_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f0c02_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_f0c02_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f0c02_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_f0c02_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f0c02_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_f0c02_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f0c02_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_f0c02_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f0c02_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_f0c02_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f0c02_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_f0c02_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f0c02_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_f0c02_row19_col1" class="data row19 col1" >493c</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f0c02_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_f0c02_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f0c02_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_f0c02_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f0c02_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_f0c02_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f0c02_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_f0c02_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f0c02_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_f0c02_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_f0c02_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_f0c02_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_f0c02_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_f0c02_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_f0c02_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_f0c02_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_f0c02_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_f0c02_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_f0c02_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_f0c02_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f0c02_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_f0c02_row30_col0" class="d

# %% [markdown]
# ## saving preprocessed datasets for future

# %%
train_encoded = get_config("X")
train_encoded["price"] = get_config("y")

prep_pipe = get_config("prep_pipe")
test_encoded = prep_pipe.transform(test)

train_encoded.shape, test_encoded.shape
# Out:
# ((115367, 90), (34686, 89))

# %%
train_encoded.to_parquet("data/2022-04-11_train_encoded_full.parquet")
test_encoded.to_parquet("data/2022-04-11_test_encoded_full.parquet")

# %% [markdown]
# ## comparing models

# %%
best = compare_models(exclude=["dummy", "ada"], n_select=7)
# Out:
# <style type="text/css">
# #T_6611b_ th {
#   text-align: left;
# }
# #T_6611b_row0_col0, #T_6611b_row0_col1, #T_6611b_row0_col5, #T_6611b_row0_col6, #T_6611b_row1_col0, #T_6611b_row1_col2, #T_6611b_row1_col3, #T_6611b_row1_col4, #T_6611b_row1_col5, #T_6611b_row1_col6, #T_6611b_row2_col0, #T_6611b_row2_col1, #T_6611b_row2_col2, #T_6611b_row2_col3, #T_6611b_row2_col4, #T_6611b_row2_col5, #T_6611b_row2_col6, #T_6611b_row3_col0, #T_6611b_row3_col1, #T_6611b_row3_col2, #T_6611b_row3_col3, #T_6611b_row3_col4, #T_6611b_row4_col0, #T_6611b_row4_col1, #T_6611b_row4_col2, #T_6611b_row4_col3, #T_6611b_row4_col4, #T_6611b_row4_col5, #T_6611b_row4_col6, #T_6611b_row5_col0, #T_6611b_row5_col1, #T_6611b_row5_col2, #T_6611b_row5_col3, #T_6611b_row5_col4, #T_6611b_row5_col5, #T_6611b_row5_col6, #T_6611b_row6_col0, #T_6611b_row6_col1, #T_6611b_row6_col2, #T_6611b_row6_col3, #T_6611b_row6_col4, #T_6611b_row6_col5, #T_6611b_row6_col6, #T_6611b_row7_col0, #T_6611b_row7_col1, #T_6611b_row7_col2, #T_6611b_row7_col3, #T_6611b_row7_col4, #T_6611b_row7_col5, #T_6611b_row7_col6, #T_6611b_row8_col0, #T_6611b_row8_col1, #T_6611b_row8_col2, #T_6611b_row8_col3, #T_6611b_row8_col4, #T_6611b_row8_col5, #T_6611b_row8_col6, #T_6611b_row9_col0, #T_6611b_row9_col1, #T_6611b_row9_col2, #T_6611b_row9_col3, #T_6611b_row9_col4, #T_6611b_row9_col5, #T_6611b_row9_col6, #T_6611b_row10_col0, #T_6611b_row10_col1, #T_6611b_row10_col2, #T_6611b_row10_col3, #T_6611b_row10_col4, #T_6611b_row10_col5, #T_6611b_row10_col6, #T_6611b_row11_col0, #T_6611b_row11_col1, #T_6611b_row11_col2, #T_6611b_row11_col3, #T_6611b_row11_col4, #T_6611b_row11_col5, #T_6611b_row11_col6, #T_6611b_row12_col0, #T_6611b_row12_col1, #T_6611b_row12_col2, #T_6611b_row12_col3, #T_6611b_row12_col4, #T_6611b_row12_col5, #T_6611b_row12_col6, #T_6611b_row13_col0, #T_6611b_row13_col1, #T_6611b_row13_col2, #T_6611b_row13_col3, #T_6611b_row13_col4, #T_6611b_row13_col5, #T_6611b_row13_col6, #T_6611b_row14_col0, #T_6611b_row14_col1, #T_6611b_row14_col2, #T_6611b_row14_col3, #T_6611b_row14_col4, #T_6611b_row14_col5, #T_6611b_row14_col6, #T_6611b_row15_col0, #T_6611b_row15_col1, #T_6611b_row15_col2, #T_6611b_row15_col3, #T_6611b_row15_col4, #T_6611b_row15_col5, #T_6611b_row15_col6, #T_6611b_row16_col0, #T_6611b_row16_col1, #T_6611b_row16_col2, #T_6611b_row16_col3, #T_6611b_row16_col4, #T_6611b_row16_col5, #T_6611b_row16_col6 {
#   text-align: left;
# }
# #T_6611b_row0_col2, #T_6611b_row0_col3, #T_6611b_row0_col4, #T_6611b_row1_col1, #T_6611b_row3_col5, #T_6611b_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6611b_row0_col7, #T_6611b_row1_col7, #T_6611b_row2_col7, #T_6611b_row3_col7, #T_6611b_row4_col7, #T_6611b_row5_col7, #T_6611b_row6_col7, #T_6611b_row7_col7, #T_6611b_row8_col7, #T_6611b_row10_col7, #T_6611b_row11_col7, #T_6611b_row12_col7, #T_6611b_row13_col7, #T_6611b_row14_col7, #T_6611b_row15_col7, #T_6611b_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6611b_row9_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6611b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6611b_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_6611b_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_6611b_row0_col1" class="data row0 col1" >154520.9054</td>
#       <td id="T_6611b_row0_col2" class="data row0 col2" >195083135484.4420</td>
#       <td id="T_6611b_row0_col3" class="data row0 col3" >418959.1588</td>
#       <td id="T_6611b_row0_col4" class="data row0 col4" >0.9481</td>
#       <td id="T_6611b_row0_col5" class="data row0 col5" >0.2278</td>
#       <td id="T_6611b_row0_col6" class="data row0 col6" >0.1605</td>
#       <td id="T_6611b_row0_col7" class="data row0 col7" >8.5590</td>
#     </tr>
#     <tr>
#       <th id="T_6611b_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_6611b_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_6611b_row1_col1" class="data row1 col1" >141823.8047</td>
#       <td id="T_6611b_row1_col2" class="data row1 col2" >204674463100.7356</td>
#       <td id="T_6611b_row1_col3" class="data row1 col3" >431128.3114</td>
#       <td id="T_6611b_row1_col4" class="data row1 col4" >0.9457</td>
#       <td id="T_6611b_row1_col5" class="data row1 col5" >0.2081</td>
#       <td id="T_6611b_row1_col6" class="data row1 col6" >0.1461</td>
#       <td id="T_6611b_row1_col7" class="data row1 col7" >53.9070</td>
#     </tr>
#     <tr>
#       <th id="T_6611b_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_6611b_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_6611b_row2_col1" class="data row2 col1" >160054.6781</td>
#       <td id="T_6611b_row2_col2" class="data row2 col2" >205508395008.0000</td>
#       <td id="T_6611b_row2_col3" class="data row2 col3" >431799.1062</td>
#       <td id="T_6611b_row2_col4" class="data row2 col4" >0.9452</td>
#       <td id="T_6611b_row2_col5" class="data row2 col5" >0.2396</td>
#       <td id="T_6611b_row2_col6" class="data row2 col6" >0.1660</td>
#       <td id="T_6611b_row2_col7" class="data row2 col7" >10.0720</td>
#     </tr>
#     <tr>
#       <th id="T_6611b_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_6611b_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_6611b_row3_col1" class="data row3 col1" >143688.3994</td>
#       <td id="T_6611b_row3_col2" class="data row3 col2" >220588339247.8722</td>
#       <td id="T_6611b_row3_col3" class="data row3 col3" >448960.6547</td>
#       <td id="T_6611b_row3_col4" class="data row3 col4" >0.9415</td>
#       <td id="T_6611b_row3_col5" class="data row3 col5" >0.2071</td>
#       <td id="T_6611b_row3_col6" class="data row3 col6" >0.1447</td>
#       <td id="T_6611b_row3_col7" class="data row3 col7" >40.7590</td>
#     </tr>
#     <tr>
#       <th id="T_6611b_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_6611b_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6611b_row4_col1" class="data row4 col1" >183881.0534</td>
#       <td id="T_6611b_row4_col2" class="data row4 col2" >229491187904.0496</td>
#       <td id="T_6611b_row4_col3" class="data row4 col3" >461453.6431</td>
#       <td id="T_6611b_row4_col4" class="data row4 col4" >0.9388</td>
#       <td id="T_6611b_row4_col5" class="data row4 col5" >0.2578</td>
#       <td id="T_6611b_row4_col6" class="data row4 col6" >0.1945</td>
#       <td id="T_6611b_row4_col7" class="data row4 col7" >0.7110</td>
#     </tr>
#     <tr>
#       <th id="T_6611b_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_6611b_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_6611b_row5_col1" class="data row5 col1" >251894.0976</td>
#       <td id="T_6611b_row5_col2" class="data row5 col2" >368420090885.7047</td>
#       <td id="T_6611b_row5_col3" class="data row5 col3" >596274.7162</td>
#       <td id="T_6611b_row5_col4" class="data row5 col4" >0.9008</td>
#       <td id="T_6611b_row5_col5" class="data row5 col5" >0.3496</td>
#       <td id="T_6611b_row5_col6" class="data row5 col6" >0.2693</td>
#       <td id="T_6611b_row5_col7" class="data row5 col7" >12.3730</td>
#     </tr>
#     <tr>
#       <th id="T_6611b_level0_row6" class="row_heading level0 row6" >knn</th>
#       <td id="T_6611b_row6_col0" class="data row6 col0" >K Neighbors Regressor</td>
#       <td id="T_6611b_row6_col1" class="data row6 col1" >214915.6000</td>
#       <td id="T_661

# %% [markdown]
# ## prediction - first try

# %%
predictions = predict_model(best[0], data = test)

# %%
submission = pd.read_csv("data/sample_submission.csv")
submission["price"] = predictions["Label"]
submission.to_csv("submission.csv", index=False)

# %% [markdown]
# ## saving models and variables

# %%
save_config("models/2022-04-11_config")
save_model(best, "models/2022-04-11_model")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='price',
#                                        time_features=['parsed_date'])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numer...
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100,
#                                              n_iter_no_change=None,
#                                              presort='deprecated',
#                                              random_state=3213, subsample=1.0,
#                                              tol=0.0001, validation_fraction=0.1,
#                                              verbose=0, warm_start=False),
#                    KNeighborsRegressor(algorithm='auto', leaf_size=30,
#                                        metric='minkowski', metric_params=None,
#                                        n_jobs=-1, n_neighbors=5, p=2,
#                                        weights='uniform')]]],
#           verbose=False),
#  'models/2022-04-11_model.pkl')

# %% [markdown]
# ## creating models

# %%
catboost = create_model("catboost", fold=8)
rf = create_model("rf", fold=8)
knn = create_model("knn", fold=8)
# Out:
# <style type="text/css">
# #T_c539e_row8_col0, #T_c539e_row8_col1, #T_c539e_row8_col2, #T_c539e_row8_col3, #T_c539e_row8_col4, #T_c539e_row8_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c539e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c539e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c539e_row0_col0" class="data row0 col0" >157332.8126</td>
#       <td id="T_c539e_row0_col1" class="data row0 col1" >571484708730.0208</td>
#       <td id="T_c539e_row0_col2" class="data row0 col2" >755966.0764</td>
#       <td id="T_c539e_row0_col3" class="data row0 col3" >0.8540</td>
#       <td id="T_c539e_row0_col4" class="data row0 col4" >0.2299</td>
#       <td id="T_c539e_row0_col5" class="data row0 col5" >0.1596</td>
#     </tr>
#     <tr>
#       <th id="T_c539e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c539e_row1_col0" class="data row1 col0" >153244.9817</td>
#       <td id="T_c539e_row1_col1" class="data row1 col1" >131571212306.1318</td>
#       <td id="T_c539e_row1_col2" class="data row1 col2" >362727.4629</td>
#       <td id="T_c539e_row1_col3" class="data row1 col3" >0.9618</td>
#       <td id="T_c539e_row1_col4" class="data row1 col4" >0.2254</td>
#       <td id="T_c539e_row1_col5" class="data row1 col5" >0.1609</td>
#     </tr>
#     <tr>
#       <th id="T_c539e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c539e_row2_col0" class="data row2 col0" >153938.8423</td>
#       <td id="T_c539e_row2_col1" class="data row2 col1" >139421391944.1100</td>
#       <td id="T_c539e_row2_col2" class="data row2 col2" >373391.7406</td>
#       <td id="T_c539e_row2_col3" class="data row2 col3" >0.9647</td>
#       <td id="T_c539e_row2_col4" class="data row2 col4" >0.2331</td>
#       <td id="T_c539e_row2_col5" class="data row2 col5" >0.1628</td>
#     </tr>
#     <tr>
#       <th id="T_c539e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c539e_row3_col0" class="data row3 col0" >157277.0730</td>
#       <td id="T_c539e_row3_col1" class="data row3 col1" >190313576764.3681</td>
#       <td id="T_c539e_row3_col2" class="data row3 col2" >436249.4433</td>
#       <td id="T_c539e_row3_col3" class="data row3 col3" >0.9456</td>
#       <td id="T_c539e_row3_col4" class="data row3 col4" >0.2307</td>
#       <td id="T_c539e_row3_col5" class="data row3 col5" >0.1632</td>
#     </tr>
#     <tr>
#       <th id="T_c539e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c539e_row4_col0" class="data row4 col0" >161978.6365</td>
#       <td id="T_c539e_row4_col1" class="data row4 col1" >226046641963.5348</td>
#       <td id="T_c539e_row4_col2" class="data row4 col2" >475443.6265</td>
#       <td id="T_c539e_row4_col3" class="data row4 col3" >0.9413</td>
#       <td id="T_c539e_row4_col4" class="data row4 col4" >0.2353</td>
#       <td id="T_c539e_row4_col5" class="data row4 col5" >0.1647</td>
#     </tr>
#     <tr>
#       <th id="T_c539e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c539e_row5_col0" class="data row5 col0" >153782.0250</td>
#       <td id="T_c539e_row5_col1" class="data row5 col1" >144470610835.1919</td>
#       <td id="T_c539e_row5_col2" class="data row5 col2" >380092.8976</td>
#       <td id="T_c539e_row5_col3" class="data row5 col3" >0.9609</td>
#       <td id="T_c539e_row5_col4" class="data row5 col4" >0.2183</td>
#       <td id="T_c539e_row5_col5" class="data row5 col5" >0.1560</td>
#     </tr>
#     <tr>
#       <th id="T_c539e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c539e_row6_col0" class="data row6 col0" >154578.8670</td>
#       <td id="T_c539e_row6_col1" class="data row6 col1" >129693485511.0100</td>
#       <td id="T_c539e_row6_col2" class="data row6 col2" >360129.8176</td>
#       <td id="T_c539e_row6_col3" class="data row6 col3" >0.9622</td>
#       <td id="T_c539e_row6_col4" class="data row6 col4" >0.2298</td>
#       <td id="T_c539e_row6_col5" class="data row6 col5" >0.1629</td>
#     </tr>
#     <tr>
#       <th id="T_c539e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c539e_row7_col0" class="data row7 col0" >153136.1506</td>
#       <td id="T_c539e_row7_col1" class="data row7 col1" >112601400680.9762</td>
#       <td id="T_c539e_row7_col2" class="data row7 col2" >335561.3218</td>
#       <td id="T_c539e_row7_col3" class="data row7 col3" >0.9687</td>
#       <td id="T_c539e_row7_col4" class="data row7 col4" >0.2258</td>
#       <td id="T_c539e_row7_col5" class="data row7 col5" >0.1600</td>
#     </tr>
#     <tr>
#       <th id="T_c539e_level0_row8" class="row_heading level0 row8" >Mean</th>
#       <td id="T_c539e_row8_col0" class="data row8 col0" >155658.6736</td>
#       <td id="T_c539e_row8_col1" class="data row8 col1" >205700378591.9180</td>
#       <td id="T_c539e_row8_col2" class="data row8 col2" >434945.2983</td>
#       <td id="T_c539e_row8_col3" class="data row8 col3" >0.9449</td>
#       <td id="T_c539e_row8_col4" class="data row8 col4" >0.2285</td>
#       <td id="T_c539e_row8_col5" class="data row8 col5" >0.1613</td>
#     </tr>
#     <tr>
#       <th id="T_c539e_level0_row9" class="row_heading level0 row9" >Std</th>
#       <td id="T_c539e_row9_col0" class="data row9 col0" >2854.7883</td>
#       <td id="T_c539e_row9_col1" class="data row9 col1" >142535298078.6476</td>
#       <td id="T_c539e_row9_col2" class="data row9 col2" >128541.6899</td>
#       <td id="T_c539e_row9_col3" class="data row9 col3" >0.0355</td>
#       <td id="T_c539e_row9_col4" class="data row9 col4" >0.0050</td>
#       <td id="T_c539e_row9_col5" class="data row9 col5" >0.0026</td>
#     </tr>
#   </tbody>
# </table>
# IntProgress(value=0, description='Processing: ', max=4)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                 21:38:23
# Status     . . . . . . . . . . . . . . . . . .          Fitting 8 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Regressor
# Empty DataFrame
# Columns: [Fold, MAE, MSE, RMSE, R2, RMSLE, MAPE]
# Index: []

# %%
tuned_rf = tune_model(rf)
tuned_knn = tune_model(knn)
