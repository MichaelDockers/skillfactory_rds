# %% [markdown]
# ## imports

# %%
import warnings

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("data/count_by_model_and_region.csv").sort_values(["count"], ascending=False)
df
# Out:
#          model                 region  count
# 19    mercedes     moskovskaya_oblast   4918
# 16         bmw     moskovskaya_oblast   4886
# 22  volkswagen     moskovskaya_oblast   3622
# 20      toyota     moskovskaya_oblast   2795
# 17      nissan     moskovskaya_oblast   2716
# 13        audi     moskovskaya_oblast   2457
# 12       skoda     moskovskaya_oblast   2277
# 23  mitsubishi     moskovskaya_oblast   1401
# 4          bmw  leningradskaya_oblast   1322
# 7     mercedes  leningradskaya_oblast   1269
# 10  volkswagen  leningradskaya_oblast   1242
# 15       volvo     moskovskaya_oblast    985
# 0        skoda  leningradskaya_oblast    817
# 8       toyota  leningradskaya_oblast    774
# 1         audi  leningradskaya_oblast    769
# 21       lexus     moskovskaya_oblast    765
# 5       nissan  leningradskaya_oblast    720
# 14       honda     moskovskaya_oblast    680
# 11  mitsubishi  leningradskaya_oblast    575
# 18    infiniti     moskovskaya_oblast    554
# ...

# %%
plt.figure(figsize=(8, 16))
sns.barplot(data=df, y="model", x="count", hue="region")
plt.show()

# %% [markdown]
# ## conclusion
#
# To parse: all spb + msk < 800
