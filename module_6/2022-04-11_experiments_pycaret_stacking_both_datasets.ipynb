# %% [markdown]
# ## imports

# %%
from warnings import filterwarnings

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pycaret.regression import *

sns.set()
filterwarnings("ignore")

# %% [markdown]
# ## pre-saved data loading

# %%
train_raw = pd.read_parquet("https://github.com/XelorR/sf_project_6/raw/master/data/2022-04-08_train_pre-model.parquet")
test_raw = pd.read_parquet("https://github.com/XelorR/sf_project_6/raw/master/data/2022-04-08_test_pre-model.parquet")

train_raw.shape, test_raw.shape
# Out:
# ((115367, 30), (34686, 28))

# %% [markdown]
# ## pre-preprocessing

# %%
train_raw["train/test"] = "train"
test_raw["train/test"] = "test"

data = train_raw.append(test_raw)
data["ptc"].fillna("Оригинал", inplace=True)
data[data.select_dtypes("object").columns.tolist()] = data[data.select_dtypes("object").columns.tolist()].astype(str)

train = data.loc[data["train/test"] == "train"].drop(columns=["sample", "description", "train/test"])
test = data.loc[data["train/test"] == "test"].drop(columns=["sample", "description", "train/test", "price"])

# %% [markdown]
# ## preprocessing

# %%
s = setup(
    data = train,
    target="price",
    date_features=["parsed_date"],
    high_cardinality_features = ["model_name"], 
    normalize=True,
    transformation=True,
    remove_outliers = True,
    handle_unknown_categorical = True,
    remove_multicollinearity = True,
    # preprocess = False,
    # categorical_imputation = "mode",
    # imputation_type="iterative",
    # numeric_iterative_imputer = "catboost",
    # categorical_iterative_imputer = "catboost",
    # feature_selection=True,
    # feature_selection_threshold = 0.5,
    combine_rare_levels = True,
)
# Out:
# <style type="text/css">
# #T_b29f1_row7_col1, #T_b29f1_row27_col1, #T_b29f1_row29_col1, #T_b29f1_row35_col1, #T_b29f1_row38_col1, #T_b29f1_row40_col1, #T_b29f1_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b29f1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b29f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b29f1_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_b29f1_row0_col1" class="data row0 col1" >6413</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b29f1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b29f1_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b29f1_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_b29f1_row2_col1" class="data row2 col1" >(115367, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b29f1_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_b29f1_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b29f1_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_b29f1_row4_col1" class="data row4 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b29f1_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_b29f1_row5_col1" class="data row5 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b29f1_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_b29f1_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b29f1_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_b29f1_row7_col1" class="data row7 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b29f1_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_b29f1_row8_col1" class="data row8 col1" >frequency</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b29f1_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_b29f1_row9_col1" class="data row9 col1" >(76718, 90)</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b29f1_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_b29f1_row10_col1" class="data row10 col1" >(34611, 90)</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b29f1_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_b29f1_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b29f1_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_b29f1_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b29f1_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_b29f1_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b29f1_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_b29f1_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b29f1_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_b29f1_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b29f1_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_b29f1_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b29f1_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_b29f1_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b29f1_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_b29f1_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b29f1_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_b29f1_row19_col1" class="data row19 col1" >94bf</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b29f1_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_b29f1_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b29f1_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_b29f1_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_b29f1_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_b29f1_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_b29f1_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_b29f1_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_b29f1_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_b29f1_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_b29f1_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_b29f1_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_b29f1_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_b29f1_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_b29f1_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_b29f1_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_b29f1_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_b29f1_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_b29f1_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_b29f1_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b29f1_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_b29f1_row30_col0" class="d

# %% [markdown]
# ## creating models

# %%
catboost = create_model("catboost")
# Out:
# <style type="text/css">
# #T_4b586_row10_col0, #T_4b586_row10_col1, #T_4b586_row10_col2, #T_4b586_row10_col3, #T_4b586_row10_col4, #T_4b586_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4b586_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b586_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4
td>
#     </tr>
#     <tr>
#       <th id="T_4b586_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4b586_row8_col0" class="data row8 col0" >154417.6015</td>
#       <td id="T_4b586_row8_col1" class="data row8 col1" >152200688635.9000</td>
#       <td id="T_4b586_row8_col2" class="data row8 col2" >390129.0666</td>
#       <td id="T_4b586_row8_col3" class="data row8 col3" >0.9608</td>
#       <td id="T_4b586_row8_col4" class="data row8 col4" >0.2274</td>
#       <td id="T_4b586_row8_col5" class="data row8 col5" >0.1600</td>
#     </tr>
#     <tr>
#       <th id="T_4b586_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4b586_row9_col0" class="data row9 col0" >160853.7654</td>
#       <td id="T_4b586_row9_col1" class="data row9 col1" >243250478932.2458</td>
#       <td id="T_4b586_row9_col2" class="data row9 col2" >493204.2974</td>
#       <td id="T_4b586_row9_col3" class="data row9 col3" >0.9264</td>
#       <td id="T_4b586_row9_col4" class="data row9 col4" >0.2344</td>
#       <td id="T_4b586_row9_col5" class="data row9 col5" >0.1623</td>
#     </tr>
#     <tr>
#       <th id="T_4b586_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_4b586_row10_col0" class="data row10 col0" >154360.2913</td>
#       <td id="T_4b586_row10_col1" class="data row10 col1" >212268666840.4941</td>
#       <td id="T_4b586_row10_col2" class="data row10 col2" >437483.2035</td>
#       <td id="T_4b586_row10_col3" class="data row10 col3" >0.9411</td>
#       <td id="T_4b586_row10_col4" class="data row10 col4" >0.2296</td>
#       <td id="T_4b586_row10_col5" class="data row10 col5" >0.1601</td>
#     </tr>
#     <tr>
#       <th id="T_4b586_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_4b586_row11_col0" class="data row11 col0" >3220.4429</td>
#       <td id="T_4b586_row11_col1" class="data row11 col1" >171076474827.5880</td>
#       <td id="T_4b586_row11_col2" class="data row11 col2" >144489.1468</td>
#       <td id="T_4b586_row11_col3" class="data row11 col3" >0.0448</td>
#       <td id="T_4b586_row11_col4" class="data row11 col4" >0.0044</td>
#       <td id="T_4b586_row11_col5" class="data row11 col5" >0.0030</td>
#     </tr>
#   </tbody>
# </table>

# %%
lightgbm = create_model("lightgbm")
# Out:
# <style type="text/css">
# #T_fc646_row10_col0, #T_fc646_row10_col1, #T_fc646_row10_col2, #T_fc646_row10_col3, #T_fc646_row10_col4, #T_fc646_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_fc646_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc646_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc646_row0_col0" class="data row0 col0" >177319.9655</td>
#       <td id="T_fc646_row0_col1" class="data row0 col1" >143723849993.4290</td>
#       <td id="T_fc646_row0_col2" class="data row0 col2" >379109.2850</td>
#       <td id="T_fc646_row0_col3" class="data row0 col3" >0.9538</td>
#       <td id="T_fc646_row0_col4" class="data row0 col4" >0.2512</td>
#       <td id="T_fc646_row0_col5" class="data row0 col5" >0.1908</td>
#     </tr>
#     <tr>
#       <th id="T_fc646_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fc646_row1_col0" class="data row1 col0" >185158.7029</td>
#       <td id="T_fc646_row1_col1" class="data row1 col1" >193465157867.7304</td>
#       <td id="T_fc646_row1_col2" class="data row1 col2" >439846.7436</td>
#       <td id="T_fc646_row1_col3" class="data row1 col3" >0.9457</td>
#       <td id="T_fc646_row1_col4" class="data row1 col4" >0.2640</td>
#       <td id="T_fc646_row1_col5" class="data row1 col5" >0.2005</td>
#     </tr>
#     <tr>
#       <th id="T_fc646_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f
td>
#     </tr>
#     <tr>
#       <th id="T_fc646_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fc646_row9_col0" class="data row9 col0" >184968.7149</td>
#       <td id="T_fc646_row9_col1" class="data row9 col1" >243992456442.4710</td>
#       <td id="T_fc646_row9_col2" class="data row9 col2" >493955.9256</td>
#       <td id="T_fc646_row9_col3" class="data row9 col3" >0.9261</td>
#       <td id="T_fc646_row9_col4" class="data row9 col4" >0.2588</td>
#       <td id="T_fc646_row9_col5" class="data row9 col5" >0.1905</td>
#     </tr>
#     <tr>
#       <th id="T_fc646_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_fc646_row10_col0" class="data row10 col0" >180589.0058</td>
#       <td id="T_fc646_row10_col1" class="data row10 col1" >238296286413.6540</td>
#       <td id="T_fc646_row10_col2" class="data row10 col2" >467224.0144</td>
#       <td id="T_fc646_row10_col3" class="data row10 col3" >0.9338</td>
#       <td id="T_fc646_row10_col4" class="data row10 col4" >0.2539</td>
#       <td id="T_fc646_row10_col5" class="data row10 col5" >0.1902</td>
#     </tr>
#     <tr>
#       <th id="T_fc646_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_fc646_row11_col0" class="data row11 col0" >3314.2022</td>
#       <td id="T_fc646_row11_col1" class="data row11 col1" >177456279486.3804</td>
#       <td id="T_fc646_row11_col2" class="data row11 col2" >141414.3090</td>
#       <td id="T_fc646_row11_col3" class="data row11 col3" >0.0462</td>
#       <td id="T_fc646_row11_col4" class="data row11 col4" >0.0053</td>
#       <td id="T_fc646_row11_col5" class="data row11 col5" >0.0047</td>
#     </tr>
#   </tbody>
# </table>

# %%
rf = create_model("rf")
# Out:
# <style type="text/css">
# #T_c94ae_row10_col0, #T_c94ae_row10_col1, #T_c94ae_row10_col2, #T_c94ae_row10_col3, #T_c94ae_row10_col4, #T_c94ae_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c94ae_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c94ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c94ae_row0_col0" class="data row0 col0" >142875.6250</td>
#       <td id="T_c94ae_row0_col1" class="data row0 col1" >134277716043.5105</td>
#       <td id="T_c94ae_row0_col2" class="data row0 col2" >366439.2392</td>
#       <td id="T_c94ae_row0_col3" class="data row0 col3" >0.9569</td>
#       <td id="T_c94ae_row0_col4" class="data row0 col4" >0.2058</td>
#       <td id="T_c94ae_row0_col5" class="data row0 col5" >0.1431</td>
#     </tr>
#     <tr>
#       <th id="T_c94ae_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c94ae_row1_col0" class="data row1 col0" >144960.4827</td>
#       <td id="T_c94ae_row1_col1" class="data row1 col1" >171992501188.4998</td>
#       <td id="T_c94ae_row1_col2" class="data row1 col2" >414719.7863</td>
#       <td id="T_c94ae_row1_col3" class="data row1 col3" >0.9518</td>
#       <td id="T_c94ae_row1_col4" class="data row1 col4" >0.2145</td>
#       <td id="T_c94ae_row1_col5" class="data row1 col5" >0.1480</td>
#     </tr>
#     <tr>
#       <th id="T_c94ae_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c94ae_row2_col0" class="data row2 col0" >137781.1552</td>
#       <td id="T_c94ae_row2_col1" class="data row2 col1" >130220308847.7251</td>
#       <td id="T_c94ae_row2_col2" class="data row2 col2" >360860.5116</td>
#       <td id="T_c94ae_row2_col3" class="data row2 col3" >0.9630</td>
#       <td id="T_c94ae_row2_col4" class="data row2 col4" >0.2068</td>
#       <td id="T_c94ae_row2_col5" class="data row2 col5" >0.1466</td>
#     </tr>
#     <tr>
#       <th id="T_c94ae_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c94ae_row3_col0" class="data row3 col0" >135558.7029</td>
#       <td id="T_c94ae_row3_col1" class="data row3 col1" >92740325921.3341</td>
#       <td id="T_c94ae_row3_col2" class="data row3 col2" >304532.9636</td>
#       <td id="T_c94ae_row3_col3" class="data row3 col3" >0.9695</td>
#       <td id="T_c94ae_row3_col4" class="data row3 col4" >0.2085</td>
#       <td id="T_c94ae_row3_col5" class="data row3 col5" >0.1480</td>
#     </tr>
#     <tr>
#       <th id="T_c94ae_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c94ae_row4_col0" class="data row4 col0" >139543.3919</td>
#       <td id="T_c94ae_row4_col1" class="data row4 col1" >137296527828.6858</td>
#       <td id="T_c94ae_row4_col2" class="data row4 col2" >370535.4610</td>
#       <td id="T_c94ae_row4_col3" class="data row4 col3" >0.9618</td>
#       <td id="T_c94ae_row4_col4" class="data row4 col4" >0.2010</td>
#       <td id="T_c94ae_row4_col5" class="data row4 col5" >0.1399</td>
#     </tr>
#     <tr>
#       <th id="T_c94ae_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c94ae_row5_col0" class="data row5 col0" >142227.4781</td>
#       <td id="T_c94ae_row5_col1" class="data row5 col1" >167450632028.7688</td>
#       <td id="T_c94ae_row5_col2" class="data row5 col2" >409207.3216</td>
#       <td id="T_c94ae_row5_col3" class="data row5 col3" >0.9579</td>
#       <td id="T_c94ae_row5_col4" class="data row5 col4" >0.2017</td>
#       <td id="T_c94ae_row5_col5" class="data row5 col5" >0.1377</td>
#     </tr>
#     <tr>
#       <th id="T_c94ae_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c94ae_row6_col0" class="data row6 col0" >147165.8160</td>
#       <td id="T_c94ae_row6_col1" class="data row6 col1" >715692401116.5433</td>
#       <td id="T_c94ae_row6_col2" class="data row6 col2" >845986.0526</td>
#       <td id="T_c94ae_row6_col3" class="data row6 col3" >0.8100</td>
#       <td id="T_c94ae_row6_col4" class="data row6 col4" >0.2093</td>
#       <td id="T_c94ae_row6_col5" class="data row6 col5" >0.1438</td>
#     </tr>
#     <tr>
#       <th id="T_c94ae_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c94ae_row7_col0" class="data row7 col0" >149803.4085</td>
#       <td id="T_c94ae_row7_col1" class="data row7 col1" >254819212697.8726</td>
#       <td id="T_c94ae_row7_col2" class="data row7 col2" >504796.2091</td>
#       <td id="T_c94ae_row7_col3" class="data row7 col3" >0.9327</td>
#       <td id="T_c94ae_row7_col4" class="data row7 col4" >0.2085</td>
#       <td id="T_c94ae_row7_col5" class="data row7 col5" >0.1441</td>
#     </tr>
#     <tr>
#       <th id="T_c94ae_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c94ae_row8_col0" class="data row8 col0" >140849.3264</td>
#       <td id="T_c94ae_row8_col1" class="data row8 col1" >149150138536.1176</td>
#       <td id="T_c94ae_row8_col2" class="data row8 col2" >386199.6097</td>
#       <td id="T_c94ae_row8_col3" class="data row8 col3" >0.9616</td>
#       <td id="T_c94ae_row8_col4" class="data row8 col4" >0.2083</td>
#       <td id="T_c94ae_row8_col5" class="data row8 col5" >0.1464</td>
#     </tr>
#     <tr>
#       <th id="T_c94ae_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c94ae_row9_col0" class="data row9 col0" >143074.2032</td>
#       <td id="T_c94ae_row9_col1" class="data row9 col1" >229690694502.8298</td>
#       <td id="T_c94ae_row9_col2" class="data row9 col2" >479260.5706</td>
#       <td id="T_c94ae_row9_col3" class="data row9 col3" >0.9305</td>
#       <td id="T_c94ae_row9_col4" class="data row9 col4" >0.2097</td>
#       <td id="T_c94ae_row9_col5" class="data row9 col5" >0.1449</td>
#     </tr>
#     <tr>
#       <th id="T_c94ae_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c94ae_row10_col0" class="data row10 col0" >142383.9590</td>
#       <td id="T_c94ae_row10_col1" class="data row10 col1" >218333045871.1888</td>
#       <td id="T_c94ae_row10_col2" class="data row10 col2" >444253.7725</td>
#       <td id="T_c94ae_row10_col3" class="data row10 col3" >0.9396</td>
#       <td id="T_c94ae_row10_col4" class="data row10 col4" >0.2074</td>
#       <td id="T_c94ae_row10_col5" class="data row10 col5" >0.1443</td>
#     </tr>
#     <tr>
#       <th id="T_c94ae_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c94ae_row11_col0" class="data row11 col0" >4043.3818</td>
#       <td id="T_c94ae_row11_col1" class="data row11 col1" >171906633684.8387</td>
#       <td id="T_c94ae_row11_col2" class="data row11 col2" >144815.8537</td>
#       <td id="T_c94ae_row11_col3" class="data row11 col3" >0.0449</td>
#       <td id="T_c94ae_row11_col4" class="data row11 col4" >0.0037</td>
#       <td id="T_c94ae_row11_col5" class="data row11 col5" >0.0032</td>
#     </tr>
#   </tbody>
# </table>

# %%
knn = create_model("knn")
# Out:
# <style type="text/css">
# #T_e4bf2_row10_col0, #T_e4bf2_row10_col1, #T_e4bf2_row10_col2, #T_e4bf2_row10_col3, #T_e4bf2_row10_col4, #T_e4bf2_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_e4bf2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4bf2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4bf2_row0_col0" class="data row0 col0" >210183.2188</td>
#       <td id="T_e4bf2_row0_col1" class="data row0 col1" >266336845824.0000</td>
#       <td id="T_e4bf2_row0_col2" class="data row0 col2" >516078.3438</td>
#       <td id="T_e4bf2_row0_col3" class="data row0 col3" >0.9144</td>
#       <td id="T_e4bf2_row0_col4" class="data row0 col4" >0.2577</td>
#       <td id="T_e4bf2_row0_col5" class="data row0 col5" >0.1925</td>
#     </tr>
#     <tr>
#       <th id="T_e4bf2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4bf2_row1_col0" class="data row1 col0" >216416.7969</td>
#       <td id="T_e4bf2_row1_col1" class="data row1 col1" >354883239936.0000</td>
#       <td id="T_e4bf2_row1_col2" class="data row1 col2" >595720.7500</td>
#       <td id="T_e4bf2_row1_col3" class="data row1 col3" >0.9005</td>
#       <td id="T_e4bf2_row1_col4" class="data row1 col4" >0.2689</td>
#       <td id="T_e4bf2_row1_col5" class="data row1 col5" >0.2027</td>
#     </tr>
#     <tr>
#       <th id="T_e4bf2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e4bf2_row2_col0" class="data row2 col0" >202568.6406</td>
#       <td id="T_e4bf2_row2_col1" class="data row2 col1" >219669954560.0000</td>
#       <td id="T_e4bf2_row2_col2" class="data row2 col2" >468689.6250</td>
#       <td id="T_e4bf2_row2_col3" class="data row2 col3" >0.9376</td>
#       <td id="T_e4bf2_row2_col4" class="data row2 col4" >0.2610</td>
#       <td id="T_e4bf2_row2_col5" class="data row2 col5" >0.1938</td>
#     </tr>
#     <tr>
#       <th id="T_e4bf2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e4bf2_row3_col0" class="data row3 col0" >208227.2812</td>
#       <td id="T_e4bf2_row3_col1" class="data row3 col1" >272442769408.0000</td>
#       <td id="T_e4bf2_row3_col2" class="data row3 col2" >521960.5000</td>
#       <td id="T_e4bf2_row3_col3" class="data row3 col3" >0.9103</td>
#       <td id="T_e4bf2_row3_col4" class="data row3 col4" >0.2579</td>
#       <td id="T_e4bf2_row3_col5" class="data row3 col5" >0.1948</td>
#     </tr>
#     <tr>
#       <th id="T_e4bf2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e4bf2_row4_col0" class="data row4 col0" >209045.3594</td>
#       <td id="T_e4bf2_row4_col1" class="data row4 col1" >257177436160.0000</td>
#       <td id="T_e4bf2_row4_col2" class="data row4 col2" >507126.6562</td>
#       <td id="T_e4bf2_row4_col3" class="data row4 col3" >0.9284</td>
#       <td id="T_e4bf2_row4_col4" class="data row4 col4" >0.2556</td>
#       <td id="T_e4bf2_row4_col5" class="data row4 col5" >0.1893</td>
#     </tr>
#     <tr>
#       <th id="T_e4bf2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e4bf2_row5_col0" class="data row5 col0" >215488.7812</td>
#       <td id="T_e4bf2_row5_col1" class="data row5 col1" >297429925888.0000</td>
#       <td id="T_e4bf2_row5_col2" class="data row5 col2" >545371.3750</td>
#       <td id="T_e4bf2_row5_col3" class="data row5 col3" >0.9253</td>
#       <td id="T_e4bf2_row5_col4" class="data row5 col4" >0.2620</td>
#       <td id="T_e4bf2_row5_col5" class="data row5 col5" >0.1929</td>
#     </tr>
#     <tr>
#       <th id="T_e4bf2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e4bf2_row6_col0" class="data row6 col0" >210604.9688</td>
#       <td id="T_e4bf2_row6_col1" class="data row6 col1" >832086671360.0000</td>
#       <td id="T_e4bf2_row6_col2" class="data row6 col2" >912187.8750</td>
#       <td id="T_e4bf2_row6_col3" class="data row6 col3" >0.7791</td>
#       <td id="T_e4bf2_row6_col4" class="data row6 col4" >0.2636</td>
#       <td id="T_e4bf2_row6_col5" class="data row6 col5" >0.1933</td>
#     </tr>
#     <tr>
#       <th id="T_e4bf2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e4bf2_row7_col0" class="data row7 col0" >214175.2188</td>
#       <td id="T_e4bf2_row7_col1" class="data row7 col1" >572843687936.0000</td>
#       <td id="T_e4bf2_row7_col2" class="data row7 col2" >756864.3750</td>
#       <td id="T_e4bf2_row7_col3" class="data row7 col3" >0.8487</td>
#       <td id="T_e4bf2_row7_col4" class="data row7 col4" >0.2601</td>
#       <td id="T_e4bf2_row7_col5" class="data row7 col5" >0.1915</td>
#     </tr>
#     <tr>
#       <th id="T_e4bf2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e4bf2_row8_col0" class="data row8 col0" >212325.2656</td>
#       <td id="T_e4bf2_row8_col1" class="data row8 col1" >313772998656.0000</td>
#       <td id="T_e4bf2_row8_col2" class="data row8 col2" >560154.4375</td>
#       <td id="T_e4bf2_row8_col3" class="data row8 col3" >0.9191</td>
#       <td id="T_e4bf2_row8_col4" class="data row8 col4" >0.2535</td>
#       <td id="T_e4bf2_row8_col5" class="data row8 col5" >0.1910</td>
#     </tr>
#     <tr>
#       <th id="T_e4bf2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e4bf2_row9_col0" class="data row9 col0" >213075.0469</td>
#       <td id="T_e4bf2_row9_col1" class="data row9 col1" >373914632192.0000</td>
#       <td id="T_e4bf2_row9_col2" class="data row9 col2" >611485.6250</td>
#       <td id="T_e4bf2_row9_col3" class="data row9 col3" >0.8868</td>
#       <td id="T_e4bf2_row9_col4" class="data row9 col4" >0.2638</td>
#       <td id="T_e4bf2_row9_col5" class="data row9 col5" >0.1966</td>
#     </tr>
#     <tr>
#       <th id="T_e4bf2_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e4bf2_row10_col0" class="data row10 col0" >211211.0578</td>
#       <td id="T_e4bf2_row10_col1" class="data row10 col1" >376055816192.0000</td>
#       <td id="T_e4bf2_row10_col2" class="data row10 col2" >599563.9562</td>
#       <td id="T_e4bf2_row10_col3" class="data row10 col3" >0.8950</td>
#       <td id="T_e4bf2_row10_col4" class="data row10 col4" >0.2604</td>
#       <td id="T_e4bf2_row10_col5" class="data row10 col5" >0.1938</td>
#     </tr>
#     <tr>
#       <th id="T_e4bf2_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e4bf2_row11_col0" class="data row11 col0" >3854.9857</td>
#       <td id="T_e4bf2_row11_col1" class="data row11 col1" >178484221389.8026</td>
#       <td id="T_e4bf2_row11_col2" class="data row11 col2" >128759.0260</td>
#       <td id="T_e4bf2_row11_col3" class="data row11 col3" >0.0455</td>
#       <td id="T_e4bf2_row11_col4" class="data row11 col4" >0.0042</td>
#       <td id="T_e4bf2_row11_col5" class="data row11 col5" >0.0035</td>
#     </tr>
#   </tbody>
# </table>

# %%
lr = create_model("lr")
# Out:
# <style type="text/css">
# #T_3c780_row10_col0, #T_3c780_row10_col1, #T_3c780_row10_col2, #T_3c780_row10_col3, #T_3c780_row10_col4, #T_3c780_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3c780_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c780_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c780_row0_col0" class="data row0 col0" >589259.1250</td>
#       <td id="T_3c780_row0_col1" class="data row0 col1" >953328795648.0000</td>
#       <td id="T_3c780_row0_col2" class="data row0 col2" >976385.5625</td>
#       <td id="T_3c780_row0_col3" class="data row0 col3" >0.6937</td>
#       <td id="T_3c780_row0_col4" class="data row0 col4" >0.8891</td>
#       <td id="T_3c780_row0_col5" class="data row0 col5" >0.9384</td>
#     </tr>
#     <tr>
#       <th id="T_3c780_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3c780_row1_col0" class="data row1 col0" >598627.0000</td>
#       <td id="T_3c780_row1_col1" class="data row1 col1" >1329666064384.0000</td>
#       <td id="T_3c780_row1_col2" class="data row1 col2" >1153111.5000</td>
#       <td id="T_3c780_row1_col3" class="data row1 col3" >0.6271</td>
#       <td id="T_3c780_row1_col4" class="data row1 col4" >0.8882</td>
#       <td id="T_3c780_row1_col5" class="data row1 col5" >0.9481</td>
#     </tr>
#     <tr>
#       <th id="T_3c780_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3c780_row2_col0" class="data row2 col0" >582515.3125</td>
#       <td id="T_3c780_row2_col1" class="data row2 col1" >1371203305472.0000</td>
#       <td id="T_3c780_row2_col2" class="data row2 col2" >1170983.8750</td>
#       <td id="T_3c780_row2_col3" class="data row2 col3" >0.6102</td>
#       <td id="T_3c780_row2_col4" class="data row2 col4" >0.8988</td>
#       <td id="T_3c780_row2_col5" class="data row2 col5" >0.9309</td>
#     </tr>
#     <tr>
#       <th id="T_3c780_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3c780_row3_col0" class="data row3 col0" >589420.6875</td>
#       <td id="T_3c780_row3_col1" class="data row3 col1" >980886683648.0000</td>
#       <td id="T_3c780_row3_col2" class="data row3 col2" >990397.2500</td>
#       <td id="T_3c780_row3_col3" class="data row3 col3" >0.6772</td>
#       <td id="T_3c780_row3_col4" class="data row3 col4" >0.9191</td>
#       <td id="T_3c780_row3_col5" class="data row3 col5" >0.9920</td>
#     </tr>
#     <tr>
#       <th id="T_3c780_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3c780_row4_col0" class="data row4 col0" >598185.7500</td>
#       <td id="T_3c780_row4_col1" class="data row4 col1" >1365668003840.0000</td>
#       <td id="T_3c780_row4_col2" class="data row4 col2" >1168618.0000</td>
#       <td id="T_3c780_row4_col3" class="data row4 col3" >0.6197</td>
#       <td id="T_3c780_row4_col4" class="data row4 col4" >0.8901</td>
#       <td id="T_3c780_row4_col5" class="data row4 col5" >0.9254</td>
#     </tr>
#     <tr>
#       <th id="T_3c780_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3c780_row5_col0" class="data row5 col0" >611441.4375</td>
#       <td id="T_3c780_row5_col1" class="data row5 col1" >1564390850560.0000</td>
#       <td id="T_3c780_row5_col2" class="data row5 col2" >1250756.1250</td>
#       <td id="T_3c780_row5_col3" class="data row5 col3" >0.6069</td>
#       <td id="T_3c780_row5_col4" class="data row5 col4" >0.8744</td>
#       <td id="T_3c780_row5_col5" class="data row5 col5" >0.9113</td>
#     </tr>
#     <tr>
#       <th id="T_3c780_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3c780_row6_col0" class="data row6 col0" >597233.3125</td>
#       <td id="T_3c780_row6_col1" class="data row6 col1" >1593659621376.0000</td>
#       <td id="T_3c780_row6_col2" class="data row6 col2" >1262402.3750</td>
#       <td id="T_3c780_row6_col3" class="data row6 col3" >0.5769</td>
#       <td id="T_3c780_row6_col4" class="data row6 col4" >0.9080</td>
#       <td id="T_3c780_row6_col5" class="data row6 col5" >0.9774</td>
#     </tr>
#     <tr>
#       <th id="T_3c780_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3c780_row7_col0" class="data row7 col0" >590620.6875</td>
#       <td id="T_3c780_row7_col1" class="data row7 col1" >1692782559232.0000</td>
#       <td id="T_3c780_row7_col2" class="data row7 col2" >1301069.7500</td>
#       <td id="T_3c780_row7_col3" class="data row7 col3" >0.5530</td>
#       <td id="T_3c780_row7_col4" class="data row7 col4" >0.8987</td>
#       <td id="T_3c780_row7_col5" class="data row7 col5" >0.9613</td>
#     </tr>
#     <tr>
#       <th id="T_3c780_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3c780_row8_col0" class="data row8 col0" >611019.2500</td>
#       <td id="T_3c780_row8_col1" class="data row8 col1" >1572587569152.0000</td>
#       <td id="T_3c780_row8_col2" class="data row8 col2" >1254028.5000</td>
#       <td id="T_3c780_row8_col3" class="data row8 col3" >0.5947</td>
#       <td id="T_3c780_row8_col4" class="data row8 col4" >0.8939</td>
#       <td id="T_3c780_row8_col5" class="data row8 col5" >0.9895</td>
#     </tr>
#     <tr>
#       <th id="T_3c780_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3c780_row9_col0" class="data row9 col0" >600755.1875</td>
#       <td id="T_3c780_row9_col1" class="data row9 col1" >1170315149312.0000</td>
#       <td id="T_3c780_row9_col2" class="data row9 col2" >1081811.0000</td>
#       <td id="T_3c780_row9_col3" class="data row9 col3" >0.6457</td>
#       <td id="T_3c780_row9_col4" class="data row9 col4" >0.9119</td>
#       <td id="T_3c780_row9_col5" class="data row9 col5" >0.9732</td>
#     </tr>
#     <tr>
#       <th id="T_3c780_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3c780_row10_col0" class="data row10 col0" >596907.7750</td>
#       <td id="T_3c780_row10_col1" class="data row10 col1" >1359448860262.3999</td>
#       <td id="T_3c780_row10_col2" class="data row10 col2" >1160956.3938</td>
#       <td id="T_3c780_row10_col3" class="data row10 col3" >0.6205</td>
#       <td id="T_3c780_row10_col4" class="data row10 col4" >0.8972</td>
#       <td id="T_3c780_row10_col5" class="data row10 col5" >0.9548</td>
#     </tr>
#     <tr>
#       <th id="T_3c780_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3c780_row11_col0" class="data row11 col0" >8894.3092</td>
#       <td id="T_3c780_row11_col1" class="data row11 col1" >244637203390.4696</td>
#       <td id="T_3c780_row11_col2" class="data row11 col2" >107838.3271</td>
#       <td id="T_3c780_row11_col3" class="data row11 col3" >0.0408</td>
#       <td id="T_3c780_row11_col4" class="data row11 col4" >0.0124</td>
#       <td id="T_3c780_row11_col5" class="data row11 col5" >0.0267</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## model tuning

# %%
tuned_lightgbm = tune_model(lightgbm, search_library="optuna", n_iter=100, optimize = "MAPE")
# Out:
# <style type="text/css">
# #T_3f92d_row10_col0, #T_3f92d_row10_col1, #T_3f92d_row10_col2, #T_3f92d_row10_col3, #T_3f92d_row10_col4, #T_3f92d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3f92d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f92d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3
td>
#     </tr>
#     <tr>
#       <th id="T_3f92d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3f92d_row7_col0" class="data row7 col0" >151690.5115</td>
#       <td id="T_3f92d_row7_col1" class="data row7 col1" >454264323513.7657</td>
#       <td id="T_3f92d_row7_col2" class="data row7 col2" >673991.3379</td>
#       <td id="T_3f92d_row7_col3" class="data row7 col3" >0.8801</td>
#       <td id="T_3f92d_row7_col4" class="data row7 col4" >0.2173</td>
#       <td id="T_3f92d_row7_col5" class="data row7 col5" >0.1436</td>
#     </tr>
#     <tr>
#       <th id="T_3f92d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3f92d_row8_col0" class="data row8 col0" >151183.5539</td>
#       <td id="T_3f92d_row8_col1" class="data row8 col1" >258739856066.7448</td>
#       <td id="T_3f92d_row8_col2" class="data row8 col2" >508664.7777</td>
#       <td id="T_3f92d_row8_col3" class="data row8 col3" >0.9333</td>
#       <td id="T_3f92d_row8_col4" class="data row8 col4" >0.2151</td>
#       <td id="T_3f92d_row8_col5" class="data row8 col5" >0.1512</td>
#     </tr>
#     <tr>
#       <th id="T_3f92d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3f92d_row9_col0" class="data row9 col0" >153988.8326</td>
#       <td id="T_3f92d_row9_col1" class="data row9 col1" >259323139127.7986</td>
#       <td id="T_3f92d_row9_col2" class="data row9 col2" >509237.8021</td>
#       <td id="T_3f92d_row9_col3" class="data row9 col3" >0.9215</td>
#       <td id="T_3f92d_row9_col4" class="data row9 col4" >0.2300</td>
#       <td id="T_3f92d_row9_col5" class="data row9 col5" >0.1542</td>
#     </tr>
#     <tr>
#       <th id="T_3f92d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3f92d_row10_col0" class="data row10 col0" >148206.6683</td>
#       <td id="T_3f92d_row10_col1" class="data row10 col1" >292413901801.7468</td>
#       <td id="T_3f92d_row10_col2" class="data row10 col2" >521683.4810</td>
#       <td id="T_3f92d_row10_col3" class="data row10 col3" >0.9196</td>
#       <td id="T_3f92d_row10_col4" class="data row10 col4" >0.2229</td>
#       <td id="T_3f92d_row10_col5" class="data row10 col5" >0.1489</td>
#     </tr>
#     <tr>
#       <th id="T_3f92d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3f92d_row11_col0" class="data row11 col0" >4175.1570</td>
#       <td id="T_3f92d_row11_col1" class="data row11 col1" >169225507364.6622</td>
#       <td id="T_3f92d_row11_col2" class="data row11 col2" >142338.4960</td>
#       <td id="T_3f92d_row11_col3" class="data row11 col3" >0.0432</td>
#       <td id="T_3f92d_row11_col4" class="data row11 col4" >0.0087</td>
#       <td id="T_3f92d_row11_col5" class="data row11 col5" >0.0041</td>
#     </tr>
#   </tbody>
# </table>

# %%
tuned_rf = tune_model(rf, choose_better = True, optimize = "MAPE", search_library="optuna")
# Out:
# IntProgress(value=0, description='Processing: ', max=7)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   08:12:44
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .    Random Forest Regressor
# Empty DataFrame
# Columns: [Fold, MAE, MSE, RMSE, R2, RMSLE, MAPE]
# Index: []
# [I 2022-04-12 08:12:44,879] Searching the best hyperparameters using 76718 samples...
# exception calling callback for <Future at 0x7f12e81b1bd0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81b1d90 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81b1ad0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81b10d0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e9a3d9d0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81ddf90 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81ddc90 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81b1210 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81dd250 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8230ed0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81dded0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12eb6c9890 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8249d10 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81b7850 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81dd990 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81ddbd0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8145510 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81da050 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81dad90 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81dadd0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8158e10 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8158e90 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81583d0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81cc250 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8230b10 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f13536b2290 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e822a0d0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8145950 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12eb730350 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# ...
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12f817a890 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# [W 2022-04-12 20:14:25,961] Trial 6 failed because of the following error: WorkerInterrupt()
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/tree/_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/tree/_classes.py", line 375, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     r = call_item()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 285, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 600, in __call__
#     raise WorkerInterrupt() from e
# joblib.my_exceptions.WorkerInterrupt
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/optuna/study/_optimize.py", line 213, in _run_trial
#     value_or_values = func(trial)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/optuna/integration/sklearn.py", line 238, in __call__
#     scoring=self.scoring,
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/model_selection/_validation.py", line 248, in cross_validate
#     for train, test in cv.split(X, y, groups))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 1044, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/pycaret/internal/pipeline.py", line 118, in fit
#     result = super().fit(X, y=y, **fit_kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/imblearn/pipeline.py", line 281, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/ensemble/_forest.py", line 392, in fit
#     for i, t in enumerate(trees))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 1054, in __call__
#     self.retrieve()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 933, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/usr/lib64/python3.7/concurrent/futures/_base.py", line 435, in result
#     return self.__get_result()
#   File "/usr/lib64/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# joblib.my_exceptions.WorkerInterrupt
# [W 2022-04-12 20:14:26,682] Trial 8 failed because of the following error: ShutdownExecutorError('The Executor was shutdown with `kill_workers=True` before this job could complete.')
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/optuna/study/_optimize.py", line 213, in _run_trial
#     value_or_values = func(trial)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/optuna/integration/sklearn.py", line 238, in __call__
#     scoring=self.scoring,
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/model_selection/_validation.py", line 248, in cross_validate
#     for train, test in cv.split(X, y, groups))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/pycaret/internal/pipeline.py", line 118, in fit
#     result = super().fit(X, y=y, **fit_kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/imblearn/pipeline.py", line 281, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/ensemble/_forest.py", line 392, in fit
#     for i, t in enumerate(trees))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 1054, in __call__
#     self.retrieve()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 933, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/usr/lib64/python3.7/concurrent/futures/_base.py", line 435, in result
#     return self.__get_result()
#   File "/usr/lib64/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# joblib.externals.loky.process_executor.ShutdownExecutorError: The Executor was shutdown with `kill_workers=True` before this job could complete.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     102                     if len(futures) >= n_jobs:
# --> 103                         completed, futures = wait(futures, return_when=FIRST_COMPLETED)
#     104                         # Raise if exception occurred in executing the completed futures.
#
# /usr/lib64/python3.7/concurrent/futures/_base.py in wait(fs, timeout, return_when)
#     300
# --> 301     waiter.event.wait(timeout)
#     302     for f in fs:
#
# /usr/lib64/python3.7/threading.py in wait(self, timeout)
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#
# /usr/lib64/python3.7/threading.py in wait(self, timeout)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_23688/1936977519.py in <module>
# ----> 1 tuned_rf = tune_model(rf, choose_better = True, optimize = "MAPE", search_library="optuna")
#
# ~/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/pycaret/regression.py in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1168         tuner_verbose=tuner_verbose,
#    1169         return_train_score=return_train_score,
# -> 1170         **kwargs,
#    1171     )
#    1172
#
# ~/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/pycaret/internal/tabular.py in tune_model_supervised(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, display, return_train_score, **kwargs)
#    4679                 model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4680         else:
# -> 4681             model_grid.fit(X_train, y_train, groups=groups, **fit_kwargs)
#    4682         best_params = model_grid.best_params_
#    4683         logger.info(f"best_params: {best_params}")
#
# ~/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/optuna/integration/sklearn.py in fit(self, X, y, groups, **fit_params)
#     874
#     875         self.study_.optimize(
# --> 876             objective, n_jobs=self.n_jobs, n_trials=self.n_trials, timeout=self.timeout
#     877         )
#     878
#
# ~/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     407             callbacks=callbacks,
#     408             gc_after_trial=gc_after_trial,
# --> 409             show_progress_bar=show_progress_bar,
#     410         )
#     411
#
# ~/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     118                             True,
#     119                             time_start,
# --> 120                             None,
#     121                         )
#     122                     )
#
# /usr/lib64/python3.7/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     621
#     622     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 623         self.shutdown(wait=True)
#     624         return False
#     625
#
# /usr/lib64/python3.7/concurrent/futures/thread.py in shutdown(self, wait)
#     214         if wait:
#     215             for t in self._threads:
# --> 216                 t.join()
#     217     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# /usr/lib64/python3.7/threading.py in join(self, timeout)
#    1042
#    1043         if timeout is None:
# -> 1044             self._wait_for_tstate_lock()
#    1045         else:
#    1046             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib64/python3.7/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1058         if lock is None:  # already determined that the C code is done
#    1059             assert self._is_stopped
# -> 1060         elif lock.acquire(block, timeout):
#    1061             lock.release()
#    1062             self._stop()
#
# KeyboardInterrupt:

# %%
tuned_knn = tune_model(knn, optimize = "MAPE", search_library="optuna")

# %% [markdown]
# ## emsemble - stacking

# %%
stacker = stack_models(estimator_list=[catboost, tuned_lightgbm, tuned_rf, tuned_knn, lr])

# %%
save_model(stacker, "stacker")

# %%
save_model(tuned_rf, "tuned_rf")

# %%
save_model(tuned_knn, "tuned_knn")

# %%
save_model(tuned_lightgbm, "tuned_lightgbm")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='price',
#                                        time_features=['parsed_date'])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numer...
#                                 importance_type='split',
#                                 learning_rate=0.07138121645973822, max_depth=-1,
#                                 min_child_samples=78, min_child_weight=0.001,
#                                 min_split_gain=0.726386549714634,
#                                 n_estimators=268, n_jobs=-1, num_leaves=245,
#                                 objective=None, random_state=6413,
#                                 reg_alpha=0.2358859554808448,
#                                 reg_lambda=0.0005740818542342191, silent='warn',
#                                 subsample=1.0, subsample_for_bin=200000,
#                                 subsample_freq=0)]],
#           verbose=False),
#  'tuned_lightgbm.pkl')

# %%
save_model(catboost, "catboost")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='price',
#                                        time_features=['parsed_date'])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numer...
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'),
#                  ('fix_multi',
#                   Fix_multicollinearity(correlation_with_target_preference=None,
#                                         correlation_with_target_threshold=0.0,
#                                         target_variable='price',
#                                         threshold=0.9)),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   <catboost.core.CatBoostRegressor object at 0x7f135687ba50>]],
#           verbose=False),
#  'catboost.pkl')

# %%
save_model(lr, "lr")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='price',
#                                        time_features=['parsed_date'])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numer...
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', 'passthrough'),
#                  ('fix_multi',
#                   Fix_multicollinearity(correlation_with_target_preference=None,
#                                         correlation_with_target_threshold=0.0,
#                                         target_variable='price',
#                                         threshold=0.9)),
#                  ('dfs', 'passthrough'), ('pca', 'passthrough'),
#                  ['trained_model',
#                   LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1,
#                                    normalize=False)]],
#           verbose=False),
#  'lr.pkl')
# exception calling callback for <Future at 0x7f12e8072410 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8072390 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8072310 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8072290 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e80721d0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8072190 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8072210 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e803b290 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f128e62fed0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f128e62f2d0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f13536c8950 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e818fb10 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12eb7f9410 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8034c90 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8180310 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8180e50 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8030e10 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8180450 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e819a290 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12f8139d90 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8034e50 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81f8f50 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e80300d0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8034990 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8185610 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8030890 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e81f8e10 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8030ad0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e80345d0 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
# ...
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8029450 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8029350 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8029250 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# exception calling callback for <Future at 0x7f12e8029150 state=finished raised ShutdownExecutorError>
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/_base.py", line 625, in _invoke_callbacks
#     callback(self)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 359, in __call__
#     self.parallel.dispatch_next()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 792, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 531, in apply_async
#     future = self._workers.submit(SafeFunction(func))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/reusable_executor.py", line 178, in submit
#     fn, *args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 1105, in submit
#     'cannot schedule new futures after shutdown')
# joblib.externals.loky.process_executor.ShutdownExecutorError: cannot schedule new futures after shutdown
# [W 2022-04-12 20:22:30,641] Trial 3 failed because of the following error: WorkerInterrupt()
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/ensemble/_forest.py", line 168, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/tree/_classes.py", line 1246, in fit
#     X_idx_sorted=X_idx_sorted)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/tree/_classes.py", line 375, in fit
#     builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
# KeyboardInterrupt
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     r = call_item()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/externals/loky/process_executor.py", line 285, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 600, in __call__
#     raise WorkerInterrupt() from e
# joblib.my_exceptions.WorkerInterrupt
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/optuna/study/_optimize.py", line 213, in _run_trial
#     value_or_values = func(trial)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/optuna/integration/sklearn.py", line 238, in __call__
#     scoring=self.scoring,
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/model_selection/_validation.py", line 248, in cross_validate
#     for train, test in cv.split(X, y, groups))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 1044, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/pycaret/internal/pipeline.py", line 118, in fit
#     result = super().fit(X, y=y, **fit_kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/imblearn/pipeline.py", line 281, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/ensemble/_forest.py", line 392, in fit
#     for i, t in enumerate(trees))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 1054, in __call__
#     self.retrieve()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 933, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/usr/lib64/python3.7/concurrent/futures/_base.py", line 435, in result
#     return self.__get_result()
#   File "/usr/lib64/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# joblib.my_exceptions.WorkerInterrupt
# [W 2022-04-12 20:22:30,706] Trial 7 failed because of the following error: ShutdownExecutorError('The Executor was shutdown with `kill_workers=True` before this job could complete.')
# Traceback (most recent call last):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/optuna/study/_optimize.py", line 213, in _run_trial
#     value_or_values = func(trial)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/optuna/integration/sklearn.py", line 238, in __call__
#     scoring=self.scoring,
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/model_selection/_validation.py", line 248, in cross_validate
#     for train, test in cv.split(X, y, groups))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 1044, in __call__
#     while self.dispatch_one_batch(iterator):
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 263, in __call__
#     for func, args, kwargs in self.items]
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 263, in <listcomp>
#     for func, args, kwargs in self.items]
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/pycaret/internal/pipeline.py", line 118, in fit
#     result = super().fit(X, y=y, **fit_kwargs)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/imblearn/pipeline.py", line 281, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params)
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/sklearn/ensemble/_forest.py", line 392, in fit
#     for i, t in enumerate(trees))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 1054, in __call__
#     self.retrieve()
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/parallel.py", line 933, in retrieve
#     self._output.extend(job.get(timeout=self.timeout))
#   File "/home/user/Documents/sf_project_6/env_ml/lib64/python3.7/site-packages/joblib/_parallel_backends.py", line 542, in wrap_future_result
#     return future.result(timeout=timeout)
#   File "/usr/lib64/python3.7/concurrent/futures/_base.py", line 435, in result
#     return self.__get_result()
#   File "/usr/lib64/python3.7/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# joblib.externals.loky.process_executor.ShutdownExecutorError: The Executor was shutdown with `kill_workers=True` before this job could complete.
