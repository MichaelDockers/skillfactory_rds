# %% [markdown]
# - [previous file - EDA](2022-03-31_train-test_EDA.ipynb)
# - [next tile - models with pre-tuned parameters and ensembles](2022-04-15_ensemble.ipynb)
#
# ## imports

# %%
from warnings import filterwarnings

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import RobustScaler, LabelEncoder
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, StackingRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
import xgboost as xgb
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
import optuna
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_percentage_error

from lib.model_related import *

sns.set()
filterwarnings("ignore")

# %% [markdown]
# ## reading data

# %%
train_raw = pd.read_parquet("data/2022-04-08_train_pre-model.parquet")
test_raw = pd.read_parquet("data/2022-04-08_test_pre-model.parquet")

train_raw.shape, test_raw.shape
# Out:
# ((115367, 30), (34686, 28))

# %%
def submit(hold_out: pd.DataFrame, model, name="submission"):
    preds = model.predict(hold_out)
    submission = pd.read_csv("data/sample_submission.csv")
    submission["price"] = preds
    submission.to_csv(f"{name}.csv", index=False)
    
    
def submit_log(hold_out: pd.DataFrame, model, name="submission"):
    preds = model.predict(hold_out)
    submission = pd.read_csv("data/sample_submission.csv")
    submission["price"] = np.exp(preds)
    submission.to_csv(f"{name}.csv", index=False)

# %% [markdown]
# ## encoding

# %%
train_raw["train/test"] = "train"
test_raw["train/test"] = "test"

data = train_raw.append(test_raw)
data["ptc"].fillna("Оригинал", inplace=True)

data[data.select_dtypes("object").columns.tolist()] = data[
    data.select_dtypes("object").columns.tolist()
].astype(str)

for col in set(data.select_dtypes(exclude=("object")).columns) - {"price"}:
    data[col] = (
        RobustScaler().fit_transform(data[col].values.reshape(-1, 1)).reshape(-1, 1)
    )

for col in ["model_name"]:
    data[col] = LabelEncoder().fit_transform(data[col].astype("str"))

data = pd.get_dummies(
    data,
    columns=[
        "vehicle_transmission",
        "vendor",
        "brand",
        "fuel_type",
        "body_type",
        "color",
        "ptc",
        "drive",
        "wheel",
        "age_cat",
    ],
)

train = data.loc[data["train/test"] == "train"]

train_jane = train.loc[train["sample"] == "jane"]
train_sokolov = train.loc[train["sample"] == "sokolov"]
train_jane["price"] = train_jane["price"] * 0.86
train = train_jane.append(train_sokolov)

train.drop(columns=["sample", "description", "train/test"], inplace=True)
test = data.loc[data["train/test"] == "test"].drop(
    columns=["sample", "description", "train/test", "price"]
)

# %% [markdown]
# ## modelling

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train.drop(columns="price"), train["price"], random_state = 42, shuffle=True)
X_train.shape, y_train.shape, X_valid.shape, y_valid.shape
# Out:
# ((86525, 112), (86525,), (28842, 112), (28842,))

# %% [markdown]
# ## model tuning

# %% [markdown]
# ### lightgbm

# %%
def objective(trial):

    param = {
        "objective": "regression",
        "metric": "mape",
        "learning_rate": trial.suggest_uniform("learning_rate", 0.001, 1.0),
        "lambda_l1": trial.suggest_loguniform("lambda_l1", 1e-8, 10.0),
        "lambda_l2": trial.suggest_loguniform("lambda_l2", 1e-8, 10.0),
        "num_leaves": trial.suggest_int("num_leaves", 2, 256),
        "feature_fraction": trial.suggest_uniform("feature_fraction", 0.4, 1.0),
        "bagging_fraction": trial.suggest_uniform("bagging_fraction", 0.4, 1.0),
        "bagging_freq": trial.suggest_int("bagging_freq", 1, 7),
        "min_child_samples": trial.suggest_int("min_child_samples", 5, 100),
        "verbosity": -1,
    }

    gbm = LGBMRegressor(**param, silent=True)
    cv_roc_auc = cross_val_score(gbm, X_train, y_train, cv=8, scoring="neg_mean_absolute_percentage_error", n_jobs=-1)

    return np.mean(cv_roc_auc)


study = optuna.create_study(
    direction="maximize",
    storage="sqlite:///LGBMRegressor.db",
    study_name="LGBMRegressor",
    load_if_exists=True,
)
study.optimize(objective, n_trials=1000)
# Out:
# [I 2022-04-14 15:43:16,930] Using an existing study with name 'LGBMRegressor' instead of creating a new one.
# [I 2022-04-14 15:43:25,432] Trial 445 finished with value: -0.14180395741799445 and parameters: {'learning_rate': 0.19347733786437052, 'lambda_l1': 3.355228574586955e-05, 'lambda_l2': 1.1601895771957918e-05, 'num_leaves': 252, 'feature_fraction': 0.8970063024698147, 'bagging_fraction': 0.9606519036808351, 'bagging_freq': 5, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:43:33,612] Trial 446 finished with value: -0.14215296021720059 and parameters: {'learning_rate': 0.15531498091829857, 'lambda_l1': 5.7423118976627957e-05, 'lambda_l2': 3.860936427136809e-06, 'num_leaves': 242, 'feature_fraction': 0.9507236756761598, 'bagging_fraction': 0.9823924219102652, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:43:39,859] Trial 447 finished with value: -0.15595972309571607 and parameters: {'learning_rate': 0.13238816663126335, 'lambda_l1': 6.722824096860128, 'lambda_l2': 4.519439215832234e-05, 'num_leaves': 147, 'feature_fraction': 0.5074008349004805, 'bagging_fraction': 0.7308011036666182, 'bagging_freq': 5, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:43:48,532] Trial 448 finished with value: -0.14615103011018526 and parameters: {'learning_rate': 0.18382983633861633, 'lambda_l1': 2.186994917919563e-05, 'lambda_l2': 2.6517059080236044e-08, 'num_leaves': 230, 'feature_fraction': 0.8815223323751555, 'bagging_fraction': 0.9894597695953253, 'bagging_freq': 5, 'min_child_samples': 24}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:43:56,741] Trial 449 finished with value: -0.1446704018011359 and parameters: {'learning_rate': 0.20782449905830927, 'lambda_l1': 0.004871910798213063, 'lambda_l2': 1.4640552471285752e-08, 'num_leaves': 247, 'feature_fraction': 0.9213752405187822, 'bagging_fraction': 0.97438107232075, 'bagging_freq': 6, 'min_child_samples': 12}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:44:07,111] Trial 450 finished with value: -0.1549421666375994 and parameters: {'learning_rate': 0.25533676699289964, 'lambda_l1': 0.002952859911515816, 'lambda_l2': 1.1716724942890071e-07, 'num_leaves': 256, 'feature_fraction': 0.9079980701175505, 'bagging_fraction': 0.9996151225308793, 'bagging_freq': 5, 'min_child_samples': 63}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:44:14,484] Trial 451 finished with value: -0.154047923748605 and parameters: {'learning_rate': 0.4148075442845684, 'lambda_l1': 0.007152146380012093, 'lambda_l2': 1.036508831752625e-08, 'num_leaves': 251, 'feature_fraction': 0.9338361399637797, 'bagging_fraction': 0.9586545601658184, 'bagging_freq': 5, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:44:22,384] Trial 452 finished with value: -0.14193689106000612 and parameters: {'learning_rate': 0.15163949322245576, 'lambda_l1': 0.002287287256727618, 'lambda_l2': 3.1980836073209244e-08, 'num_leaves': 236, 'feature_fraction': 0.8916684120811854, 'bagging_fraction': 0.9808936246452173, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:44:30,109] Trial 453 finished with value: -0.14324038751322554 and parameters: {'learning_rate': 0.17406461859189967, 'lambda_l1': 1.4957042505147227e-05, 'lambda_l2': 6.071494864891732e-08, 'num_leaves': 246, 'feature_fraction': 0.5586216266991373, 'bagging_fraction': 0.9882756903950748, 'bagging_freq': 4, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:44:39,072] Trial 454 finished with value: -0.14592270139695396 and parameters: {'learning_rate': 0.23236774800398746, 'lambda_l1': 0.00529297053508772, 'lambda_l2': 1.9187048214088296e-08, 'num_leaves': 256, 'feature_fraction': 0.914600576736301, 'bagging_fraction': 0.9701146292855405, 'bagging_freq': 5, 'min_child_samples': 20}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:44:47,607] Trial 455 finished with value: -0.1440525523135797 and parameters: {'learning_rate': 0.11344437782293673, 'lambda_l1': 6.23464975734775e-05, 'lambda_l2': 6.303625911635406e-06, 'num_leaves': 242, 'feature_fraction': 0.8639507585451699, 'bagging_fraction': 0.9468776968477725, 'bagging_freq': 5, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:44:56,507] Trial 456 finished with value: -0.14217580301642788 and parameters: {'learning_rate': 0.16446362834647327, 'lambda_l1': 0.00023548590296291824, 'lambda_l2': 4.0054089407085445e-08, 'num_leaves': 251, 'feature_fraction': 0.9596485017507269, 'bagging_fraction': 0.9993944984444859, 'bagging_freq': 3, 'min_child_samples': 10}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:45:04,260] Trial 457 finished with value: -0.14219661769986727 and parameters: {'learning_rate': 0.19896040095990497, 'lambda_l1': 8.752520086008218e-06, 'lambda_l2': 1.3760990199728728e-06, 'num_leaves': 247, 'feature_fraction': 0.9295191924745152, 'bagging_fraction': 0.9805432574716986, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:45:13,870] Trial 458 finished with value: -0.1460358905372936 and parameters: {'learning_rate': 0.13470741049533147, 'lambda_l1': 0.10635323448720631, 'lambda_l2': 2.409711730519271e-08, 'num_leaves': 251, 'feature_fraction': 0.9023763620739559, 'bagging_fraction': 0.9885111294109916, 'bagging_freq': 6, 'min_child_samples': 40}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:45:22,097] Trial 459 finished with value: -0.14136033137281334 and parameters: {'learning_rate': 0.1545184774864039, 'lambda_l1': 0.007991156286465717, 'lambda_l2': 3.1066813174089756e-06, 'num_leaves': 240, 'feature_fraction': 0.9989682794106798, 'bagging_fraction': 0.9999669393961114, 'bagging_freq': 3, 'min_child_samples': 8}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:45:30,807] Trial 460 finished with value: -0.14327742685371284 and parameters: {'learning_rate': 0.14644504524190635, 'lambda_l1': 0.0032553711963132876, 'lambda_l2': 2.5356086923724227e-06, 'num_leaves': 231, 'feature_fraction': 0.9936262819461351, 'bagging_fraction': 0.9895658973520581, 'bagging_freq': 3, 'min_child_samples': 13}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:45:39,752] Trial 461 finished with value: -0.15250371186768558 and parameters: {'learning_rate': 0.07022671779158447, 'lambda_l1': 0.00013521892360541697, 'lambda_l2': 3.986773399724755e-06, 'num_leaves': 236, 'feature_fraction': 0.9947528251314375, 'bagging_fraction': 0.9995543706098162, 'bagging_freq': 4, 'min_child_samples': 11}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:45:48,099] Trial 462 finished with value: -0.14426468906985312 and parameters: {'learning_rate': 0.12060959228670798, 'lambda_l1': 0.007611497824899267, 'lambda_l2': 3.4381999191073756e-06, 'num_leaves': 226, 'feature_fraction': 0.9789539108986731, 'bagging_fraction': 0.9893073779165816, 'bagging_freq': 5, 'min_child_samples': 8}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:45:57,133] Trial 463 finished with value: -0.1452050322885607 and parameters: {'learning_rate': 0.10085582704405674, 'lambda_l1': 0.0016585999023963406, 'lambda_l2': 2.4524886118343907e-06, 'num_leaves': 239, 'feature_fraction': 0.9530963580664846, 'bagging_fraction': 0.9994465747620237, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:46:03,948] Trial 464 finished with value: -0.15394980871353098 and parameters: {'learning_rate': 0.4503730654322458, 'lambda_l1': 0.004149299338654631, 'lambda_l2': 5.4890740947584e-06, 'num_leaves': 242, 'feature_fraction': 0.9821877336368481, 'bagging_fraction': 0.9999864180658941, 'bagging_freq': 3, 'min_child_samples': 6}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:46:12,461] Trial 465 finished with value: -0.14226515366955234 and parameters: {'learning_rate': 0.15424475982702307, 'lambda_l1': 1.1545163264640553e-05, 'lambda_l2': 1.68202562281472e-06, 'num_leaves': 234, 'feature_fraction': 0.9432994370560537, 'bagging_fraction': 0.9795414255014354, 'bagging_freq': 3, 'min_child_samples': 8}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:46:20,128] Trial 466 finished with value: -0.1503491684352527 and parameters: {'learning_rate': 0.3452173652562123, 'lambda_l1': 0.04940610294545504, 'lambda_l2': 8.622568730665224e-07, 'num_leaves': 241, 'feature_fraction': 0.9332541281210276, 'bagging_fraction': 0.979084935334178, 'bagging_freq': 3, 'min_child_samples': 11}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:46:28,710] Trial 467 finished with value: -0.14390540122566362 and parameters: {'learning_rate': 0.12667758967436077, 'lambda_l1': 0.024370688903886283, 'lambda_l2': 9.246503858662165e-08, 'num_leaves': 244, 'feature_fraction': 0.9708478095182168, 'bagging_fraction': 0.9890837400434858, 'bagging_freq': 3, 'min_child_samples': 15}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:46:36,732] Trial 468 finished with value: -0.14267851456930883 and parameters: {'learning_rate': 0.16568357865847722, 'lambda_l1': 0.008316468738836317, 'lambda_l2': 4.856069165918931e-08, 'num_leaves': 236, 'feature_fraction': 0.9794058954245357, 'bagging_fraction': 0.9644444725202127, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:46:45,851] Trial 469 finished with value: -0.1422079304344138 and parameters: {'learning_rate': 0.19073600458862713, 'lambda_l1': 0.0025402604866447487, 'lambda_l2': 1.1587639173705654e-06, 'num_leaves': 247, 'feature_fraction': 0.9985915750617671, 'bagging_fraction': 0.980116646819485, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:46:55,176] Trial 470 finished with value: -0.14226093045665697 and parameters: {'learning_rate': 0.1430679329689739, 'lambda_l1': 2.547733658070505e-05, 'lambda_l2': 3.263496381766647e-08, 'num_leaves': 240, 'feature_fraction': 0.9657958719983314, 'bagging_fraction': 0.9878610780704651, 'bagging_freq': 5, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:47:02,577] Trial 471 finished with value: -0.1532279591420729 and parameters: {'learning_rate': 0.28352179487110285, 'lambda_l1': 0.005366454766805409, 'lambda_l2': 9.012977015053212e-06, 'num_leaves': 248, 'feature_fraction': 0.7736750542734503, 'bagging_fraction': 0.7112686292430421, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:47:11,327] Trial 472 finished with value: -0.14347630857406635 and parameters: {'learning_rate': 0.17041966730618624, 'lambda_l1': 0.03708455400161504, 'lambda_l2': 6.666369667309153e-08, 'num_leaves': 252, 'feature_fraction': 0.8776197601865883, 'bagging_fraction': 0.9668897980111084, 'bagging_freq': 3, 'min_child_samples': 13}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:47:18,893] Trial 473 finished with value: -0.14204748915159915 and parameters: {'learning_rate': 0.2074140023033496, 'lambda_l1': 0.001368750306146564, 'lambda_l2': 1.757855504057789e-05, 'num_leaves': 233, 'feature_fraction': 0.8950737494438833, 'bagging_fraction': 0.9752859412976203, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:47:26,463] Trial 474 finished with value: -0.20546086051410253 and parameters: {'learning_rate': 0.883474818085416, 'lambda_l1': 4.9083085414151044e-05, 'lambda_l2': 1.9453959387986565e-08, 'num_leaves': 245, 'feature_fraction': 0.9119149177499458, 'bagging_fraction': 0.9890862195463539, 'bagging_freq': 3, 'min_child_samples': 10}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:47:34,681] Trial 475 finished with value: -0.1422807635533606 and parameters: {'learning_rate': 0.15266672460093628, 'lambda_l1': 0.0032774480724656776, 'lambda_l2': 3.275645425529351e-08, 'num_leaves': 251, 'feature_fraction': 0.946365941268319, 'bagging_fraction': 0.9594309732129718, 'bagging_freq': 7, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:47:42,666] Trial 476 finished with value: -0.1457012825771201 and parameters: {'learning_rate': 0.18194437681736375, 'lambda_l1': 0.010401514195322781, 'lambda_l2': 3.0044540277429025e-06, 'num_leaves': 240, 'feature_fraction': 0.9290350991327109, 'bagging_fraction': 0.8425055762596714, 'bagging_freq': 5, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:47:51,206] Trial 477 finished with value: -0.14207029898049978 and parameters: {'learning_rate': 0.13002139520345782, 'lambda_l1': 4.839111814944426e-06, 'lambda_l2': 1.6934783098474645e-06, 'num_leaves': 256, 'feature_fraction': 0.9214321441443183, 'bagging_fraction': 0.9897838565992374, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:47:57,221] Trial 478 finished with value: -0.15175672886610875 and parameters: {'learning_rate': 0.2180396567166872, 'lambda_l1': 0.023123133986296035, 'lambda_l2': 5.178992287034234e-08, 'num_leaves': 100, 'feature_fraction': 0.9064368514108765, 'bagging_fraction': 0.9733410312984655, 'bagging_freq': 3, 'min_child_samples': 12}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:48:07,629] Trial 479 finished with value: -0.15226987414935764 and parameters: {'learning_rate': 0.16515968404432851, 'lambda_l1': 0.001978240915611343, 'lambda_l2': 1.6760928024900963e-08, 'num_leaves': 247, 'feature_fraction': 0.8870864998287153, 'bagging_fraction': 0.998686846872882, 'bagging_freq': 3, 'min_child_samples': 66}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:48:15,392] Trial 480 finished with value: -0.14184036654680826 and parameters: {'learning_rate': 0.19302493671728035, 'lambda_l1': 0.005877502370253776, 'lambda_l2': 2.5149838689766267e-08, 'num_leaves': 243, 'feature_fraction': 0.9406110895967902, 'bagging_fraction': 0.9999568282917728, 'bagging_freq': 3, 'min_child_samples': 8}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:48:23,572] Trial 481 finished with value: -0.14276090643008063 and parameters: {'learning_rate': 0.14310138029442074, 'lambda_l1': 0.0636403621983515, 'lambda_l2': 1.0347512291464979e-07, 'num_leaves': 230, 'feature_fraction': 0.9582976738628873, 'bagging_fraction': 0.9819161418484754, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:48:32,635] Trial 482 finished with value: -0.14411611053779094 and parameters: {'learning_rate': 0.1059432556869847, 'lambda_l1': 0.0002933702773552631, 'lambda_l2': 1.580330723658945e-08, 'num_leaves': 251, 'feature_fraction': 0.9008995626730886, 'bagging_fraction': 0.9704905879179927, 'bagging_freq': 5, 'min_child_samples': 10}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:48:40,232] Trial 483 finished with value: -0.14147285268728557 and parameters: {'learning_rate': 0.23556638037221, 'lambda_l1': 0.00015432022681007482, 'lambda_l2': 3.643515761872662e-08, 'num_leaves': 247, 'feature_fraction': 0.9207755272819765, 'bagging_fraction': 0.9998914000767234, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:48:47,835] Trial 484 finished with value: -0.1412813148896504 and parameters: {'learning_rate': 0.2328135812038993, 'lambda_l1': 0.0001351884143488278, 'lambda_l2': 2.883024842147192e-08, 'num_leaves': 250, 'feature_fraction': 0.9172472590437052, 'bagging_fraction': 0.9898680013712275, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:48:55,479] Trial 485 finished with value: -0.14258548546018912 and parameters: {'learning_rate': 0.2502201735861523, 'lambda_l1': 0.00013638915815748385, 'lambda_l2': 2.855803468021503e-08, 'num_leaves': 256, 'feature_fraction': 0.9160588681813417, 'bagging_fraction': 0.9887257011372713, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:49:02,781] Trial 486 finished with value: -0.14194782029544536 and parameters: {'learning_rate': 0.2341718009736844, 'lambda_l1': 0.00010131564730327359, 'lambda_l2': 4.0347062311576904e-08, 'num_leaves': 237, 'feature_fraction': 0.9227223188918012, 'bagging_fraction': 0.9883951783634528, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:49:09,994] Trial 487 finished with value: -0.14350859168725058 and parameters: {'learning_rate': 0.27908532887816534, 'lambda_l1': 0.00016534772940681602, 'lambda_l2': 2.1677742634030165e-08, 'num_leaves': 246, 'feature_fraction': 0.9023185919744237, 'bagging_fraction': 0.9997356886164964, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:49:17,414] Trial 488 finished with value: -0.14280420075209935 and parameters: {'learning_rate': 0.24819674441473516, 'lambda_l1': 0.00024667739533802983, 'lambda_l2': 6.710336386042097e-08, 'num_leaves': 251, 'feature_fraction': 0.90959734425897, 'bagging_fraction': 0.9790845351352289, 'bagging_freq': 4, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:49:27,866] Trial 489 finished with value: -0.15683921206503842 and parameters: {'learning_rate': 0.22885066114152494, 'lambda_l1': 0.00016535570729976057, 'lambda_l2': 1.6138902865499756e-08, 'num_leaves': 241, 'feature_fraction': 0.890236671168048, 'bagging_fraction': 0.9613527569904416, 'bagging_freq': 3, 'min_child_samples': 91}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:49:35,687] Trial 490 finished with value: -0.14223838366703087 and parameters: {'learning_rate': 0.22184954959784148, 'lambda_l1': 9.950459523692235e-05, 'lambda_l2': 2.9746558471778637e-08, 'num_leaves': 251, 'feature_fraction': 0.9236177784499946, 'bagging_fraction': 0.9832713890154362, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:49:43,284] Trial 491 finished with value: -0.1456553956706036 and parameters: {'learning_rate': 0.20988604675874362, 'lambda_l1': 0.0002246007726270398, 'lambda_l2': 1.0220072435810968e-08, 'num_leaves': 247, 'feature_fraction': 0.9113729799166468, 'bagging_fraction': 0.7609098210552402, 'bagging_freq': 3, 'min_child_samples': 6}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:49:50,601] Trial 492 finished with value: -0.14284768087645733 and parameters: {'learning_rate': 0.2559266972678596, 'lambda_l1': 6.948556062400362e-05, 'lambda_l2': 2.8699395405260725e-08, 'num_leaves': 256, 'feature_fraction': 0.8673945449324793, 'bagging_fraction': 0.9704788279659367, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:49:58,334] Trial 493 finished with value: -0.14222848257031195 and parameters: {'learning_rate': 0.20927601190181402, 'lambda_l1': 0.00016627681700571667, 'lambda_l2': 1.4558769192256414e-08, 'num_leaves': 237, 'feature_fraction': 0.9994632264234816, 'bagging_fraction': 0.9885868421534433, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:50:07,313] Trial 494 finished with value: -0.15021553432716372 and parameters: {'learning_rate': 0.2336393710911499, 'lambda_l1': 0.00031471460431088124, 'lambda_l2': 5.558739137609546e-08, 'num_leaves': 243, 'feature_fraction': 0.9323611946383162, 'bagging_fraction': 0.9999855190855195, 'bagging_freq': 3, 'min_child_samples': 36}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:50:15,385] Trial 495 finished with value: -0.14190590127952823 and parameters: {'learning_rate': 0.19955170131352692, 'lambda_l1': 0.0003489114431514685, 'lambda_l2': 2.120097701766118e-08, 'num_leaves': 248, 'feature_fraction': 0.8997825231538945, 'bagging_fraction': 0.9521026849697884, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:50:23,213] Trial 496 finished with value: -0.14167133632187917 and parameters: {'learning_rate': 0.19319485650895604, 'lambda_l1': 0.00022232801272240962, 'lambda_l2': 3.837334791062931e-08, 'num_leaves': 252, 'feature_fraction': 0.9204990849246242, 'bagging_fraction': 0.9753652931764031, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:50:30,490] Trial 497 finished with value: -0.1636335197024037 and parameters: {'learning_rate': 0.23613717051375333, 'lambda_l1': 0.00011398940472898861, 'lambda_l2': 4.832896356793071e-08, 'num_leaves': 256, 'feature_fraction': 0.9232306820736592, 'bagging_fraction': 0.4050228410517842, 'bagging_freq': 5, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:50:38,615] Trial 498 finished with value: -0.14401516372759526 and parameters: {'learning_rate': 0.21612389424131678, 'lambda_l1': 0.00017511215026238747, 'lambda_l2': 5.275611854548757e-07, 'num_leaves': 252, 'feature_fraction': 0.9368788999242255, 'bagging_fraction': 0.9368655246658736, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:50:46,676] Trial 499 finished with value: -0.142002073874259 and parameters: {'learning_rate': 0.19214946858455695, 'lambda_l1': 0.00011355498143935061, 'lambda_l2': 8.18753135402015e-08, 'num_leaves': 256, 'feature_fraction': 0.9155232143702358, 'bagging_fraction': 0.9604619419786949, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:50:54,665] Trial 500 finished with value: -0.1426945442201511 and parameters: {'learning_rate': 0.19529329593238376, 'lambda_l1': 0.0004226904933493562, 'lambda_l2': 1.4967986025599583e-07, 'num_leaves': 249, 'feature_fraction': 0.9248626638273141, 'bagging_fraction': 0.9708985733852161, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:51:02,362] Trial 501 finished with value: -0.15725803485808473 and parameters: {'learning_rate': 0.21760564255586737, 'lambda_l1': 7.818868274069345e-05, 'lambda_l2': 1.0011660420820096e-08, 'num_leaves': 251, 'feature_fraction': 0.9495415027270715, 'bagging_fraction': 0.5372223059228574, 'bagging_freq': 4, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:51:09,972] Trial 502 finished with value: -0.14479934139074976 and parameters: {'learning_rate': 0.2672161717195539, 'lambda_l1': 0.00022387418767478892, 'lambda_l2': 3.892438412303725e-08, 'num_leaves': 242, 'feature_fraction': 0.9392154268697791, 'bagging_fraction': 0.9473946879845245, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:51:17,924] Trial 503 finished with value: -0.14195994698636583 and parameters: {'learning_rate': 0.1809497145439503, 'lambda_l1': 4.856093428632508e-05, 'lambda_l2': 1.8656136948187437e-08, 'num_leaves': 251, 'feature_fraction': 0.9143819334135778, 'bagging_fraction': 0.9767583640493563, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:51:25,643] Trial 504 finished with value: -0.15402246917478574 and parameters: {'learning_rate': 0.24275959227576066, 'lambda_l1': 0.00018555763950626862, 'lambda_l2': 8.970885857916082e-08, 'num_leaves': 246, 'feature_fraction': 0.9297596270560036, 'bagging_fraction': 0.6516704544478735, 'bagging_freq': 5, 'min_child_samples': 11}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:51:34,081] Trial 505 finished with value: -0.14545630266916432 and parameters: {'learning_rate': 0.20599357168485233, 'lambda_l1': 0.00047821728625497515, 'lambda_l2': 3.6096663793348916e-08, 'num_leaves': 227, 'feature_fraction': 0.9100232468711589, 'bagging_fraction': 0.979974755956898, 'bagging_freq': 3, 'min_child_samples': 18}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:51:42,048] Trial 506 finished with value: -0.14610564730919123 and parameters: {'learning_rate': 0.30243563624299574, 'lambda_l1': 0.0002630846030234908, 'lambda_l2': 1.4799406841959441e-08, 'num_leaves': 256, 'feature_fraction': 0.9504908089762966, 'bagging_fraction': 0.9898976726753335, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:51:50,208] Trial 507 finished with value: -0.14166861218417576 and parameters: {'learning_rate': 0.18220281862399137, 'lambda_l1': 0.0005865170278898433, 'lambda_l2': 6.55491319615146e-08, 'num_leaves': 251, 'feature_fraction': 0.8906608125253003, 'bagging_fraction': 0.9641673018815553, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:51:57,864] Trial 508 finished with value: -0.14311843993327822 and parameters: {'learning_rate': 0.17709445458971423, 'lambda_l1': 0.00043903930108776286, 'lambda_l2': 7.111801875148873e-08, 'num_leaves': 234, 'feature_fraction': 0.8872729522856674, 'bagging_fraction': 0.9576280032620804, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:52:02,762] Trial 509 finished with value: -0.1643148500439477 and parameters: {'learning_rate': 0.17915990999185347, 'lambda_l1': 0.0002927759599300858, 'lambda_l2': 5.780293692799609e-08, 'num_leaves': 46, 'feature_fraction': 0.879344248573227, 'bagging_fraction': 0.9878978773149358, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:52:09,021] Trial 510 finished with value: -0.15001134620974604 and parameters: {'learning_rate': 0.16416963639078602, 'lambda_l1': 0.000630965589825913, 'lambda_l2': 4.3030737568084016e-08, 'num_leaves': 116, 'feature_fraction': 0.8957200074112869, 'bagging_fraction': 0.9778895848025425, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:52:16,709] Trial 511 finished with value: -0.1419801151927175 and parameters: {'learning_rate': 0.1920171160355321, 'lambda_l1': 0.0005211260084174716, 'lambda_l2': 2.4490425248015534e-08, 'num_leaves': 240, 'feature_fraction': 0.875215543837603, 'bagging_fraction': 0.9997082537238797, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:52:24,444] Trial 512 finished with value: -0.15574949841787322 and parameters: {'learning_rate': 0.1774483956578863, 'lambda_l1': 0.0009707177940776756, 'lambda_l2': 1.305554644789223e-07, 'num_leaves': 247, 'feature_fraction': 0.8998714985350837, 'bagging_fraction': 0.48574115392012224, 'bagging_freq': 3, 'min_child_samples': 10}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:52:31,734] Trial 513 finished with value: -0.1676789122787996 and parameters: {'learning_rate': 0.5846048813403493, 'lambda_l1': 0.00015008889552110211, 'lambda_l2': 4.883646210983405e-08, 'num_leaves': 256, 'feature_fraction': 0.8891289390011922, 'bagging_fraction': 0.9727808666485687, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:52:40,100] Trial 514 finished with value: -0.14197999760733598 and parameters: {'learning_rate': 0.16081034697867655, 'lambda_l1': 0.0003680143134572931, 'lambda_l2': 2.713451739438638e-08, 'num_leaves': 244, 'feature_fraction': 0.9097270476821079, 'bagging_fraction': 0.9896253838741514, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:52:48,060] Trial 515 finished with value: -0.14140119353616015 and parameters: {'learning_rate': 0.22027872572292317, 'lambda_l1': 0.00021781316159751892, 'lambda_l2': 7.688577028342092e-08, 'num_leaves': 252, 'feature_fraction': 0.9184566965687558, 'bagging_fraction': 0.9997157423924752, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:52:55,618] Trial 516 finished with value: -0.14271256844868194 and parameters: {'learning_rate': 0.23001097230246642, 'lambda_l1': 0.00024032591962213297, 'lambda_l2': 7.551281389912212e-08, 'num_leaves': 237, 'feature_fraction': 0.9010210948443541, 'bagging_fraction': 0.9603521551594876, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:53:05,455] Trial 517 finished with value: -0.15303260210623937 and parameters: {'learning_rate': 0.21930312159598903, 'lambda_l1': 9.220839277340608e-05, 'lambda_l2': 1.707677855864061e-07, 'num_leaves': 248, 'feature_fraction': 0.9153259922880057, 'bagging_fraction': 0.9809457464063306, 'bagging_freq': 3, 'min_child_samples': 52}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:53:13,000] Trial 518 finished with value: -0.14303888158106107 and parameters: {'learning_rate': 0.2570560558756675, 'lambda_l1': 0.00017809953188928365, 'lambda_l2': 9.516746927460892e-08, 'num_leaves': 241, 'feature_fraction': 0.8878922265615131, 'bagging_fraction': 0.9709094790302271, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:53:20,976] Trial 519 finished with value: -0.14130367994440238 and parameters: {'learning_rate': 0.2054985591308306, 'lambda_l1': 0.00030354958628961816, 'lambda_l2': 1.0188153171284569e-07, 'num_leaves': 251, 'feature_fraction': 0.921063941943735, 'bagging_fraction': 0.9890516032740624, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:53:28,796] Trial 520 finished with value: -0.1426527016628817 and parameters: {'learning_rate': 0.2349932628356058, 'lambda_l1': 0.0005204078332891131, 'lambda_l2': 9.57609182116521e-08, 'num_leaves': 245, 'feature_fraction': 0.9047499111669862, 'bagging_fraction': 0.9997740306435697, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:53:37,256] Trial 521 finished with value: -0.1433069582523424 and parameters: {'learning_rate': 0.21633125253914245, 'lambda_l1': 0.0004007590309436957, 'lambda_l2': 1.3323118226151775e-07, 'num_leaves': 230, 'feature_fraction': 0.8678523520600393, 'bagging_fraction': 0.9997578468324589, 'bagging_freq': 3, 'min_child_samples': 11}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:53:45,199] Trial 522 finished with value: -0.14358362491343127 and parameters: {'learning_rate': 0.2465866702043243, 'lambda_l1': 0.0008162719505903058, 'lambda_l2': 6.187454235747027e-08, 'num_leaves': 248, 'feature_fraction': 0.8936398582551618, 'bagging_fraction': 0.9891363573417895, 'bagging_freq': 4, 'min_child_samples': 8}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:53:55,268] Trial 523 finished with value: -0.15319473275923157 and parameters: {'learning_rate': 0.20166433181525498, 'lambda_l1': 0.00030148120437858766, 'lambda_l2': 1.2181120651690192e-07, 'num_leaves': 237, 'feature_fraction': 0.9211148769419987, 'bagging_fraction': 0.987432583987222, 'bagging_freq': 3, 'min_child_samples': 56}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:54:02,938] Trial 524 finished with value: -0.14546318805105402 and parameters: {'learning_rate': 0.2783193151279605, 'lambda_l1': 0.00012353726574365265, 'lambda_l2': 1.844902780827562e-07, 'num_leaves': 243, 'feature_fraction': 0.909820949230449, 'bagging_fraction': 0.9875225369991105, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:54:11,188] Trial 525 finished with value: -0.142311699753775 and parameters: {'learning_rate': 0.21187847152915035, 'lambda_l1': 0.0011779067770235098, 'lambda_l2': 7.888789756238872e-08, 'num_leaves': 252, 'feature_fraction': 0.9300316624737365, 'bagging_fraction': 0.9998195892903187, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:54:19,281] Trial 526 finished with value: -0.14167757043581136 and parameters: {'learning_rate': 0.18743349010861535, 'lambda_l1': 0.0006709846209164517, 'lambda_l2': 6.500538878992621e-08, 'num_leaves': 251, 'feature_fraction': 0.8808366930062352, 'bagging_fraction': 0.9801155654153335, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:54:27,318] Trial 527 finished with value: -0.14399953876951846 and parameters: {'learning_rate': 0.2271704686168028, 'lambda_l1': 0.0003169136784613542, 'lambda_l2': 1.0494578125921047e-07, 'num_leaves': 244, 'feature_fraction': 0.9016389638938338, 'bagging_fraction': 0.9889551019702842, 'bagging_freq': 3, 'min_child_samples': 11}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:54:35,167] Trial 528 finished with value: -0.14238462857073048 and parameters: {'learning_rate': 0.17385904883392778, 'lambda_l1': 0.0007804927151637578, 'lambda_l2': 5.631006035468363e-08, 'num_leaves': 234, 'feature_fraction': 0.9158522359197075, 'bagging_fraction': 0.9668387825530081, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:54:40,349] Trial 529 finished with value: -0.16145283951779305 and parameters: {'learning_rate': 0.19856590987072814, 'lambda_l1': 0.00044884628555392434, 'lambda_l2': 3.4131467799626766e-08, 'num_leaves': 55, 'feature_fraction': 0.9250102045502854, 'bagging_fraction': 0.9797682414152108, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:54:49,367] Trial 530 finished with value: -0.1474797155358246 and parameters: {'learning_rate': 0.16445004463925597, 'lambda_l1': 0.00020509975049165703, 'lambda_l2': 4.5572777401630756e-08, 'num_leaves': 248, 'feature_fraction': 0.8966763976531908, 'bagging_fraction': 0.949130004169171, 'bagging_freq': 4, 'min_child_samples': 27}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:54:58,415] Trial 531 finished with value: -0.14195536456455204 and parameters: {'learning_rate': 0.18684656114771786, 'lambda_l1': 0.0012476532059754655, 'lambda_l2': 1.4858508038498881e-08, 'num_leaves': 252, 'feature_fraction': 0.9363631265535344, 'bagging_fraction': 0.9998030270321421, 'bagging_freq': 3, 'min_child_samples': 13}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:55:05,774] Trial 532 finished with value: -0.14436565352299646 and parameters: {'learning_rate': 0.24167315266905748, 'lambda_l1': 0.00013165591291087228, 'lambda_l2': 2.592975775779973e-08, 'num_leaves': 240, 'feature_fraction': 0.854169153326272, 'bagging_fraction': 0.9684533454373383, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:55:13,760] Trial 533 finished with value: -0.142552975681463 and parameters: {'learning_rate': 0.2071931123415875, 'lambda_l1': 0.0005340453035624924, 'lambda_l2': 2.387159294975994e-07, 'num_leaves': 247, 'feature_fraction': 0.9095897067037002, 'bagging_fraction': 0.9879552744745348, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:55:21,710] Trial 534 finished with value: -0.1514255169981926 and parameters: {'learning_rate': 0.15445886711276546, 'lambda_l1': 0.0002849235924574396, 'lambda_l2': 1.1123015309792897e-07, 'num_leaves': 256, 'feature_fraction': 0.9850951141563711, 'bagging_fraction': 0.5582087517384631, 'bagging_freq': 3, 'min_child_samples': 10}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:55:29,918] Trial 535 finished with value: -0.14138432922208577 and parameters: {'learning_rate': 0.1766729442613269, 'lambda_l1': 0.1013264674733174, 'lambda_l2': 2.0380633980851402e-08, 'num_leaves': 240, 'feature_fraction': 0.8806500734450026, 'bagging_fraction': 0.9785658937332748, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:55:37,706] Trial 536 finished with value: -0.14414528686519937 and parameters: {'learning_rate': 0.26240560305452765, 'lambda_l1': 0.13642400612550884, 'lambda_l2': 1.3426260962433188e-08, 'num_leaves': 231, 'feature_fraction': 0.9209238204570912, 'bagging_fraction': 0.9805784136123893, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:55:44,116] Trial 537 finished with value: -0.1487211417998695 and parameters: {'learning_rate': 0.16557159078745243, 'lambda_l1': 0.05739578967818759, 'lambda_l2': 1.0256509719654587e-08, 'num_leaves': 133, 'feature_fraction': 0.9348169406578095, 'bagging_fraction': 0.9894434036309242, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:55:51,666] Trial 538 finished with value: -0.14196575535487344 and parameters: {'learning_rate': 0.21381563293126396, 'lambda_l1': 0.10434829576102325, 'lambda_l2': 1.957504479859555e-08, 'num_leaves': 227, 'feature_fraction': 0.9064657158568751, 'bagging_fraction': 0.9996884091529842, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:55:58,260] Trial 539 finished with value: -0.1782866174787014 and parameters: {'learning_rate': 0.7063239716351863, 'lambda_l1': 0.07846251213115221, 'lambda_l2': 2.213960693022763e-08, 'num_leaves': 187, 'feature_fraction': 0.880207408516147, 'bagging_fraction': 0.9793746486270949, 'bagging_freq': 3, 'min_child_samples': 11}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:56:04,910] Trial 540 finished with value: -0.16087043281167213 and parameters: {'learning_rate': 0.5216897236857428, 'lambda_l1': 0.04056136563791421, 'lambda_l2': 3.367844820831672e-08, 'num_leaves': 237, 'feature_fraction': 0.9196008084987318, 'bagging_fraction': 0.9884697571085299, 'bagging_freq': 6, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:56:12,783] Trial 541 finished with value: -0.14247776675152315 and parameters: {'learning_rate': 0.18905632993319077, 'lambda_l1': 0.13250126261132095, 'lambda_l2': 1.492635233862494e-08, 'num_leaves': 239, 'feature_fraction': 0.7883420987834825, 'bagging_fraction': 0.9732205116196202, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:56:19,168] Trial 542 finished with value: -0.17002847647502473 and parameters: {'learning_rate': 0.64556409093496, 'lambda_l1': 0.2519423087275828, 'lambda_l2': 2.2920960505109468e-08, 'num_leaves': 234, 'feature_fraction': 0.9090638238303328, 'bagging_fraction': 0.9895304705183249, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:56:27,255] Trial 543 finished with value: -0.1452842020593497 and parameters: {'learning_rate': 0.15160571682635515, 'lambda_l1': 0.07411818939247569, 'lambda_l2': 1.4291930050637609e-08, 'num_leaves': 242, 'feature_fraction': 0.9283820722865858, 'bagging_fraction': 0.8008930653842178, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:56:35,768] Trial 544 finished with value: -0.14337744844824163 and parameters: {'learning_rate': 0.1713255418344131, 'lambda_l1': 6.230174008951968e-05, 'lambda_l2': 3.148871729275387e-08, 'num_leaves': 244, 'feature_fraction': 0.9413685917986103, 'bagging_fraction': 0.960979555310116, 'bagging_freq': 4, 'min_child_samples': 12}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:56:43,355] Trial 545 finished with value: -0.14305624209987833 and parameters: {'learning_rate': 0.22446211033892202, 'lambda_l1': 0.10279389078290284, 'lambda_l2': 2.0470493770377272e-08, 'num_leaves': 239, 'feature_fraction': 0.8929819673607071, 'bagging_fraction': 0.9999931661102358, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:56:51,005] Trial 546 finished with value: -0.14109297216408595 and parameters: {'learning_rate': 0.2014876305310089, 'lambda_l1': 0.00010186054688832367, 'lambda_l2': 4.198703430489366e-08, 'num_leaves': 247, 'feature_fraction': 0.9678251699748159, 'bagging_fraction': 0.975529794507245, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:56:56,058] Trial 547 finished with value: -0.1581808921010774 and parameters: {'learning_rate': 0.2432978550641853, 'lambda_l1': 0.00011074328800999462, 'lambda_l2': 4.565651063864164e-08, 'num_leaves': 66, 'feature_fraction': 0.9669443734681143, 'bagging_fraction': 0.9452590877492658, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:57:04,201] Trial 548 finished with value: -0.14284217127755422 and parameters: {'learning_rate': 0.21278837058396421, 'lambda_l1': 0.0002580440051730996, 'lambda_l2': 1.0875957488459416e-06, 'num_leaves': 248, 'feature_fraction': 0.9846074723799737, 'bagging_fraction': 0.9548460151326236, 'bagging_freq': 7, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:57:12,195] Trial 549 finished with value: -0.1417396963110033 and parameters: {'learning_rate': 0.20643196273611428, 'lambda_l1': 8.869937361555895e-05, 'lambda_l2': 1.7992407369989473e-06, 'num_leaves': 252, 'feature_fraction': 0.9767307124874264, 'bagging_fraction': 0.971952862428693, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:57:20,154] Trial 550 finished with value: -0.1414368562109946 and parameters: {'learning_rate': 0.19420709689726848, 'lambda_l1': 6.98172980171201e-05, 'lambda_l2': 4.2748837198479115e-08, 'num_leaves': 256, 'feature_fraction': 0.9639935631823432, 'bagging_fraction': 0.9694071879154491, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:57:28,010] Trial 551 finished with value: -0.15023998595414653 and parameters: {'learning_rate': 0.22806573414262926, 'lambda_l1': 5.013746083102407e-05, 'lambda_l2': 3.9285757956375514e-08, 'num_leaves': 256, 'feature_fraction': 0.9700905922163978, 'bagging_fraction': 0.6681301597805809, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:57:35,893] Trial 552 finished with value: -0.14286045151729743 and parameters: {'learning_rate': 0.20443600073239693, 'lambda_l1': 9.346301671386797e-05, 'lambda_l2': 1.481146742866403e-08, 'num_leaves': 256, 'feature_fraction': 0.9599932590773568, 'bagging_fraction': 0.9586557126264862, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:57:43,684] Trial 553 finished with value: -0.14475226858352136 and parameters: {'learning_rate': 0.2589419577659678, 'lambda_l1': 5.110616334498263e-05, 'lambda_l2': 2.6382055753821248e-08, 'num_leaves': 252, 'feature_fraction': 0.9850679870793368, 'bagging_fraction': 0.9417850241295619, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:57:51,507] Trial 554 finished with value: -0.1429721143743255 and parameters: {'learning_rate': 0.23687710223354752, 'lambda_l1': 5.0360863812338444e-05, 'lambda_l2': 2.131599151718606e-08, 'num_leaves': 256, 'feature_fraction': 0.9993845180770755, 'bagging_fraction': 0.9684889920113581, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:57:59,695] Trial 555 finished with value: -0.14373058804190458 and parameters: {'learning_rate': 0.186771789608939, 'lambda_l1': 0.00012084761917782233, 'lambda_l2': 1.0067631339949758e-08, 'num_leaves': 247, 'feature_fraction': 0.9750440363787212, 'bagging_fraction': 0.9297204388153077, 'bagging_freq': 3, 'min_child_samples': 8}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:58:06,490] Trial 556 finished with value: -0.14479578180773 and parameters: {'learning_rate': 0.19915500201099195, 'lambda_l1': 0.00013098888816465978, 'lambda_l2': 4.228209049399729e-08, 'num_leaves': 158, 'feature_fraction': 0.9605151274596087, 'bagging_fraction': 0.9819757226201299, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:58:14,605] Trial 557 finished with value: -0.14359416991999552 and parameters: {'learning_rate': 0.22211670036015413, 'lambda_l1': 0.00014732677992086978, 'lambda_l2': 5.143816373931446e-06, 'num_leaves': 251, 'feature_fraction': 0.9720734236741463, 'bagging_fraction': 0.968814401976392, 'bagging_freq': 3, 'min_child_samples': 9}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:58:23,673] Trial 558 finished with value: -0.1458937507184756 and parameters: {'learning_rate': 0.17702222836290435, 'lambda_l1': 9.38163625275095e-05, 'lambda_l2': 1.0093375737859273e-08, 'num_leaves': 244, 'feature_fraction': 0.9583360604737058, 'bagging_fraction': 0.95346328020763, 'bagging_freq': 3, 'min_child_samples': 22}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:58:29,248] Trial 559 finished with value: -0.1539179034370447 and parameters: {'learning_rate': 0.19826704218645888, 'lambda_l1': 6.719558155195237e-05, 'lambda_l2': 2.5902451409795475e-06, 'num_leaves': 86, 'feature_fraction': 0.9532887793720751, 'bagging_fraction': 0.9800294454629761, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:58:37,523] Trial 560 finished with value: -0.14126236674680331 and parameters: {'learning_rate': 0.1562190585696045, 'lambda_l1': 0.18586375289635101, 'lambda_l2': 3.0304763378988765e-08, 'num_leaves': 251, 'feature_fraction': 0.9617012248370786, 'bagging_fraction': 0.989149576654471, 'bagging_freq': 3, 'min_child_samples': 7}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:58:45,703] Trial 561 finished with value: -0.14318261149105999 and parameters: {'learning_rate': 0.2212332197704653, 'lambda_l1': 7.215834964013016e-05, 'lambda_l2': 5.093673442300991e-08, 'num_leaves': 252, 'feature_fraction': 0.9841960632836008, 'bagging_fraction': 0.9883357773566923, 'bagging_freq': 3, 'min_child_samples': 10}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:58:53,689] Trial 562 finished with value: -0.14151387514113267 and parameters: {'learning_rate': 0.17414270163095857, 'lambda_l1': 0.2780493509556366, 'lambda_l2': 3.396993032027692e-08, 'num_leaves': 245, 'feature_fraction': 0.965817078538529, 'bagging_fraction': 0.98936207704968, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# [I 2022-04-14 15:59:02,180] Trial 563 finished with value: -0.142395614707599 and parameters: {'learning_rate': 0.13914038329988937, 'lambda_l1': 0.4886125932705274, 'lambda_l2': 3.882024899067774e-08, 'num_leaves': 247, 'feature_fraction': 0.9705973939528446, 'bagging_fraction': 0.980204187062365, 'bagging_freq': 3, 'min_child_samples': 5}. Best is trial 365 with value: -0.1408362612546663.
# ...
# [I 2022-04-14 17:52:50,145] Trial 1406 finished with value: -0.14157292610074385 and parameters: {'learning_rate': 0.15583781331147742, 'lambda_l1': 2.1610299828091573e-07, 'lambda_l2': 1.944297457390926, 'num_leaves': 231, 'feature_fraction': 0.8246695059044974, 'bagging_fraction': 0.9889488843765537, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:52:58,368] Trial 1407 finished with value: -0.1422270924430604 and parameters: {'learning_rate': 0.18509171957805332, 'lambda_l1': 9.180203539305522e-07, 'lambda_l2': 0.9051648251171951, 'num_leaves': 236, 'feature_fraction': 0.8115382724031462, 'bagging_fraction': 0.9811300186852805, 'bagging_freq': 2, 'min_child_samples': 7}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:53:03,244] Trial 1408 finished with value: -0.15025056963915012 and parameters: {'learning_rate': 0.16350551140586178, 'lambda_l1': 1.0022911923048248e-07, 'lambda_l2': 0.04891021012061755, 'num_leaves': 110, 'feature_fraction': 0.8169706440020796, 'bagging_fraction': 0.9896213161013001, 'bagging_freq': 1, 'min_child_samples': 5}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:53:10,372] Trial 1409 finished with value: -0.15792865514747842 and parameters: {'learning_rate': 0.5582540925977999, 'lambda_l1': 4.274423615934845e-07, 'lambda_l2': 3.928234341801853, 'num_leaves': 211, 'feature_fraction': 0.797948478774971, 'bagging_fraction': 0.9995822148826413, 'bagging_freq': 2, 'min_child_samples': 8}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:53:18,672] Trial 1410 finished with value: -0.14223915524992775 and parameters: {'learning_rate': 0.18966004597877417, 'lambda_l1': 7.187744861435617e-08, 'lambda_l2': 2.2802694842786577, 'num_leaves': 228, 'feature_fraction': 0.8426900349765385, 'bagging_fraction': 0.970829647318002, 'bagging_freq': 2, 'min_child_samples': 7}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:53:29,625] Trial 1411 finished with value: -0.1520374949431193 and parameters: {'learning_rate': 0.14469469241430527, 'lambda_l1': 1.5745207687496278e-07, 'lambda_l2': 0.5430341648411526, 'num_leaves': 237, 'feature_fraction': 0.8393721278636656, 'bagging_fraction': 0.9999233613110028, 'bagging_freq': 2, 'min_child_samples': 89}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:53:37,158] Trial 1412 finished with value: -0.16636882549269696 and parameters: {'learning_rate': 0.6505613287962233, 'lambda_l1': 1.049005721927494e-08, 'lambda_l2': 3.4076640397503817, 'num_leaves': 223, 'feature_fraction': 0.7755951627405004, 'bagging_fraction': 0.9996550519202564, 'bagging_freq': 2, 'min_child_samples': 10}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:53:45,285] Trial 1413 finished with value: -0.14178352626669735 and parameters: {'learning_rate': 0.1771911216518169, 'lambda_l1': 4.554900549892046e-08, 'lambda_l2': 1.2975288179523832, 'num_leaves': 231, 'feature_fraction': 0.8184777153876388, 'bagging_fraction': 0.9819629232884483, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:53:53,749] Trial 1414 finished with value: -0.14149520781832775 and parameters: {'learning_rate': 0.19763546423315842, 'lambda_l1': 2.061718701853562e-07, 'lambda_l2': 4.9429364545899785, 'num_leaves': 238, 'feature_fraction': 0.8466152368063613, 'bagging_fraction': 0.9641219444546707, 'bagging_freq': 2, 'min_child_samples': 9}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:54:02,007] Trial 1415 finished with value: -0.14275038077648014 and parameters: {'learning_rate': 0.16267517756320102, 'lambda_l1': 6.811412494428322e-07, 'lambda_l2': 2.2496379436168663, 'num_leaves': 218, 'feature_fraction': 0.8633353523381809, 'bagging_fraction': 0.9794813269959664, 'bagging_freq': 2, 'min_child_samples': 7}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:54:08,486] Trial 1416 finished with value: -0.15055879679354112 and parameters: {'learning_rate': 0.5119690573983282, 'lambda_l1': 1.2074672799180356e-07, 'lambda_l2': 4.905160372182383, 'num_leaves': 149, 'feature_fraction': 0.8720511117591664, 'bagging_fraction': 0.9995268200245508, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:54:15,348] Trial 1417 finished with value: -0.14264934781214378 and parameters: {'learning_rate': 0.12960016705591013, 'lambda_l1': 8.467448710553227e-08, 'lambda_l2': 3.011583167831403, 'num_leaves': 239, 'feature_fraction': 0.8103967380122309, 'bagging_fraction': 0.9881996076897906, 'bagging_freq': 1, 'min_child_samples': 7}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:54:23,885] Trial 1418 finished with value: -0.14250719617851212 and parameters: {'learning_rate': 0.18554807980718768, 'lambda_l1': 2.2682439819072047e-08, 'lambda_l2': 6.08182700492943, 'num_leaves': 233, 'feature_fraction': 0.7982658671890555, 'bagging_fraction': 0.9704662161553879, 'bagging_freq': 2, 'min_child_samples': 11}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:54:32,325] Trial 1419 finished with value: -0.14266111590960417 and parameters: {'learning_rate': 0.19912949918830655, 'lambda_l1': 2.8261550694633584e-07, 'lambda_l2': 1.6682442486359503, 'num_leaves': 227, 'feature_fraction': 0.8981496823260255, 'bagging_fraction': 0.9890171090297091, 'bagging_freq': 2, 'min_child_samples': 9}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:54:41,022] Trial 1420 finished with value: -0.14100621104139546 and parameters: {'learning_rate': 0.16619163523583305, 'lambda_l1': 5.464813037836473e-08, 'lambda_l2': 3.9387623053584897, 'num_leaves': 240, 'feature_fraction': 0.8532372732890442, 'bagging_fraction': 0.9994189378680375, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:54:49,095] Trial 1421 finished with value: -0.14186921299838806 and parameters: {'learning_rate': 0.14025646061305932, 'lambda_l1': 1.0594263713778662e-07, 'lambda_l2': 2.3571167464649934, 'num_leaves': 233, 'feature_fraction': 0.8357222615171862, 'bagging_fraction': 0.9999921709253686, 'bagging_freq': 2, 'min_child_samples': 7}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:54:57,459] Trial 1422 finished with value: -0.14111504825000293 and parameters: {'learning_rate': 0.2027258769912641, 'lambda_l1': 6.868161248781447e-08, 'lambda_l2': 6.537191489790791, 'num_leaves': 241, 'feature_fraction': 0.8751886705520732, 'bagging_fraction': 0.9810733570710337, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:55:05,305] Trial 1423 finished with value: -0.14232728043426277 and parameters: {'learning_rate': 0.1790072169708565, 'lambda_l1': 3.4822085627300534e-08, 'lambda_l2': 1.0676923130986613, 'num_leaves': 225, 'feature_fraction': 0.8951940481182998, 'bagging_fraction': 0.9999858409606528, 'bagging_freq': 2, 'min_child_samples': 9}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:55:14,965] Trial 1424 finished with value: -0.14994831744497344 and parameters: {'learning_rate': 0.1490177276513163, 'lambda_l1': 2.3190464702258351e-07, 'lambda_l2': 3.8593964130987506, 'num_leaves': 237, 'feature_fraction': 0.830865458156815, 'bagging_fraction': 0.9999709391771094, 'bagging_freq': 2, 'min_child_samples': 57}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:55:20,870] Trial 1425 finished with value: -0.16153210142742036 and parameters: {'learning_rate': 0.5925929573857108, 'lambda_l1': 1.507448020179351e-07, 'lambda_l2': 1.7901089669677348, 'num_leaves': 230, 'feature_fraction': 0.8530642631403569, 'bagging_fraction': 0.9710970567997548, 'bagging_freq': 1, 'min_child_samples': 7}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:55:28,738] Trial 1426 finished with value: -0.14146243561387545 and parameters: {'learning_rate': 0.2132891347734147, 'lambda_l1': 1.4786212839449158e-07, 'lambda_l2': 3.0488217904755888, 'num_leaves': 242, 'feature_fraction': 0.8134273321128332, 'bagging_fraction': 0.9525229927334273, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:55:38,828] Trial 1427 finished with value: -0.15276368139991792 and parameters: {'learning_rate': 0.18729183130353882, 'lambda_l1': 2.2789909499112465e-08, 'lambda_l2': 0.015179266949675804, 'num_leaves': 236, 'feature_fraction': 0.8651270843763458, 'bagging_fraction': 0.9818222264536787, 'bagging_freq': 2, 'min_child_samples': 61}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:55:48,245] Trial 1428 finished with value: -0.14431450783133462 and parameters: {'learning_rate': 0.11572977951298741, 'lambda_l1': 4.871620862682034e-08, 'lambda_l2': 9.887351725198885, 'num_leaves': 242, 'feature_fraction': 0.8805739732651183, 'bagging_fraction': 0.9615498368875803, 'bagging_freq': 2, 'min_child_samples': 11}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:55:56,885] Trial 1429 finished with value: -0.14173262129448172 and parameters: {'learning_rate': 0.1742237837656269, 'lambda_l1': 3.1553710689847195e-07, 'lambda_l2': 6.907053866021675, 'num_leaves': 229, 'feature_fraction': 0.841524972787909, 'bagging_fraction': 0.9884014635906276, 'bagging_freq': 2, 'min_child_samples': 8}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:56:05,134] Trial 1430 finished with value: -0.1414922703957801 and parameters: {'learning_rate': 0.2268851897053119, 'lambda_l1': 5.318088752465944e-07, 'lambda_l2': 4.5259503681125794, 'num_leaves': 233, 'feature_fraction': 0.8482571244194876, 'bagging_fraction': 0.9799954795277518, 'bagging_freq': 2, 'min_child_samples': 7}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:56:13,428] Trial 1431 finished with value: -0.1407756527350527 and parameters: {'learning_rate': 0.20126581986736936, 'lambda_l1': 9.304438678778313e-08, 'lambda_l2': 2.3597852975779636, 'num_leaves': 242, 'feature_fraction': 0.8606643145184395, 'bagging_fraction': 0.9734095907910024, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:56:22,824] Trial 1432 finished with value: -0.15162031781671176 and parameters: {'learning_rate': 0.0727078005444549, 'lambda_l1': 2.079649213972925e-07, 'lambda_l2': 1.3235290686813235, 'num_leaves': 221, 'feature_fraction': 0.8897865013275655, 'bagging_fraction': 0.9998738733939244, 'bagging_freq': 2, 'min_child_samples': 9}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:56:29,732] Trial 1433 finished with value: -0.14133809722035182 and parameters: {'learning_rate': 0.15877973631831227, 'lambda_l1': 3.160867228505044e-08, 'lambda_l2': 3.547918803976341, 'num_leaves': 236, 'feature_fraction': 0.8734467067579397, 'bagging_fraction': 0.9887754556415125, 'bagging_freq': 1, 'min_child_samples': 7}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:56:37,870] Trial 1434 finished with value: -0.1410457069388668 and parameters: {'learning_rate': 0.18714210706217388, 'lambda_l1': 6.314471478699756e-08, 'lambda_l2': 5.133759328654803, 'num_leaves': 227, 'feature_fraction': 0.8286207853845782, 'bagging_fraction': 0.988363451300157, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:56:45,674] Trial 1435 finished with value: -0.14329637986866509 and parameters: {'learning_rate': 0.2146431202378776, 'lambda_l1': 1.3481385609106069e-07, 'lambda_l2': 2.1739373572637652, 'num_leaves': 214, 'feature_fraction': 0.8645322928996405, 'bagging_fraction': 0.9999991121866266, 'bagging_freq': 2, 'min_child_samples': 12}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:56:54,135] Trial 1436 finished with value: -0.1415735159550564 and parameters: {'learning_rate': 0.16778942307437447, 'lambda_l1': 8.561387670571933e-08, 'lambda_l2': 0.8023207309336361, 'num_leaves': 242, 'feature_fraction': 0.8837617671789733, 'bagging_fraction': 0.9640691818605841, 'bagging_freq': 2, 'min_child_samples': 7}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:57:02,955] Trial 1437 finished with value: -0.14345323540950403 and parameters: {'learning_rate': 0.14275148081596853, 'lambda_l1': 3.3673627235549095e-07, 'lambda_l2': 2.7378908342974735, 'num_leaves': 234, 'feature_fraction': 0.8484494844329107, 'bagging_fraction': 0.9803305237552811, 'bagging_freq': 2, 'min_child_samples': 9}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:57:09,311] Trial 1438 finished with value: -0.14192067605924782 and parameters: {'learning_rate': 0.24290730196336724, 'lambda_l1': 1.3869656958348415e-08, 'lambda_l2': 6.677572864359368, 'num_leaves': 223, 'feature_fraction': 0.8967681565366782, 'bagging_fraction': 0.9867390725307195, 'bagging_freq': 1, 'min_child_samples': 5}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:57:17,585] Trial 1439 finished with value: -0.14124989508110936 and parameters: {'learning_rate': 0.20253946873776774, 'lambda_l1': 4.0182423716285313e-08, 'lambda_l2': 3.863633272156715, 'num_leaves': 237, 'feature_fraction': 0.8653727691762167, 'bagging_fraction': 0.9739807463443014, 'bagging_freq': 2, 'min_child_samples': 7}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:57:25,411] Trial 1440 finished with value: -0.15147345489845912 and parameters: {'learning_rate': 0.1846120627218557, 'lambda_l1': 1.7490548988308735e-07, 'lambda_l2': 1.531752767074086, 'num_leaves': 230, 'feature_fraction': 0.8225179926959252, 'bagging_fraction': 0.5451814816093271, 'bagging_freq': 2, 'min_child_samples': 9}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:57:34,258] Trial 1441 finished with value: -0.14196951503439587 and parameters: {'learning_rate': 0.16204124446031132, 'lambda_l1': 1.1347239769334043e-07, 'lambda_l2': 9.848302371859619, 'num_leaves': 243, 'feature_fraction': 0.8350947436630075, 'bagging_fraction': 0.9892813024048357, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:57:42,351] Trial 1442 finished with value: -0.14132996700976722 and parameters: {'learning_rate': 0.2152660673120499, 'lambda_l1': 7.411848983283811e-08, 'lambda_l2': 4.852138011930843, 'num_leaves': 238, 'feature_fraction': 0.7976815158112475, 'bagging_fraction': 0.9999545372924368, 'bagging_freq': 2, 'min_child_samples': 7}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:57:50,411] Trial 1443 finished with value: -0.1455825129089667 and parameters: {'learning_rate': 0.23610771811834075, 'lambda_l1': 3.7116570613644546e-07, 'lambda_l2': 1.9520737810171886, 'num_leaves': 232, 'feature_fraction': 0.7792243150874264, 'bagging_fraction': 0.8789541895871222, 'bagging_freq': 2, 'min_child_samples': 10}. Best is trial 1258 with value: -0.14020015220675125.
# [I 2022-04-14 17:57:58,404] Trial 1444 finished with value: -0.14728281437721402 and parameters: {'learning_rate': 0.12738865555316575, 'lambda_l1': 2.159001779410054e-07, 'lambda_l2': 2.9785633736983534, 'num_leaves': 242, 'feature_fraction': 0.8540285878160775, 'bagging_fraction': 0.6059844751087395, 'bagging_freq': 2, 'min_child_samples': 5}. Best is trial 1258 with value: -0.14020015220675125.

# %%
study.best_params
# Out:
# {'bagging_fraction': 0.9079273070338828,
#  'bagging_freq': 4,
#  'feature_fraction': 0.716472706585253,
#  'lambda_l1': 0.0007127314011370048,
#  'lambda_l2': 1.4991431139899208e-08,
#  'learning_rate': 0.24273738931459424,
#  'min_child_samples': 27,
#  'num_leaves': 129}

# %% [markdown]
# #### Version 1

# %%
lightgbm_optuned = LGBMRegressor(
    **{
        "bagging_fraction": 0.9079273070338828,
        "bagging_freq": 4,
        "feature_fraction": 0.716472706585253,
        "lambda_l1": 0.0007127314011370048,
        "lambda_l2": 1.4991431139899208e-08,
        "learning_rate": 0.24273738931459424,
        "min_child_samples": 27,
        "num_leaves": 129,
        "random_state": 42,
        "silent": True,
    }
).fit(X_train, y_train)

print("lightgbm_optuned", mean_absolute_percentage_error(y_valid, lightgbm_optuned.predict(X_valid)))
submit(test, lightgbm_optuned, "lightgbm_optuned")
# Out:
# [LightGBM] [Warning] lambda_l1 is set=0.0007127314011370048, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0007127314011370048
# [LightGBM] [Warning] bagging_fraction is set=0.9079273070338828, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9079273070338828
# [LightGBM] [Warning] feature_fraction is set=0.716472706585253, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.716472706585253
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] lambda_l2 is set=1.4991431139899208e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=1.4991431139899208e-08
# lightgbm_optuned 0.1562352982059385

# %% [markdown]
# #### Version 2

# %%
lightgbm_optuned_1899 = LGBMRegressor(
    **{
        'learning_rate': 0.2200394016092361, 
        'lambda_l1': 3.6405456215002115e-08, 
        'lambda_l2': 3.9256724979441087, 
        'num_leaves': 251, 
        'feature_fraction': 0.7849386830734889, 
        'bagging_fraction': 0.999471799816821, 
        'bagging_freq': 7, 
        'min_child_samples': 5, 
        "random_state": 42,
        "silent": True
    }
).fit(X_train, np.log(y_train))

print("lightgbm_optuned_1899_log", mean_absolute_percentage_error(y_valid, np.exp(lightgbm_optuned_1899.predict(X_valid))))
submit_log(test, lightgbm_optuned_1899, "lightgbm_optuned_log_1899")
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.7849386830734889, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7849386830734889
# [LightGBM] [Warning] lambda_l1 is set=3.6405456215002115e-08, reg_alpha=0.0 will be ignored. Current value: lambda_l1=3.6405456215002115e-08
# [LightGBM] [Warning] bagging_fraction is set=0.999471799816821, subsample=1.0 will be ignored. Current value: bagging_fraction=0.999471799816821
# [LightGBM] [Warning] lambda_l2 is set=3.9256724979441087, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.9256724979441087
# [LightGBM] [Warning] bagging_freq is set=7, subsample_freq=0 will be ignored. Current value: bagging_freq=7
# lightgbm_optuned_1899_log 0.1266083430966481

# %% [markdown]
# #### Version 3

# %%
lightgbm_optuned_1258 = LGBMRegressor(
    **{
        'learning_rate': 0.2034225924278744, 
        'lambda_l1': 1.6905457446408715e-07, 
        'lambda_l2': 3.410817513919556, 
        'num_leaves': 237, 
        'feature_fraction': 0.8139002011435048, 
        'bagging_fraction': 0.9996914517711281, 
        'bagging_freq': 2, 
        'min_child_samples': 5
    }
).fit(X_train, np.log(y_train))

print("lightgbm_optuned_1258_log", mean_absolute_percentage_error(y_valid, np.exp(lightgbm_optuned_1258.predict(X_valid))))
submit_log(test, lightgbm_optuned_1258, "lightgbm_optuned_log_1258")
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.8139002011435048, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8139002011435048
# [LightGBM] [Warning] lambda_l1 is set=1.6905457446408715e-07, reg_alpha=0.0 will be ignored. Current value: lambda_l1=1.6905457446408715e-07
# [LightGBM] [Warning] bagging_fraction is set=0.9996914517711281, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9996914517711281
# [LightGBM] [Warning] lambda_l2 is set=3.410817513919556, reg_lambda=0.0 will be ignored. Current value: lambda_l2=3.410817513919556
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# lightgbm_optuned_1258_log 0.12681490786747857
