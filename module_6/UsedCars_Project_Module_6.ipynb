# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException

from tqdm import tqdm

import re
import time
import json

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
test_data = pd.read_pickle("data/test.pkl.zip", compression="zip")

# %%
test_data.iloc[12561]['description']
# Out:
# 'Машина в отличном состоянии!!17.10.2020 было сделано Т.О заменено масло в коробке передач в двигателе,так же заменены все фильтра.Почти максимальная комплектация кроме люка!!! Без ключевой доступ. В ДТП не была не билась.Красился капот и передний бампер так как от времени были сколы.Капот фары туманки затянуты броне пленкой.Делали для себя супруга не ездит вся причина продажи.. Новая летняя резина. Продаю не спеша. '

# %%
valid_data = pd.DataFrame()
catalog_data = pd.DataFrame()

# %%
test_data['bodyType'].unique()
# Out:
# array(['лифтбек', 'внедорожник 5 дв.', 'хэтчбек 5 дв.', 'седан',
#        'компактвэн', 'универсал 5 дв.', 'пикап одинарная кабина',
#        'хэтчбек 3 дв.', 'купе', 'кабриолет', 'минивэн',
#        'пикап двойная кабина', 'внедорожник 3 дв.', 'родстер', 'микровэн',
#        'седан 2 дв.', 'купе-хардтоп', 'фастбек', 'тарга',
#        'внедорожник открытый', 'лимузин', 'пикап полуторная кабина',
#        'седан-хардтоп', 'фургон'], dtype=object)

# %%
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
# driver = webdriver.Chrome("./chromedriver", options=options)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 99.0.4844
# Get LATEST chromedriver version for 99.0.4844 google-chrome
# Driver [/home/user/.wdm/drivers/chromedriver/linux64/99.0.4844.51/chromedriver] found in cache

# %%
regions = ["leningradskaya_oblast", "moskovskaya_oblast"]
models = [
    "skoda",
    "audi",
    "honda",
    "volvo",
    "bmw",
    "nissan",
    "infiniti",
    "mercedes",
    "toyota",
    "lexus",
    "volkswagen",
    "mitsubishi",
]

# %%
urls_list = []

# %%
def get_urls_for_model_in_region(model, region):
    
    result_list = []
    cnt = True
    page_num = 1
    
    while cnt is True:
        try:
            driver.get(f'https://auto.ru/{region}/cars/{model}/used/?page={page_num}')
            next_page = driver.find_element(By.CLASS_NAME, 'ListingItemTitle__link')
            page_links = driver.find_elements(By.CLASS_NAME, 'ListingItemTitle__link')

            for item in page_links:
                result_list.append(item.get_attribute('href'))
            print(f'Parsing {page_num} page for {model} in {region}', end='\r')
            page_num += 1
        except NoSuchElementException:
            cnt = False
            print()
            print(f'There are {page_num} pages by {model}')
    
    return result_list

# %%
def get_car_info(url):
        
    driver.get(url)
    
    year = int(driver.find_element(By.CLASS_NAME, 'CardInfoRow_year').text.split('\n')[1])
    
    car = driver.find_elements(By.CLASS_NAME,'CardBreadcrumbs__itemText')
    brand = car[3].text
    model = car[4].text
    
    car_url = url
    
    bodytype = driver.find_element(By.CLASS_NAME, 'CardInfoRow_bodytype').text.split('\n')[1]
    kmage = int(re.sub('\D', '', driver.find_element(By.CLASS_NAME, 'CardInfoRow_kmAge').text))
    color = driver.find_element(By.CLASS_NAME, 'CardInfoRow_color').text.split('\n')[1]
    
    engine = driver.find_element(By.CLASS_NAME, 'CardInfoRow_engine').text.split('/')
    engineDisplacement = float(re.findall('(\d+.\d+)', engine[0])[0])
    enginePower = int(re.findall('\d+', engine[1])[0])
    fuelType = engine[2]
    
    super_gen = json.loads(driver.find_element(By.ID, 'sale-data-attributes').get_attribute('data-bem'))['sale-data-attributes']
    
    vehicleTransmission = driver.find_element(By.CLASS_NAME, 'CardInfoRow_transmission').text.split('\n')[1]
    drive = driver.find_element(By.CLASS_NAME, 'CardInfoRow_drive').text.split('\n')[1]
    wheel = driver.find_element(By.CLASS_NAME, 'CardInfoRow_wheel').text.split('\n')[1]
    state = driver.find_element(By.CLASS_NAME, 'CardInfoRow_state').text.split('\n')[1]
    owner = driver.find_element(By.CLASS_NAME, 'CardInfoRow_ownersCount').text.split('\n')[1]
    pts = driver.find_element(By.CLASS_NAME, 'CardInfoRow_pts').text.split('\n')[1]
    customs = driver.find_element(By.CLASS_NAME, 'CardInfoRow_customs').text.split('\n')[1]
    
    try:
        owningTime = driver.find_element(By.CLASS_NAME, 'CardInfoRow_owningTime').text.split('\n')[1]
    except NoSuchElementException:
        owningTime = None
    
    try:
        description = driver.find_element(By.CLASS_NAME, 'CardDescriptionHTML').text
    except NoSuchElementException:
        description = None
    
    sell_id = int(re.findall('\d+', driver.find_element(By.CLASS_NAME, 'CardHead__id').text)[0])
    price = int(re.sub('\D', '', driver.find_element(By.CLASS_NAME, 'OfferPriceCaption__price').text))
    
    complect_list = []
    
    complect_data = driver.find_elements(By.CLASS_NAME, 'ComplectationGroupsDesktop__itemList')

    for item in complect_data:
        complect_list.extend(item.text.replace('\n', '').split('•')[1:])
    
    catalog_url = driver.find_element(By.CLASS_NAME, 'CardCatalogLink').get_attribute('href')
    
    data_dict = {
        'brand': brand, 'model': model, 'year': year, 'bodytype': bodytype, 'kmage': kmage,
        'color': color, 'engineDisplacement': engineDisplacement, 'enginePower': enginePower, 
        'fuelType': fuelType, 'super_gen': super_gen, 'vehicleTransmission': vehicleTransmission,
        'drive': drive, 'wheel': wheel, 'state': state, 'owner': owner, 'pts': pts, 'customs': customs, 
        'owningTime': owningTime, 'description': description, 'sell_id': sell_id, 'price': price, 
        'car_url': car_url, 'catalog_url': catalog_url, 'equipment_dict': complect_list
    }
    
    return data_dict

# %%
def get_dicts_from_catalog(url):
    
    driver.get(url)

    car_info_full = driver.find_elements(By.CLASS_NAME, 'list-values')
    
    car_info_dict_ru = {}
    
    for item in car_info_full:
        el = item.text.split('\n')
        for i in range(0, len(el) - 1, 2):
            car_info_dict_ru[el[i]] = el[i + 1]
    
    engine_type_dict = {'бензин': 'GASOLINE', 'дизель': 'DIESEL', 
                        'гибрид': 'HYBRID', 'электро': 'ELECTRO', 'газ': 'LPG'}
    gear_type_dict = {'передний': 'FORWARD_CONTROL', 'полный': 'ALL_WHEEL_DRIVE', 'задний': 'REAR_DRIVE'}
    transmission_dict = {'автомат': 'AUTOMATIC', 'робот': 'ROBOT', 
                         'механика': 'MECHANICAL', 'вариатор': 'VARIATOR'}

    car_info_dict_en = {
        'engine_type': engine_type_dict[car_info_dict_ru['Тип двигателя']],
        'gear_type': gear_type_dict[car_info_dict_ru['Привод']],
        'transmission': transmission_dict[car_info_dict_ru['Коробка']],
        'power': int(re.findall('\d+', car_info_dict_ru['Мощность'])[0]),
        'power_kvt': int(re.findall('\d+', car_info_dict_ru['Максимальная мощность, л.с./кВт при об/мин'])[1]),
        'acceleration': car_info_dict_ru.get('Разгон до 100 км/ч, с'),
        'clearance_min': min(map(int, re.findall('\d+', car_info_dict_ru['Клиренс']))),
        'fuel_rate': float(car_info_dict_ru['Расход топлива, л город/трасса/смешанный'].split('/')[2])
    }
    
    url2 = url.replace('specifications', 'equipment')
    
    driver.get(url2)

    equipment_list = []

    equipment_data = driver.find_elements(By.CLASS_NAME, 'catalog__package-list-i')
    for item in equipment_data:
        equipment_list.append(item.text)
    
    car_data = json.loads(driver.find_element(By.CLASS_NAME, 'search-form-v2-mmm').get_attribute('data-bem'))
    equip_data = json.loads(driver.find_element(By.CLASS_NAME, 'catalog__section').get_attribute('data-bem'))
    attrib_data = json.loads(driver.find_element(By.CLASS_NAME, 'sale-data-attributes').get_attribute('data-bem'))
    
    return {'super_gen_2': car_info_dict_en, 'super_gen_3': attrib_data, 'complectation_dict': equipment_list}

# %% [markdown]
# ## Gathering URLs from MODEL pages in Regions

# %%
# %%time
all_urls = []
from time import sleep
from random import randint

i = 0
for region in regions:
    for model in models:
        print(f"{i+1} Processing {model} from {region}")
        sleep(randint(30, 70)/100.)
        model_urls = get_urls_for_model_in_region(model, region)
        all_urls.append(model_urls)
        i += 1
# Out:
# 1 Processing skoda from leningradskaya_oblast
# Parsing 23 page for skoda in leningradskaya_oblast
# There are 24 pages by skoda
# 2 Processing audi from leningradskaya_oblast
# Parsing 21 page for audi in leningradskaya_oblast
# There are 22 pages by audi
# 3 Processing honda from leningradskaya_oblast
# Parsing 6 page for honda in leningradskaya_oblast
# There are 7 pages by honda
# 4 Processing volvo from leningradskaya_oblast
# Parsing 9 page for volvo in leningradskaya_oblast
# There are 10 pages by volvo
# 5 Processing bmw from leningradskaya_oblast
# Parsing 37 page for bmw in leningradskaya_oblast
# There are 38 pages by bmw
# 6 Processing nissan from leningradskaya_oblast
# Parsing 20 page for nissan in leningradskaya_oblast
# There are 21 pages by nissan
# 7 Processing infiniti from leningradskaya_oblast
# Parsing 3 page for infiniti in leningradskaya_oblast
# There are 4 pages by infiniti
# 8 Processing mercedes from leningradskaya_oblast
# Parsing 35 page for mercedes in leningradskaya_oblast
# There are 36 pages by mercedes
# 9 Processing toyota from leningradskaya_oblast
# Parsing 21 page for toyota in leningradskaya_oblast
# There are 22 pages by toyota
# 10 Processing lexus from leningradskaya_oblast
# Parsing 5 page for lexus in leningradskaya_oblast
# There are 6 pages by lexus
# 11 Processing volkswagen from leningradskaya_oblast
# Parsing 34 page for volkswagen in leningradskaya_oblast
# There are 35 pages by volkswagen
# 12 Processing mitsubishi from leningradskaya_oblast
# Parsing 16 page for mitsubishi in leningradskaya_oblast
# There are 17 pages by mitsubishi
# 13 Processing skoda from moskovskaya_oblast
# Parsing 62 page for skoda in moskovskaya_oblast
# There are 63 pages by skoda
# 14 Processing audi from moskovskaya_oblast
# Parsing 67 page for audi in moskovskaya_oblast
# There are 68 pages by audi
# 15 Processing honda from moskovskaya_oblast
# Parsing 19 page for honda in moskovskaya_oblast
# There are 20 pages by honda
# 16 Processing volvo from moskovskaya_oblast
# Parsing 27 page for volvo in moskovskaya_oblast
# There are 28 pages by volvo
# 17 Processing bmw from moskovskaya_oblast
# Parsing 1024 page for bmw in moskovskaya_oblast
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# File <timed exec>:10, in <module>
#
# Input In [10], in get_urls_for_model_in_region(model, region)
#       9 driver.get(f'https://auto.ru/{region}/cars/{model}/used/?page={page_num}')
#      10 next_page = driver.find_element(By.CLASS_NAME, 'ListingItemTitle__link')
# ---> 11 page_links = driver.find_elements(By.CLASS_NAME, 'ListingItemTitle__link')
#      13 for item in page_links:
#      14     result_list.append(item.get_attribute('href'))
#
# File ~/Documents/sf_project_6/venv/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:1283, in WebDriver.find_elements(self, by, value)
#    1279     value = '[name="%s"]' % value
#    1281 # Return empty list if driver returns null
#    1282 # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1283 return self.execute(Command.FIND_ELEMENTS, {
#    1284     'using': by,
#    1285     'value': value})['value'] or []
#
# File ~/Documents/sf_project_6/venv/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:425, in WebDriver.execute(self, driver_command, params)
#     423 response = self.command_executor.execute(driver_command, params)
#     424 if response:
# --> 425     self.error_handler.check_response(response)
#     426     response['value'] = self._unwrap_value(
#     427         response.get('value', None))
#     428     return response
#
# File ~/Documents/sf_project_6/venv/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=99.0.4844.82)
# Stacktrace:
# #0 0x5645859d87d3 <unknown>
# #1 0x564585734688 <unknown>
# #2 0x5645857143ec <unknown>
# #3 0x56458578bc9b <unknown>
# #4 0x56458579b0c5 <unknown>
# #5 0x5645857885a3 <unknown>
# #6 0x56458575dddc <unknown>
# #7 0x56458575ede5 <unknown>
# #8 0x564585a0949d <unknown>
# #9 0x564585a2260c <unknown>
# #10 0x564585a0b205 <unknown>
# #11 0x564585a22ee5 <unknown>
# #12 0x5645859ff070 <unknown>
# #13 0x564585a3e488 <unknown>
# #14 0x564585a3e60c <unknown>
# #15 0x564585a57c6d <unknown>
# #16 0x7f2338c0ab1a <unknown>

# %% [markdown]
# ## How many cars of each model do we need to parse?

# %%
with open("data/20220326_urls.json", "w") as f:
    f.write(json.dumps(all_urls, indent=0))

# %% [markdown]
# ## Getting main car info

# %%
for url in tqdm(model_spb_urls):
    try:
        valid_data = valid_data.append(get_car_info(url), ignore_index=True)
    except NoSuchElementException:
        print('Error 404', end='\r')
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#   1%|          | 1/101 [00:19<32:52, 19.73s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#   2%|▏         | 2/101 [00:28<21:51, 13.25s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#   3%|▎         | 3/101 [00:34<15:55,  9.75s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#   4%|▍         | 4/101 [00:54<22:19, 13.81s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#   5%|▍         | 5/101 [01:04<19:54, 12.45s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#   6%|▌         | 6/101 [01:13<17:50, 11.27s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#   7%|▋         | 7/101 [01:24<17:30, 11.18s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#   8%|▊         | 8/101 [01:34<16:43, 10.79s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#   9%|▉         | 9/101 [01:45<17:05, 11.15s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  10%|▉         | 10/101 [02:00<18:41, 12.33s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  11%|█         | 11/101 [02:16<20:05, 13.40s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  12%|█▏        | 12/101 [02:22<16:17, 10.98s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  13%|█▎        | 13/101 [02:26<13:00,  8.87s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  14%|█▍        | 14/101 [02:30<10:54,  7.52s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  15%|█▍        | 15/101 [02:34<09:18,  6.50s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  16%|█▌        | 16/101 [02:39<08:15,  5.84s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  17%|█▋        | 17/101 [02:46<08:42,  6.22s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  18%|█▊        | 18/101 [02:53<09:07,  6.60s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  19%|█▉        | 19/101 [02:58<08:28,  6.20s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  20%|█▉        | 20/101 [03:05<08:32,  6.33s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  21%|██        | 21/101 [03:10<07:59,  5.99s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  22%|██▏       | 22/101 [03:25<11:25,  8.67s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  23%|██▎       | 23/101 [03:44<15:10, 11.67s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  24%|██▍       | 24/101 [03:50<12:52, 10.03s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  25%|██▍       | 25/101 [03:57<11:38,  9.19s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  26%|██▌       | 26/101 [04:05<10:47,  8.63s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  28%|██▊       | 28/101 [04:13<07:30,  6.18s/it]
# Error 404
# /tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  29%|██▊       | 29/101 [04:17<06:38,  5.54s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  30%|██▉       | 30/101 [04:22<06:22,  5.39s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  31%|███       | 31/101 [04:28<06:23,  5.48s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  32%|███▏      | 32/101 [04:33<05:58,  5.19s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  33%|███▎      | 33/101 [04:47<09:10,  8.09s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  34%|███▎      | 34/101 [04:56<09:03,  8.11s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  35%|███▍      | 35/101 [05:02<08:24,  7.64s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  36%|███▌      | 36/101 [05:06<07:13,  6.66s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  37%|███▋      | 37/101 [05:11<06:17,  5.90s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  38%|███▊      | 38/101 [05:15<05:41,  5.43s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  39%|███▊      | 39/101 [05:20<05:34,  5.40s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  40%|███▉      | 40/101 [05:25<05:15,  5.17s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  41%|████      | 41/101 [05:29<04:58,  4.98s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  42%|████▏     | 42/101 [05:34<04:46,  4.85s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  43%|████▎     | 43/101 [05:39<04:39,  4.81s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  44%|████▎     | 44/101 [05:44<04:46,  5.03s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  45%|████▍     | 45/101 [05:48<04:27,  4.78s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  46%|████▌     | 46/101 [05:54<04:38,  5.06s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  47%|████▋     | 47/101 [06:07<06:38,  7.38s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  48%|████▊     | 48/101 [06:11<05:33,  6.29s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  49%|████▊     | 49/101 [06:16<05:14,  6.04s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  50%|████▉     | 50/101 [06:22<05:11,  6.11s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  50%|█████     | 51/101 [06:29<05:12,  6.25s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  51%|█████▏    | 52/101 [06:33<04:37,  5.67s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  52%|█████▏    | 53/101 [06:39<04:28,  5.60s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  53%|█████▎    | 54/101 [06:45<04:37,  5.90s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  54%|█████▍    | 55/101 [06:50<04:14,  5.53s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  55%|█████▌    | 56/101 [07:03<05:47,  7.73s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  56%|█████▋    | 57/101 [07:07<04:54,  6.68s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  57%|█████▋    | 58/101 [07:15<05:03,  7.06s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  58%|█████▊    | 59/101 [07:22<04:52,  6.97s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  59%|█████▉    | 60/101 [07:27<04:22,  6.40s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  60%|██████    | 61/101 [07:30<03:43,  5.58s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  61%|██████▏   | 62/101 [07:39<04:14,  6.53s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  62%|██████▏   | 63/101 [07:47<04:24,  6.95s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  63%|██████▎   | 64/101 [07:52<03:49,  6.19s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  64%|██████▍   | 65/101 [07:57<03:33,  5.93s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  65%|██████▌   | 66/101 [08:01<03:12,  5.49s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  66%|██████▋   | 67/101 [08:06<02:59,  5.29s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  67%|██████▋   | 68/101 [08:15<03:33,  6.46s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  69%|██████▉   | 70/101 [08:22<02:22,  4.60s/it]
# Error 404
# /tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  70%|███████   | 71/101 [08:29<02:39,  5.33s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  71%|███████▏  | 72/101 [08:34<02:32,  5.25s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  72%|███████▏  | 73/101 [08:40<02:34,  5.52s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  73%|███████▎  | 74/101 [08:47<02:39,  5.90s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  74%|███████▍  | 75/101 [08:55<02:49,  6.51s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  75%|███████▌  | 76/101 [09:00<02:29,  5.99s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  76%|███████▌  | 77/101 [09:09<02:45,  6.89s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  77%|███████▋  | 78/101 [09:16<02:41,  7.03s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  78%|███████▊  | 79/101 [09:24<02:41,  7.33s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  79%|███████▉  | 80/101 [09:32<02:40,  7.64s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  80%|████████  | 81/101 [09:36<02:07,  6.39s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  81%|████████  | 82/101 [09:42<01:59,  6.31s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  82%|████████▏ | 83/101 [09:47<01:47,  5.96s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  83%|████████▎ | 84/101 [09:51<01:32,  5.45s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  84%|████████▍ | 85/101 [09:57<01:25,  5.36s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  85%|████████▌ | 86/101 [10:03<01:25,  5.69s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  86%|████████▌ | 87/101 [10:07<01:12,  5.16s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  87%|████████▋ | 88/101 [10:13<01:11,  5.52s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  88%|████████▊ | 89/101 [10:19<01:07,  5.66s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  89%|████████▉ | 90/101 [10:24<01:00,  5.46s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  90%|█████████ | 91/101 [10:32<01:02,  6.25s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  91%|█████████ | 92/101 [10:39<00:58,  6.49s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  92%|█████████▏| 93/101 [10:44<00:46,  5.76s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  93%|█████████▎| 94/101 [10:50<00:41,  5.92s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  94%|█████████▍| 95/101 [10:56<00:35,  5.96s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  95%|█████████▌| 96/101 [11:02<00:30,  6.12s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  96%|█████████▌| 97/101 [11:09<00:25,  6.30s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  97%|█████████▋| 98/101 [11:16<00:19,  6.38s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  98%|█████████▊| 99/101 [11:21<00:12,  6.16s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
#  99%|█████████▉| 100/101 [11:29<00:06,  6.64s/it]/tmp/ipykernel_66777/1643270487.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   valid_data = valid_data.append(get_car_info(url), ignore_index=True)
# 100%|██████████| 101/101 [11:32<00:00,  6.86s/it]

# %% [markdown]
# ## Getting additional information from catalog (links from main DF)

# %%
for car_url in tqdm(valid_data['catalog_url'].value_counts().index.tolist()):
    try:
        catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
    except NoSuchElementException:
        print('Error 404', end='\r')
# Out:
#   0%|          | 0/46 [00:00<?, ?it/s]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#   2%|▏         | 1/46 [00:15<11:47, 15.71s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#   4%|▍         | 2/46 [00:24<08:24, 11.47s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#   7%|▋         | 3/46 [00:32<07:18, 10.19s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#   9%|▊         | 4/46 [00:41<06:36,  9.44s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  11%|█         | 5/46 [00:47<05:40,  8.31s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  13%|█▎        | 6/46 [00:53<05:05,  7.63s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  15%|█▌        | 7/46 [01:05<05:54,  9.08s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  17%|█▋        | 8/46 [01:13<05:23,  8.51s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  20%|█▉        | 9/46 [01:24<05:44,  9.30s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  22%|██▏       | 10/46 [01:35<05:54,  9.84s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  24%|██▍       | 11/46 [01:41<05:09,  8.85s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  26%|██▌       | 12/46 [01:48<04:36,  8.14s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  28%|██▊       | 13/46 [01:56<04:26,  8.08s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  30%|███       | 14/46 [02:08<04:54,  9.19s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  33%|███▎      | 15/46 [02:16<04:35,  8.88s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  35%|███▍      | 16/46 [02:25<04:32,  9.07s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  37%|███▋      | 17/46 [02:36<04:36,  9.53s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  39%|███▉      | 18/46 [02:44<04:14,  9.08s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  41%|████▏     | 19/46 [02:51<03:47,  8.44s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  43%|████▎     | 20/46 [02:56<03:16,  7.55s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  46%|████▌     | 21/46 [03:02<02:56,  7.07s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  48%|████▊     | 22/46 [03:08<02:36,  6.53s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  50%|█████     | 23/46 [03:15<02:37,  6.84s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  52%|█████▏    | 24/46 [03:22<02:33,  6.96s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  54%|█████▍    | 25/46 [03:29<02:22,  6.76s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  57%|█████▋    | 26/46 [03:34<02:09,  6.48s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  59%|█████▊    | 27/46 [03:42<02:11,  6.92s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  61%|██████    | 28/46 [03:49<02:03,  6.89s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  63%|██████▎   | 29/46 [03:56<01:56,  6.88s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  65%|██████▌   | 30/46 [04:04<01:56,  7.29s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  67%|██████▋   | 31/46 [04:12<01:53,  7.54s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  70%|██████▉   | 32/46 [04:19<01:40,  7.19s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  72%|███████▏  | 33/46 [04:27<01:35,  7.34s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  74%|███████▍  | 34/46 [04:32<01:21,  6.80s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  76%|███████▌  | 35/46 [04:40<01:17,  7.03s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  78%|███████▊  | 36/46 [04:46<01:08,  6.87s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  80%|████████  | 37/46 [04:52<00:59,  6.58s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  83%|████████▎ | 38/46 [04:58<00:51,  6.48s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  85%|████████▍ | 39/46 [05:05<00:46,  6.64s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  87%|████████▋ | 40/46 [05:10<00:36,  6.02s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  89%|████████▉ | 41/46 [05:17<00:31,  6.26s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  91%|█████████▏| 42/46 [05:23<00:24,  6.23s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  93%|█████████▎| 43/46 [05:34<00:22,  7.66s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  96%|█████████▌| 44/46 [05:42<00:15,  7.69s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
#  98%|█████████▊| 45/46 [05:49<00:07,  7.72s/it]/tmp/ipykernel_66777/2336546692.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   catalog_data = catalog_data.append(get_dicts_from_catalog(car_url), ignore_index=True)
# 100%|██████████| 46/46 [05:55<00:00,  7.72s/it]

# %%
valid_data.to_pickle("data/20220326_valid_data.pkl.zip", compression="zip")
catalog_data.to_pickle("data/20220326_catalog_data.pkl.zip", compression="zip")

# %%
print("super gen 2", catalog_data["super_gen_2"][5], sep="\n")
print("super gen 3", catalog_data["super_gen_3"][5], sep="\n")
# Out:
# super gen 2
# {'engine_type': 'DIESEL', 'gear_type': 'ALL_WHEEL_DRIVE', 'transmission': 'AUTOMATIC', 'power': 238, 'power_kvt': 175, 'acceleration': '8.3', 'clearance_min': 184, 'fuel_rate': 9.0}
# super gen 3
# {'sale-data-attributes': {'asciiCat': 'cars', 'puid10': '1', 'category': 'cars', 'mark': 'INFINITI', 'model': 'FX', 'state': 'used', 'class': 'J', 'type': 'suv', 'segment': 'PREMIUM', 'group': 'family', 'power': 238, 'year': 2011}}

# %% [markdown]
# to extract
#
# - super gen 2: power_kvt, acceleration, clearance_min, fuel_rate
# - super gen 3: mark, model, class, year, group
#
# join by
#
# - model
# - mark
# - year
